# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
# !wget "http://localhost:8080/SnomedDLQuery?message=105590001" -O "data/substances.json"
# Out:
# --2023-06-27 06:38:52--  http://localhost:8080/SnomedDLQuery?message=105590001
# Resolving localhost (localhost)... 127.0.0.1
# Connecting to localhost (localhost)|127.0.0.1|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: unspecified [application/json]
# Saving to: ‘data/substances.json’
#
# data/substances.jso     [ <=>                ]   3.12M  --.-KB/s    in 0.02s
#
# 2023-06-27 06:38:54 (168 MB/s) - ‘data/substances.json’ saved [3275901]

# %%
# !wget "http://localhost:8080/SnomedDLQuery?message=736479009" -O "data/roa.json"
# Out:
# --2023-06-27 06:38:54--  http://localhost:8080/SnomedDLQuery?message=736479009
# Resolving localhost (localhost)... 127.0.0.1
# Connecting to localhost (localhost)|127.0.0.1|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: unspecified [application/json]
# Saving to: ‘data/roa.json’
#
# data/roa.json           [ <=>                ]   5.68K  --.-KB/s    in 0s
#
# 2023-06-27 06:38:55 (296 MB/s) - ‘data/roa.json’ saved [5817]

# %%
# !wget "http://localhost:8080/SnomedDLQuery?message=736542009" -O "data/form.json"
# Out:
# --2023-06-27 06:38:55--  http://localhost:8080/SnomedDLQuery?message=736542009
# Resolving localhost (localhost)... 127.0.0.1
# Connecting to localhost (localhost)|127.0.0.1|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: unspecified [application/json]
# Saving to: ‘data/form.json’
#
# data/form.json          [ <=>                ]  77.16K  --.-KB/s    in 0s
#
# 2023-06-27 06:38:56 (208 MB/s) - ‘data/form.json’ saved [79010]

# %%
 # !wget "http://localhost:8080/SnomedDLQuery?message=284009009" -O "data/roa_two.json"
# Out:
# --2023-06-27 06:38:56--  http://localhost:8080/SnomedDLQuery?message=284009009
# Resolving localhost (localhost)... 127.0.0.1
# Connecting to localhost (localhost)|127.0.0.1|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: unspecified [application/json]
# Saving to: ‘data/roa_two.json’
#
# data/roa_two.json       [ <=>                ]  31.57K  --.-KB/s    in 0s
#
# 2023-06-27 06:38:57 (220 MB/s) - ‘data/roa_two.json’ saved [32328]

# %%
 # !wget "http://localhost:8080/SnomedDLQuery?message=763158003" -O "data/medical_product.json"
# Out:
# --2023-06-27 06:38:57--  http://localhost:8080/SnomedDLQuery?message=763158003
# Resolving localhost (localhost)... 127.0.0.1
# Connecting to localhost (localhost)|127.0.0.1|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: unspecified [application/json]
# Saving to: ‘data/medical_product.json’
#
# data/medical_produc     [ <=>                ]   4.19M  --.-KB/s    in 0.02s
#
# 2023-06-27 06:38:58 (222 MB/s) - ‘data/medical_product.json’ saved [4390514]

# %%
import json
import os
import ast
import pandas as pd

def load_wget_results():
    def helper(filename):
        fullpath = f"data/{filename}"
        with open(fullpath,"r") as f:
            content = f.read()[1:-1]
#             import ipdb; ipdb.set_trace()
            obj = ast.literal_eval(content)
            return pd.DataFrame(obj)
    return {filename: helper(filename) for filename in os.listdir("data") if filename.endswith(".json")}

# %%
dfs = load_wget_results()

# %%
dfs['medical_product.json'].dropna()
# Out:
#                  iri                                          prefLabel  \
# 48         874866000  Abacavir (as abacavir sulfate) 60 mg tablet fo...
# 61         255683006                            Immunotherapeutic agent
# 145       1119349007                            SARS-CoV-2 mRNA vaccine
# 230    2251000221101  Live attenuated Measles morbillivirus and Mump...
# 591    2071000221100  Whole cell Bordetella pertussis and Corynebact...
# ...              ...                                                ...
# 23756      770311004  Cromolyn sodium 5 mg/actuation pressurized sus...
# 23793     1156183006  Human alphaherpesvirus 3 recombinant surface g...
# 23828      871744002  Cytomegalovirus antibody only product in paren...
# 23836      353844008                            Radionuclide generators
# 23900      871768005  Influenza virus antigen only vaccine product i...
#
#                                                    label  \
# 48     Product containing precisely abacavir (as abac...
# 61                     Immunotherapeutic agent (product)
# 145    Vaccine product containing only severe acute r...
# 230    Vaccine product containing only live attenuate...
# 591    Pediatric vaccine product containing only whol...
# ...                                                  ...
# 23756  Product containing precisely cromoglicate sodi...
# 23793  Vaccine product containing only Human alphaher...
# 23828  Product containing only Cytomegalovirus antibo...
# 23836                  Radionuclide generators (product)
# 23900  Vaccine product containing only Influenza viru...
#
#                                                 altLabel
# 48     Abacavir (as abacavir sulfate) 60 mg dispersib...
# 61                                     Immunologic agent
# 145    Severe acute respiratory syndrome coronavirus ...
# 230    Live attenuated measles and mumps and rubella ...
# 591    Diphtheria toxoid and Haemophilus influenzae t...
# ...                                                  ...
# 23756  Sodium cromoglicate 5 mg/actuation pressurized...
# 23793  Recombinant Varicella-zoster glycoprotein E va...
# 23828  Cytomegalovirus immunoglobulin only product in...
# 23836                             Radionuclide generator
# 23900               Influenza vaccine in nasal dose form
#
# [221 rows x 4 columns]

# %%
dfs['substances.json']
# Out:
#              iri                                         prefLabel  \
# 0       47974007                        Blood group antibody Tg^a^
# 1       24851008                             Deoxyribonucleic acid
# 2      707141001                                 2-hydroxycaproate
# 3      387940006         Italian cypress specific immunoglobulin E
# 4      129994000  Quinate dehydrogenase (pyrroloquinoline-quinone)
# ...          ...                                               ...
# 27187  396462008                                        Bambuterol
# 27188   54791001                              Metanil yellow stain
# 27189  418540006                          Calcium regulating agent
# 27190   49069005                                      Lead isotope
# 27191  130881003       4-hydroxyphenylacetaldehyde-oxime isomerase
#
#                                                    label  \
# 0                 Blood group antibody Tg^a^ (substance)
# 1                      Deoxyribonucleic acid (substance)
# 2                          2-hydroxycaproate (substance)
# 3      Cupressus sempervirens specific immunoglobulin...
# 4      Quinate dehydrogenase (pyrroloquinoline-quinon...
# ...                                                  ...
# 27187                             Bambuterol (substance)
# 27188                   Metanil yellow stain (substance)
# 27189               Calcium regulating agent (substance)
# 27190                           Lead isotope (substance)
# 27191  4-hydroxyphenylacetaldehyde-oxime isomerase (s...
#
#                                                altLabel definition
# 0                                                   NaN        NaN
# 1                           DNA - Deoxyribonucleic acid        NaN
# 2                                                   NaN        NaN
# 3      Cupressus sempervirens specific immunoglobulin E        NaN
# 4              NAD(P)-independent quinate dehydrogenase        NaN
# ...                                                 ...        ...
# 27187                                               NaN        NaN
# 27188                                    Metanil yellow        NaN
# 27189                                               NaN        NaN
# 27190                                               NaN        NaN
# 27191                                               NaN        NaN
#
# [27192 rows x 5 columns]

# %%
dfs['form.json']
# Out:
#             iri                                     prefLabel  \
# 0     385105007                               Cutaneous spray
# 1    1231323007                      Powder for dental cement
# 2     422353003             Prolonged-release oral suspension
# 3    1163573008                       Film-coated oral tablet
# 4     385128008                   Prolonged-release eye drops
# ..          ...                                           ...
# 442   385162008                                   Nasal stick
# 443  1229992005         Powder for solution for iontophoresis
# 444  1231563007                   Powder for vapor inhalation
# 445  1255299001  Tablet for oromucosal solution for mouthwash
# 446   385139006                                    Ear powder
#
#                                               altLabel  \
# 0                 Conventional release cutaneous spray
# 1        Conventional release powder for dental cement
# 2                     Extended-release oral suspension
# 3         Conventional release film-coated oral tablet
# 4                           Extended-release eye drops
# ..                                                 ...
# 442                   Conventional release nasal stick
# 443  Powder for conventional release solution for i...
# 444  Conventional release powder for vapour inhalation
# 445  Tablet for conventional release oromucosal sol...
# 446                    Conventional release ear powder
#
#                                                  label
# 0     Conventional release cutaneous spray (dose form)
# 1    Conventional release powder for dental cement ...
# 2        Prolonged-release oral suspension (dose form)
# 3    Conventional release film-coated oral tablet (...
# 4              Prolonged-release eye drops (dose form)
# ..                                                 ...
# 442       Conventional release nasal stick (dose form)
# 443  Powder for conventional release solution for i...
# 444  Conventional release powder for vapor inhalati...
# 445  Tablet for conventional release oromucosal sol...
# 446        Conventional release ear powder (dose form)
#
# [447 rows x 4 columns]

# %%
dfs['form.json'][['iri','prefLabel']]
# Out:
#             iri                                     prefLabel
# 0     385105007                               Cutaneous spray
# 1    1231323007                      Powder for dental cement
# 2     422353003             Prolonged-release oral suspension
# 3    1163573008                       Film-coated oral tablet
# 4     385128008                   Prolonged-release eye drops
# ..          ...                                           ...
# 442   385162008                                   Nasal stick
# 443  1229992005         Powder for solution for iontophoresis
# 444  1231563007                   Powder for vapor inhalation
# 445  1255299001  Tablet for oromucosal solution for mouthwash
# 446   385139006                                    Ear powder
#
# [447 rows x 2 columns]

# %%
dfs['roa.json'][['iri','prefLabel']]
# Out:
#            iri             prefLabel
# 0    738946006          Intravesical
# 1    738948007                 Nasal
# 2   1255345008            Intestinal
# 3    762070008           Intraocular
# 4    738952007                Ocular
# 5    764295003          Subcutaneous
# 6    738984000            Parenteral
# 7    738988002              Urethral
# 8    761829007            Sublingual
# 9    764786007         Oropharyngeal
# 10   738986003                Rectal
# 11   738982001            Oromucosal
# 12   783351009       Intraperitoneal
# 13   840615007        Intraarticular
# 14   738908004          Endocervical
# 15   738906000                Dental
# 16   738956005                  Oral
# 17   738904002             Cutaneous
# 18   738910002         Gastroenteral
# 19   770101002  Endotracheopulmonary
# 20  1230218002           Periodontal
# 21   738945005          Intrauterine
# 22   738943003              Gingival
# 23  1231459002        Extracorporeal
# 24   738985004             Pulmonary
# 25   738987007           Transdermal
# 26   764376008               Enteral
# 27   738989005               Vaginal
# 28   738983006                  Otic
# 29   785909009         Intralesional
# 30     Nothing                   NaN
# 31   763825005                Buccal

# %%
dfs['roa_two.json']
# Out:
#            iri                           prefLabel  \
# 0    447227007                 Transtympanic route
# 1     60213007                Intramedullary route
# 2    766790006  Extracorporeal haemodialysis route
# 3     38239002               Intraperitoneal route
# 4    418287000                  Intracoronal route
# ..         ...                                 ...
# 159  372471009                  Intravesical route
# 160  714743009                Extracorporeal route
# 161  372454008                 Gastroenteral route
# 162  447964005               Digestive tract route
# 163  447121004                  Intramammary route
#
#                                             definition  \
# 0    An otic route that begins across the tympanic ...
# 1    An intraosseous route that begins within the m...
# 2    A route used for extracorporeal hemodialysis w...
# 3    A body cavity route that begins within the per...
# 4    A dental route that begins within a portion of...
# ..                                                 ...
# 159  A body cavity route that begins within the bla...
# 160           A route that occurs outside of the body.
# 161  A digestive tract route that begins in the gas...
# 162  A route that begins anywhere in the digestive ...
# 163             A route that begins within the breast.
#
#                                                  label             altLabel
# 0                Transtympanic route (qualifier value)                  NaN
# 1               Intramedullary route (qualifier value)   Intramedullary use
# 2    Extracorporeal hemodialysis route (qualifier v...                  NaN
# 3              Intraperitoneal route (qualifier value)  Intraperitoneal use
# 4                 Intracoronal route (qualifier value)                  NaN
# ..                                                 ...                  ...
# 159               Intravesical route (qualifier value)     Intravesical use
# 160             Extracorporeal route (qualifier value)                  NaN
# 161              Gastroenteral route (qualifier value)    Gastroenteral use
# 162            Digestive tract route (qualifier value)                  NaN
# 163               Intramammary route (qualifier value)                  NaN
#
# [164 rows x 5 columns]

# %%
def clean_df(df):
    new_df = df[['iri','prefLabel']].copy()
    new_df['prefLabel'] = new_df['prefLabel'].str.upper()
    new_df.columns = ['snomed_code','snomed_label']
    return new_df.dropna()

def clean_form_snomed(raw_form_df):
    mapping = {
        "EYE" : "OPHTALMIC",
        "EAR" : "OTIC",
        "NOSE" : "NASAL"
    }
    def sub_form_snomed_helper(form):
        return ' '.join([mapping.get(el,el) for el in form.split(" ")])
    form_df = raw_form_df.copy()
    form_df['old_snomed_label'] = form_df['snomed_label'].copy()
    form_df['snomed_label'] = [sub_form_snomed_helper(el.replace(" DOSE FORM","")) for el in form_df['old_snomed_label'].values]
    return form_df

def clean_form_ocrx(raw_form_df):
    def clean_form_ocrx_helper(el):
        # removes the word in and inverts it
        if " IN " in el:
            splitted = el.split(" IN ")
            if len(splitted) > 2:
                import ipdb; ipdb.set_trace()
            start, last = splitted[:2]
            return last + " " + start
        else:
            return el
            
    form_df = raw_form_df.copy()
#     import ipdb; ipdb.set_trace()
    form_df['old_ocrx_label'] = form_df['ocrx_label'].copy()
    form_df['ocrx_label'] = [clean_form_ocrx_helper(el) for el in form_df['old_ocrx_label'].values]
    return form_df

# %%
clean_dfs = {key: clean_df(df) for key, df in dfs.items()}

# %%
clean_dfs['substances.json']
# Out:
#       snomed_code                                      snomed_label
# 0        47974007                        BLOOD GROUP ANTIBODY TG^A^
# 1        24851008                             DEOXYRIBONUCLEIC ACID
# 2       707141001                                 2-HYDROXYCAPROATE
# 3       387940006         ITALIAN CYPRESS SPECIFIC IMMUNOGLOBULIN E
# 4       129994000  QUINATE DEHYDROGENASE (PYRROLOQUINOLINE-QUINONE)
# ...           ...                                               ...
# 27187   396462008                                        BAMBUTEROL
# 27188    54791001                              METANIL YELLOW STAIN
# 27189   418540006                          CALCIUM REGULATING AGENT
# 27190    49069005                                      LEAD ISOTOPE
# 27191   130881003       4-HYDROXYPHENYLACETALDEHYDE-OXIME ISOMERASE
#
# [27191 rows x 2 columns]

# %%
def gather_ocrx_medical_term(medical_term):
    df = pd.read_csv(f"./ocrx-data/{medical_term}_en.csv")
    df = df.drop_duplicates().sort_values("sLabel")
    labels = df['sLabel'].values
    codes = df['s'].values
    return [(str(val),str(val_code)) for val, val_code in zip(labels,codes)]

def parse_dosage(dose):
    splitted = dose.split(" ")
    unit = splitted[-1]
    if unit in units_conversion:
        pass
# print('\n'.join([str(el) for el in df_compo['dose'].unique()]))
ocrx_terms = ['form','roa','substance']
ocrx_dfs = [gather_ocrx_medical_term(term) for term in ocrx_terms]

def convert_ocrx_to_df(ocrx_elems):
    return [pd.DataFrame(ocrx_df,columns=['ocrx_label','ocrx_code']) for ocrx_df in ocrx_elems]

ocrx_dfs = convert_ocrx_to_df(ocrx_dfs)
ocrx_dfs[0] = clean_form_ocrx(ocrx_dfs[0])
ocrx_form_df, ocrx_roa_df, ocrx_substance_df = ocrx_dfs

from pytrie import Trie
def make_trie(ocrx_def_df):
    return {row['ocrx_label']: row['ocrx_code'] for _, row in ocrx_def_df.iterrows()}

def make_trie_ansm(ansm_def_df):
    return {row['snomed_label']: row['snomed_code'] for _, row in ansm_def_df.iterrows()}

def get_prefix(trie,term):
    words = term.split(' ')
    for i in reversed(range(1,len(words)+1)):
        term = ' '.join(words[:i])
        if term in trie:
            return (term, trie[term])
    return None


snomed_dfs = [clean_form_snomed(clean_dfs['form.json']),clean_dfs['roa.json'],clean_dfs['substances.json']]
ocrx_form_trie,ocrx_roa_trie,ocrx_substance_trie = [make_trie(el) for el in ocrx_dfs]
snomed_tries = [make_trie_ansm(el) for el in snomed_dfs]

# %%
import os
def print_stats(df_merged,type_fn,name='snomed'):
    # total_match
    prefix_code = f"{name}_code"
    print("TOTAL MATCH:")
    total_df = df_merged.dropna()
    print(total_df.head())
    print(total_df.shape)
    total_df.to_csv(f"match-ocrx/match_{type_fn}_total_match.csv")
    # left missing
    print("ONLY OCRX")
    only_ocrx = df_merged.loc[df_merged[prefix_code].isna()]
    print(only_ocrx.head())
    print(only_ocrx.shape)
    only_ocrx.to_csv(f"match-ocrx/match_{type_fn}_only_ocrx.csv")
    # right missing
    print(f"ONLY {name.upper()}")
    only_ansm = df_merged.loc[df_merged['ocrx_code'].isna()]
    print(only_ansm.head())
    print(only_ansm.shape)
    only_ansm.to_csv(f"match-ocrx/match_{type_fn}_only_{name}.csv")

def add_prefixes(df,trie,trie_ansm,prefix='snomed'):
    prefix_code = f"{prefix}_code"
    prefix_label = f"{prefix}_label"
    def process_row(row,trie):
        if type(row['ocrx_code']) == str and type(row[prefix_code]) == str:
            return (row['ocrx_code'], row['ocrx_label'], 'EXACT')
        elif str(row['ocrx_code']) == 'nan':
            result = get_prefix(trie,row[prefix_label])
            if result is None:
                return (None, None, 'NONE')
            else:
                prefix_ocrx, ocrx_code = result
                return (ocrx_code, prefix_ocrx, 'PREFIX')
        else:
            return (row['ocrx_code'], row['ocrx_label'], 'NA')
    def process_row_ansm(row,trie):
        if type(row['ocrx_code']) == str and type(row[prefix_code]) == str:
            return (row[prefix_code], row[prefix_label], 'EXACT')
        elif str(row[prefix_code]) == 'nan':
            result = get_prefix(trie,row['ocrx_label'])
            if result is None:
                return (None, None, 'NONE')
            else:
                prefix_ansm, ansm_code = result
                return (ansm_code, prefix_ansm, 'PREFIX')
        else:
            return (row[prefix_code], row[prefix_label], 'NA')
        
            
#     import ipdb; ipdb.set_trace()
    els = ['ocrx','snomed']
    new_df = df.copy()
    for el, trie_el, process_fn in zip(els,[trie,trie_ansm],[process_row,process_row_ansm]):
        results = [process_fn(row,trie_el) for _, row in df.iterrows()]
        codes = [result[0] for result in results]
        full_terms = [result[1] for result in results]
        match_types = [result[2] for result in results]
        new_df[f'{el}_code'] = codes
        new_df[f'{el}_label'] = full_terms
        new_df[f'{el}_match_type'] = match_types
    return new_df

filenames = ['form','roa','substance']
if not os.path.exists("match-ocrx"):
    os.mkdir("match-ocrx")
ocrxs = [ocrx_form_df,ocrx_roa_df,ocrx_substance_df]
# ansms = [bdpm_form_df,bdpm_roa_df,bdpm_substance_df]
others = snomed_dfs
others_tries = snomed_tries
tries = [ocrx_form_trie,ocrx_roa_trie,ocrx_substance_trie]
for ocrx, ansm, filename, trie, trie_ansm in zip(ocrxs,others,filenames,tries,others_tries):
    fullpath = f"match-ocrx/match_{filename}.csv"
    df_merged = pd.merge(ocrx,ansm,how="outer",left_on=['ocrx_label'], right_on=['snomed_label'])
#     import ipdb; ipdb.set_trace()
    df_merged_with_prefix = add_prefixes(df_merged,trie,trie_ansm)
    print_stats(df_merged_with_prefix,filename)
    df_merged_with_prefix.to_csv(fullpath)
# Out:
# TOTAL MATCH:
#          ocrx_label   ocrx_code      old_ocrx_label snomed_code  \
# 56     ORAL CAPSULE  4000000461     CAPSULE IN ORAL   420692007
# 59  VAGINAL CAPSULE  4000000462  CAPSULE IN VAGINAL   385175008
# 72    VAGINAL CREAM  4000000693    CREAM IN VAGINAL   385165005
# 82      NASAL DROPS  4000000910      DROPS IN NASAL   385152001
# 86       ORAL DROPS  4000000427       DROPS IN ORAL   385018001
#
#        snomed_label old_snomed_label ocrx_match_type snomed_match_type
# 56     ORAL CAPSULE     ORAL CAPSULE           EXACT             EXACT
# 59  VAGINAL CAPSULE  VAGINAL CAPSULE           EXACT             EXACT
# 72    VAGINAL CREAM    VAGINAL CREAM           EXACT             EXACT
# 82      NASAL DROPS      NASAL DROPS           EXACT             EXACT
# 86       ORAL DROPS       ORAL DROPS           EXACT             EXACT
# (60, 8)
# ONLY OCRX
#                                           ocrx_label   ocrx_code  \
# 0                                            AEROSOL  4000000016
# 1                             AEROSOL (METERED DOSE)  4000000027
# 4                    DISINFECTANT (DOMESTIC) AEROSOL  4000000443
# 5  DISINFECTANT (DOMESTIC) OR DISINFECTANT (FOOD ...  4000000346
# 6  DISINFECTANT (DOMESTIC) OR DISINFECTANT (HOSPI...  4000000992
#
#                                       old_ocrx_label snomed_code snomed_label  \
# 0                                            AEROSOL        None         None
# 1                             AEROSOL (METERED DOSE)        None         None
# 4                 AEROSOL IN DISINFECTANT (DOMESTIC)        None         None
# 5  AEROSOL IN DISINFECTANT (DOMESTIC) OR DISINFEC...        None         None
# 6  AEROSOL IN DISINFECTANT (DOMESTIC) OR DISINFEC...        None         None
#
#   old_snomed_label ocrx_match_type snomed_match_type
# 0              NaN              NA              NONE
# 1              NaN              NA              NONE
# 4              NaN              NA              NONE
# 5              NaN              NA              NONE
# 6              NaN              NA              NONE
# (719, 8)
# ONLY SNOMED
#     ocrx_label ocrx_code old_ocrx_label snomed_code  \
# 935       None      None            NaN   385105007
# 937       None      None            NaN   422353003
# 938       None      None            NaN  1163573008
# 939       None      None            NaN   385128008
# 941       None      None            NaN   385289005
#
#                           snomed_label                   old_snomed_label  \
# 935                    CUTANEOUS SPRAY                    CUTANEOUS SPRAY
# 937  PROLONGED-RELEASE ORAL SUSPENSION  PROLONGED-RELEASE ORAL SUSPENSION
# 938            FILM-COATED ORAL TABLET            FILM-COATED ORAL TABLET
# 939  PROLONGED-RELEASE OPHTALMIC DROPS        PROLONGED-RELEASE EYE DROPS
# 941                             RECTAL                   RECTAL DOSE FORM
#
#     ocrx_match_type snomed_match_type
# 935            NONE                NA
# 937            NONE                NA
# 938            NONE                NA
# 939            NONE                NA
# 941            NONE                NA
# (271, 8)
# TOTAL MATCH:
#         ocrx_label   ocrx_code snomed_code    snomed_label ocrx_match_type  \
# 2           BUCCAL  4100000047   763825005          BUCCAL           EXACT
# 4           DENTAL  4100000072   738906000          DENTAL           EXACT
# 14  EXTRACORPOREAL  4100000074  1231459002  EXTRACORPOREAL           EXACT
# 38   INTRALESIONAL  4100000015   785909009   INTRALESIONAL           EXACT
# 41     INTRAOCULAR  4100000051   762070008     INTRAOCULAR           EXACT
#
#    snomed_match_type
# 2              EXACT
# 4              EXACT
# 14             EXACT
# 38             EXACT
# 41             EXACT
# (18, 6)
# ONLY OCRX
#             ocrx_label   ocrx_code snomed_code snomed_label ocrx_match_type  \
# 0          ARTHOGRAPHY  4100000037        None         None              NA
# 1   BLOCK/INFILTRATION  4100000043        None         None              NA
# 3          CYSTOGRAPHY  4100000022        None         None              NA
# 5             DIALYSIS  4100000041        None         None              NA
# 6  DISINFECTANT (BARN)  4100000021        None         None              NA
#
#   snomed_match_type
# 0              NONE
# 1              NONE
# 3              NONE
# 5              NONE
# 6              NONE
# (77, 6)
# ONLY SNOMED
#    ocrx_label ocrx_code snomed_code   snomed_label ocrx_match_type  \
# 95       None      None  1255345008     INTESTINAL            NONE
# 96       None      None   738952007         OCULAR            NONE
# 97       None      None   738984000     PARENTERAL            NONE
# 98       None      None   764786007  OROPHARYNGEAL            NONE
# 99       None      None   738982001     OROMUCOSAL            NONE
#
#    snomed_match_type
# 95                NA
# 96                NA
# 97                NA
# 98                NA
# 99                NA
# (14, 6)
# TOTAL MATCH:
#                            ocrx_label   ocrx_code snomed_code  \
# 1909  2-BROMO-2-NITROPROPANE-1,3-DIOL  3000001754   255881006
# 2069                   2-PHENYLPHENOL  3000000039   255991004
# 2248     3,4,5-TRIHYDROXYBENZOIC ACID  3000004794    15668004
# 2381                        3-PHYTASE  3000002205    77247009
# 2815            5-AMINOLEVULINIC ACID  3100005281   259496005
#
#                          snomed_label ocrx_match_type snomed_match_type
# 1909  2-BROMO-2-NITROPROPANE-1,3-DIOL           EXACT             EXACT
# 2069                   2-PHENYLPHENOL           EXACT             EXACT
# 2248     3,4,5-TRIHYDROXYBENZOIC ACID           EXACT             EXACT
# 2381                        3-PHYTASE           EXACT             EXACT
# 2815            5-AMINOLEVULINIC ACID           EXACT             EXACT
# (10246, 6)
# ONLY OCRX
#                                           ocrx_label   ocrx_code snomed_code  \
# 0  ((((3-BROMOMESITYL)CARBAMOYL)METHYL)IMINO)DIAC...  3000004317        None
# 1  (((S)-2-(4-AMINO-2-OXO-1(2H)-PYRIMIDINYL)-1-(H...  3000004831        None
# 2                ((177)LU-DOTA(0)-TYR(3))-OCTREOTATE  3000001032        None
# 3  ((1R)-1-((2,5-DICHLOROBENZAMIDO)ACETAMIDO)-3-M...  3000000494        None
# 4  ((1R)-3-METHYL-1-(((2S)-3-PHENYL-2-((PYRAZINYL...  3000002091        None
#
#   snomed_label ocrx_match_type snomed_match_type
# 0         None              NA              NONE
# 1         None              NA              NONE
# 2         None              NA              NONE
# 3         None              NA              NONE
# 4         None              NA              NONE
# (22092, 6)
# ONLY SNOMED
#       ocrx_label ocrx_code     snomed_code  \
# 29871       None      None        47974007
# 29872       None      None       707141001
# 29874       None      None       129994000
# 29875       None      None       130501006
# 29876       None      None  24431000087104
#
#                                             snomed_label ocrx_match_type  \
# 29871                         BLOOD GROUP ANTIBODY TG^A^            NONE
# 29872                                  2-HYDROXYCAPROATE            NONE
# 29874   QUINATE DEHYDROGENASE (PYRROLOQUINOLINE-QUINONE)            NONE
# 29875                   RIBONUCLEASE (POLY-(U)-SPECIFIC)            NONE
# 29876  HUMAN PAPILLOMAVIRUS TYPE 31 L1 CAPSID PROTEIN...            NONE
#
#       snomed_match_type
# 29871                NA
# 29872                NA
# 29874                NA
# 29875                NA
# 29876                NA
# (21567, 6)

# %%
# !nemo .
