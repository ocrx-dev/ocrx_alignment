# %%
import pandas as pd
df_description = pd.read_csv("Snapshot/Terminology/sct2_Description_Snapshot-en_INT_20220731.txt",sep='\t')

# %%
df_atorvastatin = pd.DataFrame([val for _, val in df_description.iterrows() if 'atorvastatin' in str(val['term']).lower()])

# %%
df_description['conceptId'].value_counts()
# Out:
# 138875005             76
# 37810007              46
# 79962008              39
# 111468003             36
# 46732000              35
#                       ..
# 264958002              2
# 264960000              2
# 264961001              2
# 264962008              2
# 900000000000550004     2
# Name: conceptId, Length: 495637, dtype: int64

# %%
df_atorvastatin['typeId'].value_counts()
# Out:
# 900000000000013009    175
# 900000000000003001    128
# Name: typeId, dtype: int64

# %%
df_atorvastatin
# Out:
#                  id  effectiveTime  active            moduleId   conceptId  \
# 164779    173134014       20180731       0  900000000000207008   108600003
# 164780    173135010       20180731       1  900000000000207008   108601004
# 200003    216272015       20170731       0  900000000000207008   134489001
# 446668    463010015       20170731       0  900000000000207008   320029006
# 446669    463011016       20170731       0  900000000000207008   320030001
# ...             ...            ...     ...                 ...         ...
# 1553602  5035252018       20220430       1  900000000000207008  1217241000
# 1553603  5035253011       20220430       1  900000000000207008  1217242007
# 1553604  5035254017       20220430       1  900000000000207008  1217242007
# 1553605  5035255016       20220430       1  900000000000207008  1217243002
# 1553606  5035256015       20220430       1  900000000000207008  1217243002
#
#         languageCode              typeId  \
# ...

# %%
df_ipilimumab = pd.DataFrame([val for _, val in df_description.iterrows() if 'ipilimumab' in str(val['term']).lower()])
df_ipilimumab['typeId'].value_counts()
# Out:
# 900000000000013009    15
# 900000000000003001    12
# Name: typeId, dtype: int64

# %%
df_ipilimumab
# Out:
#                  id  effectiveTime  active            moduleId   conceptId  \
# 1198717  2968411014       20170731       1  900000000000207008   697995005
# 1198723  2968417013       20170731       1  900000000000207008   697995005
# 1227483  3013726018       20180131       0  900000000000207008   704649006
# 1227672  3013923016       20150131       1  900000000000207008   704650006
# 1227735  3013988011       20150131       1  900000000000207008   704650006
# 1227870  3014129014       20180731       0  900000000000207008   704649006
# 1272708  3303573019       20170731       0  900000000000207008   715738009
# 1272709  3303574013       20170731       0  900000000000207008   715738009
# 1326959  3488808015       20190131       0  900000000000207008   715738009
# 1334872  3498104018       20190131       0  900000000000207008   715738009
# 1334873  3498105017       20190131       0  900000000000207008   715738009
# ...

# %%
df_description.loc[[el == 900000000000013009 or el == 900000000000003001 for el in df_description['typeId'].values]]
# Out:
#                          id  effectiveTime  active            moduleId  \
# 0                    101013       20170731       1  900000000000207008
# 1                    102018       20170731       1  900000000000207008
# 2                    103011       20170731       1  900000000000207008
# 3                    104017       20170731       1  900000000000207008
# 4                    105016       20170731       1  900000000000207008
# ...                     ...            ...     ...                 ...
# 1567700  900000000001208014       20170731       1  900000000000012004
# 1567701  900000000001209018       20170731       1  900000000000012004
# 1567702  900000000001210011       20170731       1  900000000000012004
# 1567703  900000000001211010       20170731       1  900000000000012004
# 1567704  934530801000132110       20170731       1  900000000000207008
#
#                   conceptId languageCode              typeId  \
# ...

# %%
import pandas as pd
df_concept = pd.read_csv("Snapshot/Terminology/sct2_Concept_Snapshot-en_INT_20220731.txt",sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-1fb353dfb6be> in <module>
#       1 import pandas as pd
# ----> 2 df_concept = pd.read_csv("Snapshot/Terminology/sct2_Concept_Snapshot-en_INT_20220731.txt",sep='\t')
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
[row for _,row in df_description.iterrows() if 'has' in str(row['term']).lower()][0]
# Out:
# id                                   777016
# effectiveTime                      20170731
# active                                    1
# moduleId                 900000000000012004
# conceptId                         127489000
# languageCode                             en
# typeId                   900000000000013009
# term                  Has active ingredient
# caseSignificanceId       900000000000448009
# Name: 659, dtype: object

# %%
HAS_ACTIVE_INGREDIENT_ID = 127489000

# %%
df_has = pd.DataFrame([row for _,row in df_description.iterrows() if str(row['term']).lower().startswith("has ")])

# %%
list(df_has['term'])
# Out:
# ['Has active ingredient',
#  'Has depth',
#  'Has location',
#  'Has setting',
#  'Has translucency',
#  'Has clarity',
#  'Has transparency',
#  'Has patient',
#  'Has length',
#  'Has provider',
#  'Has plan',
#  'Has part',
#  'Has assessment',
#  'Has standard deviation',
#  'Has units',
#  'Has thickness',
#  'Has value',
#  'Has time',
#  'Has method',
#  'Has objective observations',
#  'Has age',
#  'Has time',
#  'Has timing',
#  'Has duration',
#  'Has width',
#  'Has color',
#  'Has consistency',
#  'Has distance',
#  'Has distribution',
#  'Has intensity',
#  'Has odor',
#  'Has pattern',
#  'Has size',
#  'Has shape',
#  'Has texture',
#  'Has configuration',
#  'Has development',
#  'Has urgency',
#  'Has grade',
#  'Has subjective observations',
#  'Has measured component',
#  'Has object',
#  'Has scale type',
#  'Has time aspect',
#  'Has property',
#  'Has specimen',
#  'Has time -RETIRED-',
#  'Has action',
#  'Has support worker',
# ...

# %%
df_has.loc[df_has.term == 'Has dose form administration method']
# Out:
#                  id  effectiveTime  active            moduleId  conceptId  \
# 1346845  3521396010       20180131       1  900000000000012004  736472000
#
#         languageCode              typeId                                 term  \
# 1346845           en  900000000000013009  Has dose form administration method
#
#          caseSignificanceId
# 1346845  900000000000448009

# %%
import pandas as pd
df_rel = pd.read_csv('Snapshot/Terminology/sct2_Relationship_Snapshot_INT_20220731.txt',sep='\t')

# %%
df_rel['sourceId'].value_counts()
# Out:
# 253115005             130
# 176086008             129
# 91338001              125
# 80762004              125
# 40587007              123
#                      ...
# 189623006               1
# 189624000               1
# 189625004               1
# 189626003               1
# 900000000000550004      1
# Name: sourceId, Length: 444384, dtype: int64

# %%
df_rel['destinationId'].value_counts()
# Out:
# 255399007    32591
# 129284003    27801
# 39937001     25863
# 23583003     21937
# 38112003     21458
#              ...
# 724965001        1
# 724966000        1
# 724984003        1
# 725952004        1
# 240178007        1
# Name: destinationId, Length: 167372, dtype: int64

# %%
df_description.loc[df_description.conceptId == 255399007]
# Out:
#                id  effectiveTime  active            moduleId  conceptId  \
# 364325  380598010       20170731       1  900000000000207008  255399007
# 364326  380599019       20170731       1  900000000000207008  255399007
# 629129  646433016       20170731       1  900000000000207008  255399007
#
#        languageCode              typeId                          term  \
# 364325           en  900000000000013009                    Congenital
# 364326           en  900000000000013009                     Congenita
# 629129           en  900000000000003001  Congenital (qualifier value)
#
#         caseSignificanceId
# 364325  900000000000448009
# 364326  900000000000448009
# 629129  900000000000448009

# %%
df_description.loc[df_description.conceptId == 736472000]
# Out:
#                  id  effectiveTime  active            moduleId  conceptId  \
# 1346844  3521395014       20180131       1  900000000000012004  736472000
# 1346845  3521396010       20180131       1  900000000000012004  736472000
#
#         languageCode              typeId  \
# 1346844           en  900000000000003001
# 1346845           en  900000000000013009
#
#                                                     term  caseSignificanceId
# 1346844  Has dose form administration method (attribute)  900000000000448009
# 1346845              Has dose form administration method  900000000000448009

# %%
df_rel.loc[df_rel.sourceId == 736472000]
# Out:
#                  id  effectiveTime  active            moduleId   sourceId  \
# 2673349  9059470023       20180131       1  900000000000012004  736472000
#
#          destinationId  relationshipGroup     typeId  characteristicTypeId  \
# 2673349      762705008                  0  116680003    900000000000011006
#
#                  modifierId
# 2673349  900000000000451002

# %%
df_description.loc[df_description.conceptId == 762705008]
# Out:
#                  id  effectiveTime  active            moduleId  conceptId  \
# 1361312  3635487013       20180131       1  900000000000012004  762705008
# 1361313  3635488015       20180131       1  900000000000012004  762705008
#
#         languageCode              typeId  \
# 1361312           en  900000000000003001
# 1361313           en  900000000000013009
#
#                                                term  caseSignificanceId
# 1361312  Concept model object attribute (attribute)  900000000000448009
# 1361313              Concept model object attribute  900000000000448009

# %%
# Pourquoi la seule relation pour "Has dose form administration method" map to "Concept model object attribute". Ou sont les drogues et routes d'administrations?

# %%
# Test avec "Has active ingredient"
df_rel.loc[df_rel.sourceId == 127489000]
# Out:
#                  id  effectiveTime  active            moduleId   sourceId  \
# 158878    162463023       20040731       0  900000000000207008  127489000
# 1332938  2543485027       20180131       0  900000000000012004  127489000
# 2674817  9068005028       20180131       1  900000000000012004  127489000
#
#          destinationId  relationshipGroup     typeId  characteristicTypeId  \
# 158878       106237007                  0  116680003    900000000000011006
# 1332938      410662002                  0  116680003    900000000000011006
# 2674817      762951001                  0  116680003    900000000000011006
#
#                  modifierId
# 158878   900000000000451002
# 1332938  900000000000451002
# 2674817  900000000000451002

# %%
df_rel.loc[df_rel.destinationId == 127489000]
# Out:
#                  id  effectiveTime  active            moduleId   sourceId  \
# 2675013  9068210024       20180131       1  900000000000012004  762949000
#
#          destinationId  relationshipGroup     typeId  characteristicTypeId  \
# 2675013      127489000                  0  116680003    900000000000011006
#
#                  modifierId
# 2675013  900000000000451002

# %%
df_description.loc[df_description.conceptId == 106237007]
# Out:
#                 id  effectiveTime  active            moduleId  conceptId  \
# 162869   170667013       20170731       1  900000000000012004  106237007
# 562210   579195011       20190131       0  900000000000012004  106237007
# 982215  2545280012       20170731       1  900000000000012004  106237007
#
#        languageCode              typeId                               term  \
# 162869           en  900000000000013009                    Linkage concept
# 562210           en  900000000000003001        Linkage concept (attribute)
# 982215           en  900000000000003001  Linkage concept (linkage concept)
#
#         caseSignificanceId
# 162869  900000000000448009
# 562210  900000000000020002
# 982215  900000000000448009

# %%
df_description.loc[df_description.conceptId == 762949000]
# Out:
#                  id  effectiveTime  active            moduleId  conceptId  \
# 1361425  3635990014       20180131       1  900000000000012004  762949000
# 1361426  3635991013       20180131       1  900000000000012004  762949000
#
#         languageCode              typeId  \
# 1361425           en  900000000000013009
# 1361426           en  900000000000003001
#
#                                               term  caseSignificanceId
# 1361425              Has precise active ingredient  900000000000448009
# 1361426  Has precise active ingredient (attribute)  900000000000448009

# %%
import pandas as pd
df_stated_rel = pd.read_csv('Snapshot/Terminology/sct2_StatedRelationship_Snapshot_INT_20220731.txt',sep='\t')

# %%
df_stated_rel.loc[df_stated_rel.sourceId == 127489000]
# Out:
#                 id  effectiveTime  active            moduleId   sourceId  \
# 133188  3971857022       20180131       0  900000000000012004  127489000
# 872910  7981526029       20190731       0  900000000000012004  127489000
#
#         destinationId  relationshipGroup     typeId  characteristicTypeId  \
# 133188      410662002                  0  116680003    900000000000010007
# 872910      762951001                  0  116680003    900000000000010007
#
#                 modifierId
# 133188  900000000000451002
# 872910  900000000000451002

# %%
df_stated_rel.loc[df_stated_rel.destinationId == 127489000]
# Out:
#                 id  effectiveTime  active            moduleId   sourceId  \
# 872908  7981521023       20190731       0  900000000000012004  762949000
#
#         destinationId  relationshipGroup     typeId  characteristicTypeId  \
# 872908      127489000                  0  116680003    900000000000010007
#
#                 modifierId
# 872908  900000000000451002

# %%
df_description.loc[df_description.conceptId == 410662002]
# Out:
#                 id  effectiveTime  active            moduleId  conceptId  \
# 959870  2466114012       20170731       1  900000000000012004  410662002
# 966057  2472316017       20170731       1  900000000000012004  410662002
#
#        languageCode              typeId                                 term  \
# 959870           en  900000000000003001  Concept model attribute (attribute)
# 966057           en  900000000000013009              Concept model attribute
#
#         caseSignificanceId
# 959870  900000000000448009
# 966057  900000000000448009

# %%
df_description.loc[df_description.conceptId == 762951001]
# Out:
#                  id  effectiveTime  active            moduleId  conceptId  \
# 1361427  3635994017       20180131       1  900000000000012004  762951001
# 1361428  3635995016       20180131       1  900000000000012004  762951001
#
#         languageCode              typeId                        term  \
# 1361427           en  900000000000003001  Has ingredient (attribute)
# 1361428           en  900000000000013009              Has ingredient
#
#          caseSignificanceId
# 1361427  900000000000448009
# 1361428  900000000000448009

# %%
'''
Regarder SNOMED ontologie et recuperer:
- Dose Form Intended Site
- Substance
- Pharmaceutical Dose Form

- Utilise ELK raisonneur sous Maven (regarde par Slack)

Remettre le docker ocrxfact a jour.
'''
