# %%
# !mkdir data

# %%
import os
queries = ['IN', 'PIN', 'DF','SCD','SCDC']
for query in queries:
    os.system(f'wget "http://localhost:8080/SnomedDLQuery?message={query}" -O "data/{query}.json"')

# %%
import json
import os
import ast
import pandas as pd

def load_wget_results():
    def helper(filename):
        fullpath = f"data/{filename}"
        with open(fullpath,"r") as f:
            content = f.read()[1:-1]
#             import ipdb; ipdb.set_trace()
            obj = ast.literal_eval(content)
            return pd.DataFrame(obj)
    return {filename: helper(filename) for filename in os.listdir("data") if filename.endswith(".json")}

# %%
dfs = load_wget_results()

# %%
dfs['ALL_IN.json'] = pd.concat([dfs['IN.json'],dfs['PIN.json']])

# %%
for df in dfs.values():
    df.columns = ['iri', 'prefLabel']

# %%
dfs['DF.json']
# Out:
#                 iri            prefLabel
# 0     RxNorm#316982        Topical Cream
# 1     RxNorm#316983       Topical Lotion
# 2    RxNorm#2284289     Inhalation Spray
# 3     RxNorm#316984          Topical Oil
# 4     RxNorm#317678                Enema
# ..              ...                  ...
# 118    RxNorm#10652           Toothpaste
# 119   RxNorm#858080          Buccal Film
# 120    RxNorm#11107         Vaginal Foam
# 121     RxNorm#7670  Ophthalmic Solution
# 122    RxNorm#11108          Vaginal Gel
#
# [123 rows x 2 columns]

# %%
def clean_df(df):
    new_df = df[['iri','prefLabel']].copy()
    new_df['prefLabel'] = new_df['prefLabel'].str.upper()
    new_df.columns = ['rxnorm_code','rxnorm_label']
    return new_df.dropna().drop_duplicates().sort_values('rxnorm_label')

# def clean_form_snomed(raw_form_df):
#     mapping = {
#         "EYE" : "OPHTALMIC",
#         "EAR" : "OTIC",
#         "NOSE" : "NASAL"
#     }
#     def sub_form_snomed_helper(form):
#         return ' '.join([mapping.get(el,el) for el in form.split(" ")])
#     form_df = raw_form_df.copy()
#     form_df['old_snomed_label'] = form_df['snomed_label'].copy()
#     form_df['snomed_label'] = [sub_form_snomed_helper(el.replace(" DOSE FORM","")) for el in form_df['old_snomed_label'].values]
#     return form_df

def clean_form_ocrx(raw_form_df):
    def clean_form_ocrx_helper(el):
        # removes the word in and inverts it
        if " IN " in el:
            splitted = el.split(" IN ")
            if len(splitted) > 2:
                import ipdb; ipdb.st_trace()
            start, last = splitted[:2]
            return last + " " + start
        else:
            return el
            
    form_df = raw_form_df.copy()
#     import ipdb; ipdb.set_trace()
    form_df['old_ocrx_label'] = form_df['ocrx_label'].copy()
    form_df['ocrx_label'] = [clean_form_ocrx_helper(el) for el in form_df['old_ocrx_label'].values]
    return form_df

# %%
clean_dfs = {key: clean_df(df) for key, df in dfs.items()}

# %%
clean_dfs['ALL_IN.json']
# Out:
#           rxnorm_code                                       rxnorm_label
# 13068  RxNorm#1801150  (((1-METHYL-2-(5-METHYL-3-OXAZOLIDINYL)ETHOXY)...
# 11064  RxNorm#1599828  ((2S,3S,5S)-2-(2-(2,6-DIMETHYLPHENOXY)ACETAMID...
# 13682  RxNorm#2599921  ((4-HYDROXYBUTYL)AZANEDIYL)BIS(HEXANE-6,1-DIYL...
# 8894   RxNorm#2557381                                      (-)-AMBROXIDE
# 2827   RxNorm#2262004                            (1,1-DIMETHYLETHYL)UREA
# ...               ...                                                ...
# 4967   RxNorm#1649134                                   ZUCCHINI EXTRACT
# 5902    RxNorm#114176                                     ZUCLOPENTHIXOL
# 347      RxNorm#58338                             ZUCLOPENTHIXOL ACETATE
# 349      RxNorm#58339                           ZUCLOPENTHIXOL DECANOATE
# 626     RxNorm#102546                     ZUCLOPENTHIXOL DIHYDROCHLORIDE
#
# [17312 rows x 2 columns]

# %%
clean_dfs['DF.json']['rxnorm_label'].values
# Out:
# array(['AUTO-INJECTOR', 'BUCCAL FILM', 'BUCCAL TABLET', 'CARTRIDGE',
#        'CHEWABLE EXTENDED RELEASE ORAL TABLET', 'CHEWABLE TABLET',
#        'CHEWING GUM', 'DELAYED RELEASE ORAL CAPSULE',
#        'DELAYED RELEASE ORAL GRANULES', 'DELAYED RELEASE ORAL TABLET',
#        'DISINTEGRATING ORAL TABLET', 'DOUCHE', 'DRUG IMPLANT',
#        'DRUG-ELUTING CONTACT LENS', 'DRY POWDER INHALER',
#        'EFFERVESCENT ORAL TABLET', 'ENEMA',
#        'EXTENDED RELEASE ORAL CAPSULE', 'EXTENDED RELEASE ORAL TABLET',
#        'EXTENDED RELEASE SUSPENSION', 'GAS FOR INHALATION',
#        'GRANULES FOR ORAL SOLUTION', 'GRANULES FOR ORAL SUSPENSION',
#        'INHALATION POWDER', 'INHALATION SOLUTION', 'INHALATION SPRAY',
#        'INHALATION SUSPENSION', 'INJECTABLE FOAM', 'INJECTABLE SOLUTION',
#        'INJECTABLE SUSPENSION', 'INJECTION', 'INTRAPERITONEAL SOLUTION',
#        'INTRATRACHEAL SUSPENSION', 'INTRAUTERINE SYSTEM',
#        'IRRIGATION SOLUTION', 'JET INJECTOR', 'MEDICATED BAR SOAP',
#        'MEDICATED LIQUID SOAP', 'MEDICATED PAD', 'MEDICATED PATCH',
#        'MEDICATED SHAMPOO', 'MEDICATED TAPE', 'METERED DOSE INHALER',
#        'METERED DOSE NASAL SPRAY', 'MOUTHWASH', 'MUCOSAL SPRAY',
#        'MUCOUS MEMBRANE TOPICAL SOLUTION', 'NASAL GEL', 'NASAL INHALANT',
#        'NASAL OINTMENT', 'NASAL POWDER', 'NASAL SOLUTION', 'NASAL SPRAY',
#        'OPHTHALMIC CREAM', 'OPHTHALMIC GEL',
#        'OPHTHALMIC IRRIGATION SOLUTION', 'OPHTHALMIC OINTMENT',
#        'OPHTHALMIC SOLUTION', 'OPHTHALMIC SUSPENSION', 'ORAL CAPSULE',
#        'ORAL CREAM', 'ORAL FILM', 'ORAL FLAKES', 'ORAL FOAM', 'ORAL GEL',
#        'ORAL GRANULES', 'ORAL LOZENGE', 'ORAL OINTMENT', 'ORAL PASTE',
#        'ORAL PELLET', 'ORAL POWDER', 'ORAL SOLUTION', 'ORAL SPRAY',
#        'ORAL SUSPENSION', 'ORAL TABLET', 'ORAL WAFER', 'OTIC OINTMENT',
#        'OTIC SOLUTION', 'OTIC SUSPENSION', 'PACK', 'PASTE',
#        'PEN INJECTOR', 'POWDER FOR NASAL SOLUTION',
#        'POWDER FOR ORAL SOLUTION', 'POWDER FOR ORAL SUSPENSION',
#        'POWDER FOR PYELOCALYCEAL SOLUTION', 'POWDER SPRAY',
#        'PREFILLED SYRINGE', 'RECTAL CREAM', 'RECTAL FOAM', 'RECTAL GEL',
#        'RECTAL OINTMENT', 'RECTAL SOLUTION', 'RECTAL SPRAY',
#        'RECTAL SUPPOSITORY', 'SUBLINGUAL FILM', 'SUBLINGUAL POWDER',
#        'SUBLINGUAL TABLET', 'SUSTAINED RELEASE BUCCAL TABLET',
#        'TABLET FOR ORAL SUSPENSION', 'TOOTHPASTE', 'TOPICAL CREAM',
#        'TOPICAL FOAM', 'TOPICAL GEL', 'TOPICAL LIQUEFIED GAS',
#        'TOPICAL LOTION', 'TOPICAL OIL', 'TOPICAL OINTMENT',
#        'TOPICAL POWDER', 'TOPICAL SOLUTION', 'TOPICAL SPRAY',
#        'TOPICAL SUSPENSION', 'TRANSDERMAL SYSTEM', 'URETHRAL SUPPOSITORY',
#        'VAGINAL CREAM', 'VAGINAL FILM', 'VAGINAL FOAM', 'VAGINAL GEL',
#        'VAGINAL INSERT', 'VAGINAL OINTMENT', 'VAGINAL SPONGE',
#        'VAGINAL SYSTEM'], dtype=object)

# %%
#For active ingredients:

# %%
def gather_ocrx_medical_term(medical_term):
    df = pd.read_csv(f"/home/james/Datasets/ocrx-owls/match-ocrx/match_{medical_term}_en.csv")
    df = df.drop_duplicates().sort_values("sLabel")
    labels = df['sLabel'].str.upper().values
    codes = df['s'].values
    return [(str(val),str(val_code)) for val, val_code in zip(labels,codes)]

def parse_dosage(dose):
    splitted = dose.split(" ")
    unit = splitted[-1]
    if unit in units_conversion:
        pass
# print('\n'.join([str(el) for el in df_compo['dose'].unique()]))
ocrx_terms = ['form','roa','substance']
ocrx_dfs = [gather_ocrx_medical_term(term) for term in ocrx_terms]

def convert_ocrx_to_df(ocrx_elems):
    return [pd.DataFrame(ocrx_df,columns=['ocrx_label','ocrx_code']) for ocrx_df in ocrx_elems]

ocrx_dfs = convert_ocrx_to_df(ocrx_dfs)
ocrx_dfs[0] = clean_form_ocrx(ocrx_dfs[0])
ocrx_form_df, ocrx_roa_df, ocrx_substance_df = ocrx_dfs

from pytrie import Trie
def make_trie(df):
    code_col, label_col = df.columns
    return {row[label_col]: row[code_col] for _, row in df.iterrows()}

# def make_trie_ansm(ansm_def_df):
#     return {row['snomed_label']: row['snomed_code'] for _, row in ansm_def_df.iterrows()}

def get_prefix(trie,term):
    words = term.split(' ')
    for i in reversed(range(1,len(words)+1)):
        term = ' '.join(words[:i])
        if term in trie:
            return (term, trie[term])
    return None


# snomed_dfs = [clean_form_snomed(clean_dfs['form.json']),clean_dfs['roa.json'],clean_dfs['substances.json']]
# ocrx_form_trie,ocrx_roa_trie,ocrx_substance_trie = [make_trie(el) for el in ocrx_dfs]
# snomed_tries = [make_trie_ansm(el) for el in snomed_dfs]

# %%
import os
DIR = 'match-ocrx-full'
def print_stats(df_merged,type_fn,name='rxnorm'):
    # total_match
    prefix_code = f"{name}_code"
    print("TOTAL MATCH:")
    total_df = df_merged.dropna()
    print(total_df.head())
    print(total_df.shape)
    total_df.to_csv(f"{DIR}/match_{type_fn}_total_match.csv")
    # left missing
    print("ONLY OCRX")
    only_ocrx = df_merged.loc[df_merged[prefix_code].isna()]
    print(only_ocrx.head())
    print(only_ocrx.shape)
    only_ocrx.to_csv(f"{DIR}/match_{type_fn}_only_ocrx.csv")
    # right missing
    print(f"ONLY {name.upper()}")
    only_ansm = df_merged.loc[df_merged['ocrx_code'].isna()]
    print(only_ansm.head())
    print(only_ansm.shape)
    stats = {'total' : total_df.shape[0], 'ocrx' : only_ocrx.shape[0], name : only_ansm.shape[0]}
    only_ansm.to_csv(f"{DIR}/match_{type_fn}_only_{name}.csv")
    return stats

def perform_alignment(df1,df2,fn):
    all_stats = dict()
    trie1 = make_trie(df1)
    trie2 = make_trie(df2)
    fullpath = f"{DIR}/match_{fn}.csv"
    df_merged = pd.merge(df1,df2,how="outer",left_on=['ocrx_label'], right_on=['rxnorm_label'])
#     import ipdb; ipdb.set_trace()
    df_merged_with_prefix = add_prefixes(df_merged,trie1,trie2)
    all_stats[fn] = print_stats(df_merged_with_prefix,fn)
    df_merged_with_prefix.to_csv(fullpath)
    return all_stats

def add_prefixes(df,trie,trie_ansm,prefix='rxnorm'):
    prefix_code = f"{prefix}_code"
    prefix_label = f"{prefix}_label"
    def process_row(row,trie):
        if type(row['ocrx_code']) == str and type(row[prefix_code]) == str:
            return (row['ocrx_code'], row['ocrx_label'], 'EXACT')
        elif str(row['ocrx_code']) == 'nan':
            result = get_prefix(trie,row[prefix_label])
            if result is None:
                return (None, None, 'NONE')
            else:
                prefix_ocrx, ocrx_code = result
                return (ocrx_code, prefix_ocrx, 'PREFIX')
        else:
            return (row['ocrx_code'], row['ocrx_label'], 'NA')
    def process_row_ansm(row,trie):
        if type(row['ocrx_code']) == str and type(row[prefix_code]) == str:
            return (row[prefix_code], row[prefix_label], 'EXACT')
        elif str(row[prefix_code]) == 'nan':
            result = get_prefix(trie,row['ocrx_label'])
            if result is None:
                return (None, None, 'NONE')
            else:
                prefix_ansm, ansm_code = result
                return (ansm_code, prefix_ansm, 'PREFIX')
        else:
            return (row[prefix_code], row[prefix_label], 'NA')
        
            
#     import ipdb; ipdb.set_trace()
    els = ['ocrx','snomed']
    new_df = df.copy()
    for el, trie_el, process_fn in zip(els,[trie,trie_ansm],[process_row,process_row_ansm]):
        results = [process_fn(row,trie_el) for _, row in df.iterrows()]
        codes = [result[0] for result in results]
        full_terms = [result[1] for result in results]
        match_types = [result[2] for result in results]
        new_df[f'{el}_code'] = codes
        new_df[f'{el}_label'] = full_terms
        new_df[f'{el}_match_type'] = match_types
    return new_df

# filenames = ['form','roa','substance']
# if not os.path.exists(DIR):
#     os.mkdir(DIR)
# ocrxs = [ocrx_form_df,ocrx_roa_df,ocrx_substance_df]
# # ansms = [bdpm_form_df,bdpm_roa_df,bdpm_substance_df]
# others = snomed_dfs
# others_tries = snomed_tries
# tries = [ocrx_form_trie,ocrx_roa_trie,ocrx_substance_trie]
# all_stats = dict()
# for ocrx, ansm, filename, trie, trie_ansm in zip(ocrxs,others,filenames,tries,others_tries):
#     fullpath = f"{DIR}/match_{filename}.csv"
#     df_merged = pd.merge(ocrx,ansm,how="outer",left_on=['ocrx_label'], right_on=['snomed_label'])
# #     import ipdb; ipdb.set_trace()
#     df_merged_with_prefix = add_prefixes(df_merged,trie,trie_ansm)
#     all_stats[filename] = print_stats(df_merged_with_prefix,filename)
#     df_merged_with_prefix.to_csv(fullpath)

# %%
# !mkdir match-ocrx-full
# Out:
# mkdir: cannot create directory ‘match-ocrx-full’: File exists

# %%
substance_match = (ocrx_substance_df,clean_dfs['ALL_IN.json'],'substance')
substance_stats = perform_alignment(*substance_match)
# Out:
# TOTAL MATCH:
#                                     ocrx_label  \
# 103509                       1-ALPHA-VITAMIN D
# 113844                              1-PROPANOL
# 160593                          2-PHENYLPHENOL
# 211334                    4-PHENYLBUTYRIC ACID
# 219939  5-CHLORO-2-METHYL-4-ISOTHIAZOLIN-3-ONE
#
#                                  ocrx_code     rxnorm_code  \
# 103509  http://www.ocrx.ca/OCRx/3000004084   RxNorm#350465
# 113844  http://www.ocrx.ca/OCRx/3000000930  RxNorm#1362872
# 160593  http://www.ocrx.ca/OCRx/3000000039   RxNorm#236677
# 211334  http://www.ocrx.ca/OCRx/3100005151  RxNorm#1546447
# 219939  http://www.ocrx.ca/OCRx/3000004417  RxNorm#1367119
#
#                                   rxnorm_label ocrx_match_type  \
# 103509                       1-ALPHA-VITAMIN D           EXACT
# 113844                              1-PROPANOL           EXACT
# 160593                          2-PHENYLPHENOL           EXACT
# 211334                    4-PHENYLBUTYRIC ACID           EXACT
# 219939  5-CHLORO-2-METHYL-4-ISOTHIAZOLIN-3-ONE           EXACT
#
#            snomed_code                            snomed_label  \
# 103509   RxNorm#350465                       1-ALPHA-VITAMIN D
# 113844  RxNorm#1362872                              1-PROPANOL
# 160593   RxNorm#236677                          2-PHENYLPHENOL
# 211334  RxNorm#1546447                    4-PHENYLBUTYRIC ACID
# 219939  RxNorm#1367119  5-CHLORO-2-METHYL-4-ISOTHIAZOLIN-3-ONE
#
#        snomed_match_type
# 103509             EXACT
# 113844             EXACT
# 160593             EXACT
# 211334             EXACT
# 219939             EXACT
# (3603, 8)
# ONLY OCRX
#                                           ocrx_label  \
# 0  ((((3-BROMOMESITYL)CARBAMOYL)METHYL)IMINO)DIAC...
# 1  ((((3-BROMOMESITYL)CARBAMOYL)METHYL)IMINO)DIAC...
# 2  ((((3-BROMOMESITYL)CARBAMOYL)METHYL)IMINO)DIAC...
# 3  ((((3-BROMOMESITYL)CARBAMOYL)METHYL)IMINO)DIAC...
# 4  ((((3-BROMOMESITYL)CARBAMOYL)METHYL)IMINO)DIAC...
#
#                             ocrx_code rxnorm_code rxnorm_label  \
# 0  http://www.ocrx.ca/OCRx/3000004317         NaN          NaN
# 1  http://www.ocrx.ca/OCRx/2000020448         NaN          NaN
# 2  http://www.ocrx.ca/OCRx/2000020448         NaN          NaN
# 3  http://www.ocrx.ca/OCRx/2000020448         NaN          NaN
# 4  http://www.ocrx.ca/OCRx/2000020448         NaN          NaN
#
#   ocrx_match_type snomed_code snomed_label snomed_match_type
# 0              NA        None         None              NONE
# 1              NA        None         None              NONE
# 2              NA        None         None              NONE
# 3              NA        None         None              NONE
# 4              NA        None         None              NONE
# (2826036, 8)
# ONLY RXNORM
#         ocrx_label ocrx_code     rxnorm_code  \
# 2829639       None      None  RxNorm#1801150
# 2829640       None      None  RxNorm#1599828
# 2829641       None      None  RxNorm#2599921
# 2829642       None      None  RxNorm#2557381
# 2829643       None      None  RxNorm#2262004
#
#                                               rxnorm_label ocrx_match_type  \
# 2829639  (((1-METHYL-2-(5-METHYL-3-OXAZOLIDINYL)ETHOXY)...            NONE
# 2829640  ((2S,3S,5S)-2-(2-(2,6-DIMETHYLPHENOXY)ACETAMID...            NONE
# 2829641  ((4-HYDROXYBUTYL)AZANEDIYL)BIS(HEXANE-6,1-DIYL...            NONE
# 2829642                                      (-)-AMBROXIDE            NONE
# 2829643                            (1,1-DIMETHYLETHYL)UREA            NONE
#
#             snomed_code                                       snomed_label  \
# 2829639  RxNorm#1801150  (((1-METHYL-2-(5-METHYL-3-OXAZOLIDINYL)ETHOXY)...
# 2829640  RxNorm#1599828  ((2S,3S,5S)-2-(2-(2,6-DIMETHYLPHENOXY)ACETAMID...
# 2829641  RxNorm#2599921  ((4-HYDROXYBUTYL)AZANEDIYL)BIS(HEXANE-6,1-DIYL...
# 2829642  RxNorm#2557381                                      (-)-AMBROXIDE
# 2829643  RxNorm#2262004                            (1,1-DIMETHYLETHYL)UREA
#
#         snomed_match_type
# 2829639                NA
# 2829640                NA
# 2829641                NA
# 2829642                NA
# 2829643                NA
# (13715, 8)

# %%
ocrx_form_word_set = set(ocrx_form_df['ocrx_label'].values)

# %%
ocrx_roa_word_set = set(ocrx_roa_df['ocrx_label'].values)

# %%
list(range(5,3,-1))
# Out:
# [5, 4]

# %%
dose_forms = clean_dfs['DF.json']
def split_form_roa(text,form_set=ocrx_form_word_set,roa_set=ocrx_roa_word_set):
    words = text.split(" ")
    form, roa = None, None
    word_len = len(words)
    term = None
    found = 0
    for window_size in range(word_len,0,-1):
        for i in range(word_len-window_size+1):
            word = ' '.join(words[i:i+window_size])
            if word in roa_set:
                term = word
                found = 2
                break
            
        if found != 0:
            break
    if found == 0:
        for window_size in range(word_len,0,-1):
            for i in range(word_len-window_size+1):
                word = ' '.join(words[i:i+window_size])
                if word in form_set:
                    term = word
                    found = 1
                    break

            if found != 0:
                break
                
    if found == 0:
        return None, None, None
    other_term = ' '.join([word for word in words if word != term])
    form, roa = (term, other_term) if found == 1 else (other_term, term)
    splitted_form = form.split(' ')
    if splitted_form[-1] in form_set and splitted_form[0] not in form_set and len(splitted_form) > 1:
        rest = ' '.join(splitted_form[:-1])
        form = splitted_form[-1] + ' ' + f'({rest})'
    if form.endswith(" FOR"):
        form = ' '.join(form.split(' ')[:-1])
    if roa.startswith("FOR "):
        roa = ' '.join(roa.split(' ')[1:])
    if form not in form_set and len(form.split(' ')) == 1:
        return None, roa, form
    print(f"Term:{text}\tForm:{form}\tRoa:{roa}")
    return form, roa, None

def create_form_roa(df):
    splitted = [split_form_roa(term) for term in df['rxnorm_label'].values]
    forms = [el[0] for el in splitted]
    roas = [el[1] for el in splitted]
    guessed_forms = [el[2] for el in splitted]
    df['form'] = forms
    df['roa'] = roas
    df['guessed_form'] = guessed_forms
    return df

# %%
split_form_roa('ORAL TABLET')
# Out:
# Term:ORAL TABLET	Form:TABLET	Roa:ORAL
# ('TABLET', 'ORAL', None)

# %%
'ORAL TABLET' in ocrx_form_word_set
# Out:
# True

# %%
create_form_roa(dose_forms)
# Out:
# Term:BUCCAL TABLET	Form:TABLET	Roa:BUCCAL
# Term:CHEWABLE EXTENDED RELEASE ORAL TABLET	Form:TABLET (CHEWABLE EXTENDED RELEASE)	Roa:ORAL
# Term:CHEWABLE TABLET	Form:TABLET	Roa:CHEWABLE
# Term:CHEWING GUM	Form:GUM	Roa:CHEWING
# Term:DELAYED RELEASE ORAL CAPSULE	Form:CAPSULE (DELAYED RELEASE)	Roa:ORAL
# Term:DELAYED RELEASE ORAL GRANULES	Form:GRANULES (DELAYED RELEASE)	Roa:ORAL
# Term:DELAYED RELEASE ORAL TABLET	Form:TABLET (DELAYED RELEASE)	Roa:ORAL
# Term:DISINTEGRATING ORAL TABLET	Form:TABLET (DISINTEGRATING)	Roa:ORAL
# Term:DOUCHE	Form:DOUCHE	Roa:
# Term:DRY POWDER INHALER	Form:POWDER	Roa:DRY INHALER
# Term:EFFERVESCENT ORAL TABLET	Form:TABLET (EFFERVESCENT)	Roa:ORAL
# Term:ENEMA	Form:ENEMA	Roa:
# Term:EXTENDED RELEASE ORAL CAPSULE	Form:CAPSULE (EXTENDED RELEASE)	Roa:ORAL
# Term:EXTENDED RELEASE ORAL TABLET	Form:TABLET (EXTENDED RELEASE)	Roa:ORAL
# Term:EXTENDED RELEASE SUSPENSION	Form:SUSPENSION	Roa:EXTENDED RELEASE
# Term:GAS FOR INHALATION	Form:GAS	Roa:INHALATION
# Term:GRANULES FOR ORAL SOLUTION	Form:GRANULES FOR SOLUTION	Roa:ORAL
# Term:GRANULES FOR ORAL SUSPENSION	Form:GRANULES FOR SUSPENSION	Roa:ORAL
# Term:INHALATION POWDER	Form:POWDER	Roa:INHALATION
# Term:INHALATION SOLUTION	Form:SOLUTION	Roa:INHALATION
# Term:INHALATION SPRAY	Form:SPRAY	Roa:INHALATION
# Term:INHALATION SUSPENSION	Form:SUSPENSION	Roa:INHALATION
# Term:INJECTABLE FOAM	Form:FOAM	Roa:INJECTABLE
# Term:INJECTABLE SOLUTION	Form:SOLUTION	Roa:INJECTABLE
# Term:INJECTABLE SUSPENSION	Form:SUSPENSION	Roa:INJECTABLE
# Term:INTRAPERITONEAL SOLUTION	Form:SOLUTION	Roa:INTRAPERITONEAL
# Term:INTRATRACHEAL SUSPENSION	Form:SUSPENSION	Roa:INTRATRACHEAL
# Term:IRRIGATION SOLUTION	Form:SOLUTION	Roa:IRRIGATION
# Term:MEDICATED BAR SOAP	Form:BAR	Roa:MEDICATED SOAP
# Term:MEDICATED LIQUID SOAP	Form:LIQUID	Roa:MEDICATED SOAP
# Term:MEDICATED PAD	Form:PAD	Roa:MEDICATED
# Term:MEDICATED PATCH	Form:PATCH	Roa:MEDICATED
# Term:MEDICATED SHAMPOO	Form:SHAMPOO	Roa:MEDICATED
# Term:MEDICATED TAPE	Form:TAPE	Roa:MEDICATED
# Term:METERED DOSE NASAL SPRAY	Form:SPRAY (METERED DOSE)	Roa:NASAL
# Term:MOUTHWASH	Form:MOUTHWASH	Roa:
# Term:MUCOSAL SPRAY	Form:SPRAY	Roa:MUCOSAL
# Term:MUCOUS MEMBRANE TOPICAL SOLUTION	Form:SOLUTION (MUCOUS MEMBRANE)	Roa:TOPICAL
# Term:NASAL GEL	Form:GEL	Roa:NASAL
# Term:NASAL OINTMENT	Form:OINTMENT	Roa:NASAL
# Term:NASAL POWDER	Form:POWDER	Roa:NASAL
# Term:NASAL SOLUTION	Form:SOLUTION	Roa:NASAL
# Term:NASAL SPRAY	Form:SPRAY	Roa:NASAL
# Term:OPHTHALMIC CREAM	Form:CREAM	Roa:OPHTHALMIC
# Term:OPHTHALMIC GEL	Form:GEL	Roa:OPHTHALMIC
# Term:OPHTHALMIC IRRIGATION SOLUTION	Form:SOLUTION (IRRIGATION)	Roa:OPHTHALMIC
# Term:OPHTHALMIC OINTMENT	Form:OINTMENT	Roa:OPHTHALMIC
# Term:OPHTHALMIC SOLUTION	Form:SOLUTION	Roa:OPHTHALMIC
# Term:OPHTHALMIC SUSPENSION	Form:SUSPENSION	Roa:OPHTHALMIC
# Term:ORAL CAPSULE	Form:CAPSULE	Roa:ORAL
# Term:ORAL CREAM	Form:CREAM	Roa:ORAL
# Term:ORAL FOAM	Form:FOAM	Roa:ORAL
# Term:ORAL GEL	Form:GEL	Roa:ORAL
# Term:ORAL GRANULES	Form:GRANULES	Roa:ORAL
# Term:ORAL LOZENGE	Form:LOZENGE	Roa:ORAL
# Term:ORAL OINTMENT	Form:OINTMENT	Roa:ORAL
# Term:ORAL PASTE	Form:PASTE	Roa:ORAL
# Term:ORAL PELLET	Form:PELLET	Roa:ORAL
# Term:ORAL POWDER	Form:POWDER	Roa:ORAL
# Term:ORAL SOLUTION	Form:SOLUTION	Roa:ORAL
# Term:ORAL SPRAY	Form:SPRAY	Roa:ORAL
# Term:ORAL SUSPENSION	Form:SUSPENSION	Roa:ORAL
# Term:ORAL TABLET	Form:TABLET	Roa:ORAL
# Term:ORAL WAFER	Form:WAFER	Roa:ORAL
# Term:OTIC OINTMENT	Form:OINTMENT	Roa:OTIC
# Term:OTIC SOLUTION	Form:SOLUTION	Roa:OTIC
# Term:OTIC SUSPENSION	Form:SUSPENSION	Roa:OTIC
# Term:PASTE	Form:PASTE	Roa:
# Term:POWDER FOR NASAL SOLUTION	Form:POWDER FOR SOLUTION	Roa:NASAL
# Term:POWDER FOR ORAL SOLUTION	Form:POWDER FOR SOLUTION	Roa:ORAL
# Term:POWDER FOR ORAL SUSPENSION	Form:POWDER FOR SUSPENSION	Roa:ORAL
# Term:POWDER FOR PYELOCALYCEAL SOLUTION	Form:POWDER	Roa:PYELOCALYCEAL SOLUTION
# Term:POWDER SPRAY	Form:POWDER	Roa:SPRAY
# Term:RECTAL CREAM	Form:CREAM	Roa:RECTAL
# Term:RECTAL FOAM	Form:FOAM	Roa:RECTAL
# Term:RECTAL GEL	Form:GEL	Roa:RECTAL
# Term:RECTAL OINTMENT	Form:OINTMENT	Roa:RECTAL
# Term:RECTAL SOLUTION	Form:SOLUTION	Roa:RECTAL
# Term:RECTAL SPRAY	Form:SPRAY	Roa:RECTAL
# Term:RECTAL SUPPOSITORY	Form:SUPPOSITORY	Roa:RECTAL
# Term:SUBLINGUAL POWDER	Form:POWDER	Roa:SUBLINGUAL
# Term:SUBLINGUAL TABLET	Form:TABLET	Roa:SUBLINGUAL
# Term:SUSTAINED RELEASE BUCCAL TABLET	Form:TABLET (SUSTAINED RELEASE)	Roa:BUCCAL
# Term:TABLET FOR ORAL SUSPENSION	Form:TABLET FOR SUSPENSION	Roa:ORAL
# Term:TOOTHPASTE	Form:TOOTHPASTE	Roa:
# Term:TOPICAL CREAM	Form:CREAM	Roa:TOPICAL
# Term:TOPICAL FOAM	Form:FOAM	Roa:TOPICAL
# Term:TOPICAL GEL	Form:GEL	Roa:TOPICAL
# Term:TOPICAL LIQUEFIED GAS	Form:GAS (LIQUEFIED)	Roa:TOPICAL
# Term:TOPICAL LOTION	Form:LOTION	Roa:TOPICAL
# Term:TOPICAL OIL	Form:OIL	Roa:TOPICAL
# Term:TOPICAL OINTMENT	Form:OINTMENT	Roa:TOPICAL
# Term:TOPICAL POWDER	Form:POWDER	Roa:TOPICAL
# Term:TOPICAL SOLUTION	Form:SOLUTION	Roa:TOPICAL
# Term:TOPICAL SPRAY	Form:SPRAY	Roa:TOPICAL
# Term:TOPICAL SUSPENSION	Form:SUSPENSION	Roa:TOPICAL
# Term:URETHRAL SUPPOSITORY	Form:SUPPOSITORY	Roa:URETHRAL
# Term:VAGINAL CREAM	Form:CREAM	Roa:VAGINAL
# Term:VAGINAL FOAM	Form:FOAM	Roa:VAGINAL
# Term:VAGINAL GEL	Form:GEL	Roa:VAGINAL
# Term:VAGINAL INSERT	Form:INSERT	Roa:VAGINAL
# Term:VAGINAL OINTMENT	Form:OINTMENT	Roa:VAGINAL
# Term:VAGINAL SPONGE	Form:SPONGE	Roa:VAGINAL
#         rxnorm_code                           rxnorm_label  \
# 54   RxNorm#1649570                          AUTO-INJECTOR
# 119   RxNorm#858080                            BUCCAL FILM
# 53    RxNorm#970789                          BUCCAL TABLET
# 55   RxNorm#1649572                              CARTRIDGE
# 47   RxNorm#2269573  CHEWABLE EXTENDED RELEASE ORAL TABLET
# ..              ...                                    ...
# 122    RxNorm#11108                            VAGINAL GEL
# 52   RxNorm#2107950                         VAGINAL INSERT
# 86    RxNorm#317010                       VAGINAL OINTMENT
# 61   RxNorm#2173190                         VAGINAL SPONGE
# 103  RxNorm#2199220                         VAGINAL SYSTEM
#
#                                    form      roa guessed_form
# 54                                 None     None         None
# 119                                None   BUCCAL         FILM
# 53                               TABLET   BUCCAL         None
# 55                                 None     None         None
# 47   TABLET (CHEWABLE EXTENDED RELEASE)     ORAL         None
# ..                                  ...      ...          ...
# 122                                 GEL  VAGINAL         None
# 52                               INSERT  VAGINAL         None
# 86                             OINTMENT  VAGINAL         None
# 61                               SPONGE  VAGINAL         None
# 103                                None  VAGINAL       SYSTEM
#
# [122 rows x 5 columns]

# %%
pd.set_option('display.max_rows', None)
dose_forms
# Out:
#         rxnorm_code                           rxnorm_label  \
# 54   RxNorm#1649570                          AUTO-INJECTOR
# 119   RxNorm#858080                            BUCCAL FILM
# 53    RxNorm#970789                          BUCCAL TABLET
# 55   RxNorm#1649572                              CARTRIDGE
# 47   RxNorm#2269573  CHEWABLE EXTENDED RELEASE ORAL TABLET
# 29     RxNorm#91058                        CHEWABLE TABLET
# 65    RxNorm#402499                            CHEWING GUM
# 13    RxNorm#316995           DELAYED RELEASE ORAL CAPSULE
# 12   RxNorm#2284290          DELAYED RELEASE ORAL GRANULES
# 83     RxNorm#10312            DELAYED RELEASE ORAL TABLET
# 80    RxNorm#316942             DISINTEGRATING ORAL TABLET
# 66    RxNorm#479172                                 DOUCHE
# 60    RxNorm#657710                           DRUG IMPLANT
# 70   RxNorm#2603774              DRUG-ELUTING CONTACT LENS
# 46    RxNorm#744995                     DRY POWDER INHALER
# 113  RxNorm#1535727               EFFERVESCENT ORAL TABLET
# 4     RxNorm#317678                                  ENEMA
# 81    RxNorm#316943          EXTENDED RELEASE ORAL CAPSULE
# 82    RxNorm#316945           EXTENDED RELEASE ORAL TABLET
# 77    RxNorm#316946            EXTENDED RELEASE SUSPENSION
# 31    RxNorm#316999                     GAS FOR INHALATION
# 87   RxNorm#1540453             GRANULES FOR ORAL SOLUTION
# 92   RxNorm#1540454           GRANULES FOR ORAL SUSPENSION
# 75    RxNorm#317000                      INHALATION POWDER
# 43    RxNorm#346161                    INHALATION SOLUTION
# 2    RxNorm#2284289                       INHALATION SPRAY
# 76   RxNorm#2107948                  INHALATION SUSPENSION
# 10   RxNorm#1484929                        INJECTABLE FOAM
# 79    RxNorm#316949                    INJECTABLE SOLUTION
# 68    RxNorm#316950                  INJECTABLE SUSPENSION
# 50   RxNorm#1649574                              INJECTION
# 71    RxNorm#316951               INTRAPERITONEAL SOLUTION
# 102  RxNorm#1732876               INTRATRACHEAL SUSPENSION
# 73   RxNorm#1856271                    INTRAUTERINE SYSTEM
# 59    RxNorm#152903                    IRRIGATION SOLUTION
# 51   RxNorm#1649573                           JET INJECTOR
# 97    RxNorm#316954                     MEDICATED BAR SOAP
# 99    RxNorm#316955                  MEDICATED LIQUID SOAP
# 84    RxNorm#797271                          MEDICATED PAD
# 18   RxNorm#1792831                        MEDICATED PATCH
# 62    RxNorm#106332                      MEDICATED SHAMPOO
# 101   RxNorm#797685                         MEDICATED TAPE
# 30    RxNorm#721654                   METERED DOSE INHALER
# 27   RxNorm#1797831               METERED DOSE NASAL SPRAY
# 33      RxNorm#7067                              MOUTHWASH
# 40    RxNorm#346163                          MUCOSAL SPRAY
# 100   RxNorm#316956       MUCOUS MEMBRANE TOPICAL SOLUTION
# 88    RxNorm#316960                              NASAL GEL
# 95    RxNorm#316959                         NASAL INHALANT
# 89    RxNorm#316961                         NASAL OINTMENT
# 11   RxNorm#1739329                           NASAL POWDER
# 90    RxNorm#316962                         NASAL SOLUTION
# 44    RxNorm#126542                            NASAL SPRAY
# 105   RxNorm#317544                       OPHTHALMIC CREAM
# 91    RxNorm#316963                         OPHTHALMIC GEL
# 49    RxNorm#244286         OPHTHALMIC IRRIGATION SOLUTION
# 48     RxNorm#91344                    OPHTHALMIC OINTMENT
# 121     RxNorm#7670                    OPHTHALMIC SOLUTION
# 114   RxNorm#316964                  OPHTHALMIC SUSPENSION
# 115   RxNorm#316965                           ORAL CAPSULE
# 116   RxNorm#316966                             ORAL CREAM
# 45   RxNorm#2269575                              ORAL FILM
# 78    RxNorm#316947                            ORAL FLAKES
# 38    RxNorm#346284                              ORAL FOAM
# 32    RxNorm#346169                               ORAL GEL
# 22    RxNorm#317690                          ORAL GRANULES
# 14    RxNorm#316992                           ORAL LOZENGE
# 34    RxNorm#346288                          ORAL OINTMENT
# 25    RxNorm#346171                             ORAL PASTE
# 23    RxNorm#317691                            ORAL PELLET
# 35    RxNorm#346289                            ORAL POWDER
# 111   RxNorm#316968                          ORAL SOLUTION
# 41    RxNorm#346164                             ORAL SPRAY
# 112   RxNorm#316969                        ORAL SUSPENSION
# 109   RxNorm#317541                            ORAL TABLET
# 17    RxNorm#316989                             ORAL WAFER
# 106   RxNorm#316972                          OTIC OINTMENT
# 107   RxNorm#316973                          OTIC SOLUTION
# 108   RxNorm#316974                        OTIC SUSPENSION
# 96    RxNorm#746839                                   PACK
# 63    RxNorm#402496                                  PASTE
# 57   RxNorm#1649571                           PEN INJECTOR
# 85   RxNorm#1540452              POWDER FOR NASAL SOLUTION
# 93   RxNorm#1540455               POWDER FOR ORAL SOLUTION
# 94   RxNorm#1540456             POWDER FOR ORAL SUSPENSION
# 19   RxNorm#2375729      POWDER FOR PYELOCALYCEAL SOLUTION
# 67    RxNorm#317004                           POWDER SPRAY
# 28    RxNorm#721656                      PREFILLED SYRINGE
# 7     RxNorm#316975                           RECTAL CREAM
# 110   RxNorm#317542                            RECTAL FOAM
# 24    RxNorm#346170                             RECTAL GEL
# 69    RxNorm#317005                        RECTAL OINTMENT
# 72    RxNorm#317006                        RECTAL SOLUTION
# 8     RxNorm#316977                           RECTAL SPRAY
# 9     RxNorm#316978                     RECTAL SUPPOSITORY
# 39   RxNorm#2269578                        SUBLINGUAL FILM
# 56   RxNorm#1810682                      SUBLINGUAL POWDER
# 74    RxNorm#317007                      SUBLINGUAL TABLET
# 6     RxNorm#316980        SUSTAINED RELEASE BUCCAL TABLET
# 26   RxNorm#1861409             TABLET FOR ORAL SUSPENSION
# 118    RxNorm#10652                             TOOTHPASTE
# 0     RxNorm#316982                          TOPICAL CREAM
# 42    RxNorm#346285                           TOPICAL FOAM
# 37    RxNorm#346286                            TOPICAL GEL
# 58   RxNorm#1788820                  TOPICAL LIQUEFIED GAS
# 1     RxNorm#316983                         TOPICAL LOTION
# 3     RxNorm#316984                            TOPICAL OIL
# 5     RxNorm#316985                       TOPICAL OINTMENT
# 98    RxNorm#317009                         TOPICAL POWDER
# 15    RxNorm#316986                       TOPICAL SOLUTION
# 36    RxNorm#346165                          TOPICAL SPRAY
# 21   RxNorm#1649353                     TOPICAL SUSPENSION
# 16    RxNorm#316987                     TRANSDERMAL SYSTEM
# 104   RxNorm#317543                   URETHRAL SUPPOSITORY
# 117    RxNorm#11103                          VAGINAL CREAM
# 64   RxNorm#1788819                           VAGINAL FILM
# 120    RxNorm#11107                           VAGINAL FOAM
# 122    RxNorm#11108                            VAGINAL GEL
# 52   RxNorm#2107950                         VAGINAL INSERT
# 86    RxNorm#317010                       VAGINAL OINTMENT
# 61   RxNorm#2173190                         VAGINAL SPONGE
# 103  RxNorm#2199220                         VAGINAL SYSTEM
#
#                                    form                     roa guessed_form
# 54                                 None                    None         None
# 119                                None                  BUCCAL         FILM
# 53                               TABLET                  BUCCAL         None
# 55                                 None                    None         None
# 47   TABLET (CHEWABLE EXTENDED RELEASE)                    ORAL         None
# 29                               TABLET                CHEWABLE         None
# 65                                  GUM                 CHEWING         None
# 13            CAPSULE (DELAYED RELEASE)                    ORAL         None
# 12           GRANULES (DELAYED RELEASE)                    ORAL         None
# 83             TABLET (DELAYED RELEASE)                    ORAL         None
# 80              TABLET (DISINTEGRATING)                    ORAL         None
# 66                               DOUCHE                                 None
# 60                                 None                 IMPLANT         DRUG
# 70                                 None                    None         None
# 46                               POWDER             DRY INHALER         None
# 113               TABLET (EFFERVESCENT)                    ORAL         None
# 4                                 ENEMA                                 None
# 81           CAPSULE (EXTENDED RELEASE)                    ORAL         None
# 82            TABLET (EXTENDED RELEASE)                    ORAL         None
# 77                           SUSPENSION        EXTENDED RELEASE         None
# 31                                  GAS              INHALATION         None
# 87                GRANULES FOR SOLUTION                    ORAL         None
# 92              GRANULES FOR SUSPENSION                    ORAL         None
# 75                               POWDER              INHALATION         None
# 43                             SOLUTION              INHALATION         None
# 2                                 SPRAY              INHALATION         None
# 76                           SUSPENSION              INHALATION         None
# 10                                 FOAM              INJECTABLE         None
# 79                             SOLUTION              INJECTABLE         None
# 68                           SUSPENSION              INJECTABLE         None
# 50                                 None                    None         None
# 71                             SOLUTION         INTRAPERITONEAL         None
# 102                          SUSPENSION           INTRATRACHEAL         None
# 73                                 None            INTRAUTERINE       SYSTEM
# 59                             SOLUTION              IRRIGATION         None
# 51                                 None                    None         None
# 97                                  BAR          MEDICATED SOAP         None
# 99                               LIQUID          MEDICATED SOAP         None
# 84                                  PAD               MEDICATED         None
# 18                                PATCH               MEDICATED         None
# 62                              SHAMPOO               MEDICATED         None
# 101                                TAPE               MEDICATED         None
# 30                                 None                    None         None
# 27                 SPRAY (METERED DOSE)                   NASAL         None
# 33                            MOUTHWASH                                 None
# 40                                SPRAY                 MUCOSAL         None
# 100          SOLUTION (MUCOUS MEMBRANE)                 TOPICAL         None
# 88                                  GEL                   NASAL         None
# 95                                 None                   NASAL     INHALANT
# 89                             OINTMENT                   NASAL         None
# 11                               POWDER                   NASAL         None
# 90                             SOLUTION                   NASAL         None
# 44                                SPRAY                   NASAL         None
# 105                               CREAM              OPHTHALMIC         None
# 91                                  GEL              OPHTHALMIC         None
# 49                SOLUTION (IRRIGATION)              OPHTHALMIC         None
# 48                             OINTMENT              OPHTHALMIC         None
# 121                            SOLUTION              OPHTHALMIC         None
# 114                          SUSPENSION              OPHTHALMIC         None
# 115                             CAPSULE                    ORAL         None
# 116                               CREAM                    ORAL         None
# 45                                 None                    ORAL         FILM
# 78                                 None                    ORAL       FLAKES
# 38                                 FOAM                    ORAL         None
# 32                                  GEL                    ORAL         None
# 22                             GRANULES                    ORAL         None
# 14                              LOZENGE                    ORAL         None
# 34                             OINTMENT                    ORAL         None
# 25                                PASTE                    ORAL         None
# 23                               PELLET                    ORAL         None
# 35                               POWDER                    ORAL         None
# 111                            SOLUTION                    ORAL         None
# 41                                SPRAY                    ORAL         None
# 112                          SUSPENSION                    ORAL         None
# 109                              TABLET                    ORAL         None
# 17                                WAFER                    ORAL         None
# 106                            OINTMENT                    OTIC         None
# 107                            SOLUTION                    OTIC         None
# 108                          SUSPENSION                    OTIC         None
# 96                                 None                    None         None
# 63                                PASTE                                 None
# 57                                 None                    None         None
# 85                  POWDER FOR SOLUTION                   NASAL         None
# 93                  POWDER FOR SOLUTION                    ORAL         None
# 94                POWDER FOR SUSPENSION                    ORAL         None
# 19                               POWDER  PYELOCALYCEAL SOLUTION         None
# 67                               POWDER                   SPRAY         None
# 28                                 None                    None         None
# 7                                 CREAM                  RECTAL         None
# 110                                FOAM                  RECTAL         None
# 24                                  GEL                  RECTAL         None
# 69                             OINTMENT                  RECTAL         None
# 72                             SOLUTION                  RECTAL         None
# 8                                 SPRAY                  RECTAL         None
# 9                           SUPPOSITORY                  RECTAL         None
# 39                                 None              SUBLINGUAL         FILM
# 56                               POWDER              SUBLINGUAL         None
# 74                               TABLET              SUBLINGUAL         None
# 6            TABLET (SUSTAINED RELEASE)                  BUCCAL         None
# 26                TABLET FOR SUSPENSION                    ORAL         None
# 118                          TOOTHPASTE                                 None
# 0                                 CREAM                 TOPICAL         None
# 42                                 FOAM                 TOPICAL         None
# 37                                  GEL                 TOPICAL         None
# 58                      GAS (LIQUEFIED)                 TOPICAL         None
# 1                                LOTION                 TOPICAL         None
# 3                                   OIL                 TOPICAL         None
# 5                              OINTMENT                 TOPICAL         None
# 98                               POWDER                 TOPICAL         None
# 15                             SOLUTION                 TOPICAL         None
# 36                                SPRAY                 TOPICAL         None
# 21                           SUSPENSION                 TOPICAL         None
# 16                                 None             TRANSDERMAL       SYSTEM
# 104                         SUPPOSITORY                URETHRAL         None
# 117                               CREAM                 VAGINAL         None
# 64                                 None                 VAGINAL         FILM
# 120                                FOAM                 VAGINAL         None
# 122                                 GEL                 VAGINAL         None
# 52                               INSERT                 VAGINAL         None
# 86                             OINTMENT                 VAGINAL         None
# 61                               SPONGE                 VAGINAL         None
# 103                                None                 VAGINAL       SYSTEM

# %%
dose_forms.to_csv("dose_forms_parsed.csv")

# %%
rxnorm_form_df = pd.DataFrame([{"rxnorm_id" : i, "rxnorm_label" : term} for i, term in enumerate(set(list(dose_forms['form']) + list(dose_forms['guessed_form'].values))) if term != "" and term is not None])
rxnorm_roa_df = pd.DataFrame([{"rxnorm_id" : i, "rxnorm_label" : term} for i, term in enumerate(set(list(dose_forms['roa']))) if term != "" and term is not None])

# %%
rxnorm_roa_df
# Out:
#     rxnorm_id            rxnorm_label
# 0           1          MEDICATED SOAP
# 1           2                 CHEWING
# 2           3             DRY INHALER
# 3           4             TRANSDERMAL
# 4           5              OPHTHALMIC
# 5           6                   NASAL
# 6           7                 VAGINAL
# 7           8        EXTENDED RELEASE
# 8           9                  BUCCAL
# 9          10                 TOPICAL
# 10         11              INJECTABLE
# 11         12                    ORAL
# 12         13              INHALATION
# 13         14  PYELOCALYCEAL SOLUTION
# 14         15                CHEWABLE
# 15         16              IRRIGATION
# 16         17         INTRAPERITONEAL
# 17         18                  RECTAL
# 18         19                URETHRAL
# 19         20                 MUCOSAL
# 20         21                 IMPLANT
# 21         22                   SPRAY
# 22         23              SUBLINGUAL
# 23         24            INTRAUTERINE
# 24         25                    OTIC
# 25         26           INTRATRACHEAL
# 26         27               MEDICATED

# %%
rxnorm_form_df.columns = ['rxnorm_code','rxnorm_label']

# %%
rxnorm_roa_df.columns = ['rxnorm_code', 'rxnorm_label']

# %%
import os
if not os.path.exists("export"):
    os.mkdir("export")
def export_df(df,term):
    new_df = df.copy()
    new_df.columns = ['rxnorm_code','rxnorm_label']
    new_df = new_df.drop_duplicates().dropna().sort_values('rxnorm_label')
    new_df.to_csv(f'export/rxnorm_{term}_en.csv')
dfs['form.json'] = rxnorm_form_df
dfs['roa.json'] = rxnorm_roa_df

filenames = ['form.json','roa.json','SCD.json','SCDC.json','ALL_IN.json']
maps = ['form','roa','drug','component','active_ingredient']
for mapped_name, fn in zip(maps,filenames):
    export_df(dfs[fn],mapped_name)

# %%
# !nemo .

# %%
# !nemo .

# %%
ocrx_form_df, ocrx_roa_df = [df[['ocrx_code','ocrx_label']] for df in [ocrx_form_df,ocrx_roa_df]]
form_stats = perform_alignment(ocrx_form_df,rxnorm_form_df,'form')
roa_stats = perform_alignment(ocrx_roa_df,rxnorm_roa_df,'roa')
# Out:
# TOTAL MATCH:
#                               ocrx_code ocrx_label  rxnorm_code rxnorm_label  \
# 65   http://www.ocrx.ca/OCRx/4000000120        BAR         30.0          BAR
# 66   http://www.ocrx.ca/OCRx/4000000120        BAR         30.0          BAR
# 77   http://www.ocrx.ca/OCRx/4000000017    CAPSULE          3.0      CAPSULE
# 78   http://www.ocrx.ca/OCRx/4000000017    CAPSULE          3.0      CAPSULE
# 120  http://www.ocrx.ca/OCRx/4000000065      CREAM         34.0        CREAM
#
#     ocrx_match_type  snomed_code snomed_label snomed_match_type
# 65               NA         30.0          BAR                NA
# 66               NA         30.0          BAR                NA
# 77               NA          3.0      CAPSULE                NA
# 78               NA          3.0      CAPSULE                NA
# 120              NA         34.0        CREAM                NA
# (88, 8)
# ONLY OCRX
#                             ocrx_code                         ocrx_label  \
# 0  http://www.ocrx.ca/OCRx/4000000016                            AEROSOL
# 1  http://www.ocrx.ca/OCRx/4000000016                            AEROSOL
# 2  http://www.ocrx.ca/OCRx/4000000638      DENTAL AEROSOL (METERED DOSE)
# 3  http://www.ocrx.ca/OCRx/4000000638      DENTAL AEROSOL (METERED DOSE)
# 4  http://www.ocrx.ca/OCRx/4000000463  INHALATION AEROSOL (METERED DOSE)
#
#    rxnorm_code rxnorm_label ocrx_match_type  snomed_code snomed_label  \
# 0          NaN          NaN              NA          NaN         None
# 1          NaN          NaN              NA          NaN         None
# 2          NaN          NaN              NA          NaN         None
# 3          NaN          NaN              NA          NaN         None
# 4          NaN          NaN              NA          NaN         None
#
#   snomed_match_type
# 0              NONE
# 1              NONE
# 2              NONE
# 3              NONE
# 4              NONE
# (1715, 8)
# ONLY RXNORM
#      ocrx_code ocrx_label  rxnorm_code rxnorm_label ocrx_match_type  \
# 1792      None       None          9.0     INHALANT            NONE
# 1793      None       None         11.0       FLAKES            NONE
# 1799      None       None         25.0         FILM            NONE
# 1801      None       None         37.0       SYSTEM            NONE
# 1806      None       None         48.0         DRUG            NONE
#
#       snomed_code snomed_label snomed_match_type
# 1792          9.0     INHALANT                NA
# 1793         11.0       FLAKES                NA
# 1799         25.0         FILM                NA
# 1801         37.0       SYSTEM                NA
# 1806         48.0         DRUG                NA
# (5, 8)
# TOTAL MATCH:
#                              ocrx_code       ocrx_label  rxnorm_code  \
# 2   http://www.ocrx.ca/OCRx/4100000047           BUCCAL         11.0
# 17  http://www.ocrx.ca/OCRx/4100000025          IMPLANT          3.0
# 19  http://www.ocrx.ca/OCRx/4100000086       INHALATION         19.0
# 44  http://www.ocrx.ca/OCRx/4100000060  INTRAPERITONEAL         27.0
# 53  http://www.ocrx.ca/OCRx/4100000081    INTRATRACHEAL         22.0
#
#        rxnorm_label ocrx_match_type  snomed_code     snomed_label  \
# 2            BUCCAL              NA         11.0           BUCCAL
# 17          IMPLANT              NA          3.0          IMPLANT
# 19       INHALATION              NA         19.0       INHALATION
# 44  INTRAPERITONEAL              NA         27.0  INTRAPERITONEAL
# 53    INTRATRACHEAL              NA         22.0    INTRATRACHEAL
#
#    snomed_match_type
# 2                 NA
# 17                NA
# 19                NA
# 44                NA
# 53                NA
# (17, 8)
# ONLY OCRX
#                             ocrx_code          ocrx_label  rxnorm_code  \
# 0  http://www.ocrx.ca/OCRx/4100000037         ARTHOGRAPHY          NaN
# 1  http://www.ocrx.ca/OCRx/4100000043  BLOCK/INFILTRATION          NaN
# 3  http://www.ocrx.ca/OCRx/4100000022         CYSTOGRAPHY          NaN
# 4  http://www.ocrx.ca/OCRx/4100000072              DENTAL          NaN
# 5  http://www.ocrx.ca/OCRx/4100000041            DIALYSIS          NaN
#
#   rxnorm_label ocrx_match_type  snomed_code snomed_label snomed_match_type
# 0          NaN              NA          NaN         None              NONE
# 1          NaN              NA          NaN         None              NONE
# 3          NaN              NA          NaN         None              NONE
# 4          NaN              NA          NaN         None              NONE
# 5          NaN              NA          NaN         None              NONE
# (81, 8)
# ONLY RXNORM
#     ocrx_code ocrx_label  rxnorm_code      rxnorm_label ocrx_match_type  \
# 98       None       None          2.0           CHEWING            NONE
# 99       None       None          5.0             SPRAY            NONE
# 100      None       None         10.0  EXTENDED RELEASE            NONE
# 101      None       None         13.0       DRY INHALER            NONE
# 102      None       None         15.0        INJECTABLE            NONE
#
#      snomed_code      snomed_label snomed_match_type
# 98           2.0           CHEWING                NA
# 99           5.0             SPRAY                NA
# 100         10.0  EXTENDED RELEASE                NA
# 101         13.0       DRY INHALER                NA
# 102         15.0        INJECTABLE                NA
# (10, 8)

# %%
form_stats
# Out:
# {'form': {'total': 88, 'ocrx': 1715, 'rxnorm': 5}}

# %%
roa_stats
# Out:
# {'roa': {'total': 17, 'ocrx': 81, 'rxnorm': 10}}

# %%
all_stats = [substance_stats, form_stats, roa_stats]

# %%
all_dict = dict()
for stat in all_stats:
    for key, val in stat.items():
        all_dict[key] = val

# %%
pd.DataFrame([{'name' : key, **rest} for key, rest in all_dict.items()])
# Out:
#         name  total     ocrx  rxnorm
# 0  substance   3603  2826036   13715
# 1       form     88     1715       5
# 2        roa     17       81      10

# %%
# !alacritty
