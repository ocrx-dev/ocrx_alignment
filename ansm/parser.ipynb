# %% [markdown]
# `CIS_bdpm.txt`
# - Forme
# - Route d'administration
# - Code CIS
# - Nom du medicament
#
# `CIS_COMPO_bdpm.txt`
# - Code CIS
# - Ingredient Actif
# - Substance Active vs Fraction Therapeutique

# %%
import pandas as pd

# %%
columns_cis_bdpm = '''code_cis
denomination
form
roa
status_amm
type_amm
commercialisation_state
date_amm
statutbdm
num_authorization_eu
titulaire
surveillance'''.split('\n')
df_bdpm = pd.read_csv("CIS_bdpm.txt",names=columns_cis_bdpm,delimiter='\t',index_col=False)
df_bdpm
# Out:
#        code_cis                                       denomination  \
# 0      61266250                A 313 200 000 UI POUR CENT, pommade
# 1      62869109                   A 313 50 000 U.I., capsule molle
# 2      61876780  ABACAVIR ARROW 300 mg, comprimé pelliculé sécable
# 3      62401060  ABACAVIR MYLAN 300 mg, comprimé pelliculé sécable
# 4      63797011  ABACAVIR SANDOZ 300 mg, comprimé pelliculé séc...
# ...         ...                                                ...
# 15690  66425614                            ZYTIGA 250 mg, comprimé
# 15691  67337081                  ZYTIGA 500 mg, comprimé pelliculé
# 15692  63095061  ZYVOXID 100 mg/5 ml, granulés pour suspension ...
# 15693  63283095           ZYVOXID 2 mg/ml, solution pour perfusion
# 15694  68311278                 ZYVOXID 600 mg, comprimé pelliculé
#
#                                    form            roa           status_amm  \
# 0                               pommade        cutanée  Autorisation active
# 1                         capsule molle          orale  Autorisation active
# 2            comprimé pelliculé sécable          orale  Autorisation active
# 3            comprimé pelliculé sécable          orale  Autorisation active
# 4            comprimé pelliculé sécable          orale  Autorisation active
# ...                                 ...            ...                  ...
# 15690                          comprimé          orale  Autorisation active
# 15691                comprimé pelliculé          orale  Autorisation active
# 15692  granulés pour suspension buvable          orale  Autorisation active
# 15693           solution pour perfusion  intraveineuse  Autorisation active
# 15694                comprimé pelliculé          orale  Autorisation active
#
#                                    type_amm commercialisation_state  \
# 0                       Procédure nationale          Commercialisée
# 1                       Procédure nationale          Commercialisée
# 2                   Procédure décentralisée          Commercialisée
# 3                   Procédure décentralisée          Commercialisée
# 4                   Procédure décentralisée          Commercialisée
# ...                                     ...                     ...
# 15690                 Procédure centralisée      Non commercialisée
# 15691                 Procédure centralisée          Commercialisée
# 15692  Procédure de reconnaissance mutuelle          Commercialisée
# 15693  Procédure de reconnaissance mutuelle          Commercialisée
# 15694  Procédure de reconnaissance mutuelle          Commercialisée
#
#          date_amm              statutbdm num_authorization_eu  \
# 0      12/03/1998                    NaN                  NaN
# 1      07/07/1997                    NaN                  NaN
# 2      22/10/2019                    NaN                  NaN
# 3      21/02/2018                    NaN                  NaN
# 4      30/12/2016                    NaN                  NaN
# ...           ...                    ...                  ...
# 15690  05/09/2011  Warning disponibilité          EU/1/11/714
# 15691  09/11/2016                    NaN          EU/1/11/714
# 15692  31/08/2001                    NaN                  NaN
# 15693  31/08/2001                    NaN                  NaN
# 15694  31/08/2001                    NaN                  NaN
#
#                              titulaire surveillance
# 0                 PHARMA DEVELOPPEMENT          Non
# 1                 PHARMA DEVELOPPEMENT          Non
# 2                     ARROW GENERIQUES          Non
# 3                            MYLAN SAS          Non
# 4                               SANDOZ          Non
# ...                                ...          ...
# 15690   JANSSEN CILAG INTERNATIONAL NV          Oui
# 15691   JANSSEN CILAG INTERNATIONAL NV          Non
# 15692            PFIZER HOLDING FRANCE          Non
# 15693            PFIZER HOLDING FRANCE          Non
# 15694            PFIZER HOLDING FRANCE          Non
#
# [15695 rows x 12 columns]

# %%
columns_cis_compo = '''code_cis
designation
substance_code
denomination
dose
dose_ref
composant_type
num_linked'''.split('\n')
print(columns_cis_compo)
df_compo = pd.read_csv("CIS_COMPO_bdpm.txt",names=columns_cis_compo,delimiter='\t',index_col=False)
# Out:
# ['code_cis', 'designation', 'substance_code', 'denomination', 'dose', 'dose_ref', 'composant_type', 'num_linked']
# /home/james/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/pandas/util/_decorators.py:311: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   return func(*args, **kwargs)

# %%
units_conversion = {
    'mg' : 10 ** -3,
    'microgrammes' : 10 ** -6,
}


def gather_ocrx_medical_term(medical_term):
    df = pd.read_csv(f"ocrx-data/{medical_term}_fr.csv")
    labels = df['sLabel'].values
    codes = df['s'].values
    return [(str(val),str(val_code)) for val, val_code in zip(labels,codes)]

def parse_dosage(dose):
    splitted = dose.split(" ")
    unit = splitted[-1]
    if unit in units_conversion:
        pass
# print('\n'.join([str(el) for el in df_compo['dose'].unique()]))
ocrx_terms = ['form','roa','substance']
ocrx_dfs = [gather_ocrx_medical_term(term) for term in ocrx_terms]

# %%
def convert_to_upper(df,cols_name):
    for col_name in cols_name:
        df[col_name] = df[col_name].str.upper() 
# df_bdpm['form'] = df_bdpm['form'].str.upper()

# %% [markdown]
# Mots qu'on peut couper durant le matching:
#
# BASE
# MONOHYDRATE
# DEHYDRATE
# HYDRATE

# %%
sum(["HOMÉOPATHIQUE" in val for val in df_compo.denomination.values ])
# Out:
# 8022

# %%
df_compo.shape
# Out:
# (32343, 8)

# %%
def process_term(el):
    if el.endswith("BASE"):
        return ' '.join(el.split(" ")[:-1]).strip()
    if el.endswith(")"):
        return (el.split("(")[-1][:-1] + " " + ' '.join(el.split("(")[0].split(' '))).strip()
    return el.strip()
df_compo['denomination'] = df_compo['denomination'].apply(process_term)

# %%
process_term("RANITIDINE (CHLORHYDRATE DE)")
# Out:
# 'CHLORHYDRATE DE RANITIDINE'

# %%
process_term("RANITIDINE BASE")
# Out:
# 'RANITIDINE'

# %%
upper_cols = ['form','roa']
convert_to_upper(df_bdpm,upper_cols)

# %%
df_bdpm['roa'] = df_bdpm['roa'].str.split(';')

# %%
df_bdpm['roa'].iloc[107]
# Out:
# ['CUTANÉE', 'ORALE', 'SUBLINGUALE']

# %%
df_compo.loc[df_compo.dose == '45 - 70 mg']
# Out:
#      code_cis designation  substance_code                     denomination  \
# 222  60074795    solution           15614  PROTÉINES PLASMATIQUES HUMAINES
#
#            dose          dose_ref composant_type num_linked
# 222  45 - 70 mg  1 ml de solution             SA          1

# %%
df_bdpm[['code_cis','roa','form']]
# Out:
#        code_cis              roa                              form
# 0      61266250        [CUTANÉE]                           POMMADE
# 1      62869109          [ORALE]                     CAPSULE MOLLE
# 2      61876780          [ORALE]        COMPRIMÉ PELLICULÉ SÉCABLE
# 3      62401060          [ORALE]        COMPRIMÉ PELLICULÉ SÉCABLE
# 4      63797011          [ORALE]        COMPRIMÉ PELLICULÉ SÉCABLE
# ...         ...              ...                               ...
# 15690  66425614          [ORALE]                          COMPRIMÉ
# 15691  67337081          [ORALE]                COMPRIMÉ PELLICULÉ
# 15692  63095061          [ORALE]  GRANULÉS POUR SUSPENSION BUVABLE
# 15693  63283095  [INTRAVEINEUSE]           SOLUTION POUR PERFUSION
# 15694  68311278          [ORALE]                COMPRIMÉ PELLICULÉ
#
# [15695 rows x 3 columns]

# %%
def construct_vocab(df,column,is_list=False):
    vocab_set = None
    is_list = type(df[column].values[0]) == list
    if is_list:
        vocab_set = {el for els in df[column].values for el in els}
    else:
        vocab_set = {el for el in df[column].values}
    df = pd.DataFrame()
    df['ansm_label'] = list(vocab_set)
    df['ansm_code'] = [str(i) for i in range(len(vocab_set))]
    return df

# %%
bdpm_roa_df = construct_vocab(df_bdpm,"roa")
bdpm_form_df = construct_vocab(df_bdpm,"form")
bdpm_substance_df = construct_vocab(df_compo,'denomination')

bdpm_dfs = []

# %%
def convert_ocrx_to_df(ocrx_elems):
    return [pd.DataFrame(ocrx_df,columns=['ocrx_label','ocrx_code']) for ocrx_df in ocrx_elems]

ocrx_dfs = convert_ocrx_to_df(ocrx_dfs)
ocrx_form_df, ocrx_roa_df, ocrx_substance_df = ocrx_dfs

# %%
from pytrie import Trie
def make_trie(ocrx_def_df):
    return {row['ocrx_label']: row['ocrx_code'] for _, row in ocrx_def_df.iterrows()}

def make_trie_ansm(ansm_def_df):
    return {row['ansm_label']: row['ansm_code'] for _, row in ansm_def_df.iterrows()}

def get_prefix(trie,term):
    words = term.split(' ')
    for i in reversed(range(1,len(words)+1)):
        term = ' '.join(words[:i])
        if term in trie:
            return (term, trie[term])
    return None
        
bdpm_dfs = [bdpm_form_df,bdpm_roa_df,bdpm_substance_df]
ocrx_form_trie,ocrx_roa_trie,ocrx_substance_trie = [make_trie(el) for el in ocrx_dfs]
ansm_tries = [make_trie_ansm(el) for el in bdpm_dfs]

# %%
import os
def print_stats(df_merged,type_fn,name='ansm'):
    # total_match
    print("TOTAL MATCH:")
    total_df = df_merged.dropna()
    print(total_df.head())
    print(total_df.shape)
    total_df.to_csv(f"match-ocrx/match_{type_fn}_total_match.csv")
    # left missing
    print("ONLY OCRX")
    only_ocrx = df_merged.loc[df_merged['ansm_code'].isna()]
    print(only_ocrx.head())
    print(only_ocrx.shape)
    only_ocrx.to_csv(f"match-ocrx/match_{type_fn}_only_ocrx.csv")
    # right missing
    print(f"ONLY {name.upper()}")
    only_ansm = df_merged.loc[df_merged['ocrx_code'].isna()]
    print(only_ansm.head())
    print(only_ansm.shape)
    only_ansm.to_csv(f"match-ocrx/match_{type_fn}_only_{name}.csv")
    return {'total' : total_df.shape[0], 'ocrx' : only_ocrx.shape[0], 'ansm' : only_ansm.shape[0]}
def add_prefixes(df,trie,trie_ansm):
    def process_row(row,trie):
        if type(row['ocrx_code']) == str and type(row['ansm_code']) == str:
            return (row['ocrx_code'], row['ocrx_label'], 'EXACT')
        elif str(row['ocrx_code']) == 'nan':
            result = get_prefix(trie,row['ansm_label'])
            if result is None:
                return (None, None, 'NONE')
            else:
                prefix_ocrx, ocrx_code = result
                return (ocrx_code, prefix_ocrx, 'PREFIX')
        else:
            return (row['ocrx_code'], row['ocrx_label'], 'NA')
    def process_row_ansm(row,trie):
        if type(row['ocrx_code']) == str and type(row['ansm_code']) == str:
            return (row['ansm_code'], row['ansm_label'], 'EXACT')
        elif str(row['ansm_code']) == 'nan':
            result = get_prefix(trie,row['ocrx_label'])
            if result is None:
                return (None, None, 'NONE')
            else:
                prefix_ansm, ansm_code = result
                return (ansm_code, prefix_ansm, 'PREFIX')
        else:
            return (row['ansm_code'], row['ansm_label'], 'NA')
        
            
#     import ipdb; ipdb.set_trace()
    els = ['ocrx','ansm']
    new_df = df.copy()
    for el, trie_el, process_fn in zip(els,[trie,trie_ansm],[process_row,process_row_ansm]):
        results = [process_fn(row,trie_el) for _, row in df.iterrows()]
        codes = [result[0] for result in results]
        full_terms = [result[1] for result in results]
        match_types = [result[2] for result in results]
        new_df[f'{el}_code'] = codes
        new_df[f'{el}_label'] = full_terms
        new_df[f'{el}_match_type'] = match_types
    return new_df

filenames = ['form','roa','substance']
if not os.path.exists("match-ocrx"):
    os.mkdir("match-ocrx")
ocrxs = [ocrx_form_df,ocrx_roa_df,ocrx_substance_df]
ansms = [bdpm_form_df,bdpm_roa_df,bdpm_substance_df]
tries = [ocrx_form_trie,ocrx_roa_trie,ocrx_substance_trie]
all_stats = {}
for ocrx, ansm, filename, trie, trie_ansm in zip(ocrxs,ansms,filenames,tries,ansm_tries):
    fullpath = f"match-ocrx/match_{filename}.csv"
    df_merged = pd.merge(ocrx,ansm,how="outer",left_on=['ocrx_label'], right_on=['ansm_label'])
#     import ipdb; ipdb.set_trace()
    df_merged_with_prefix = add_prefixes(df_merged,trie,trie_ansm)
    all_stats[filename] = print_stats(df_merged_with_prefix,filename)
    df_merged_with_prefix.to_csv(fullpath)
# Out:
# TOTAL MATCH:
#                                           ocrx_label   ocrx_code ansm_label  \
# 0                  SOLUTION (À LIBÉRATION PROLONGÉE)  4000000106   SOLUTION
# 1  SOLUTION PAR VOIE PERCUTANÉE OU INTRADERMIQUE ...  4000000129   SOLUTION
# 2  SOLUTION PAR VOIE TOPIQUE (HÔPITAUX, ÉTABLISSE...  4000000131   SOLUTION
# 3                 SOLUTION PAR VOIE INTRA-AMNIOTIQUE  4000000132   SOLUTION
# 4  SOLUTION PAR VOIE DÉSINFECTANT (USAGE DOMESTIQUE)  4000000133   SOLUTION
#
#   ansm_code ocrx_match_type ansm_match_type
# 0        40              NA          PREFIX
# 1        40              NA          PREFIX
# 2        40              NA          PREFIX
# 3        40              NA          PREFIX
# 4        40              NA          PREFIX
# (987, 6)
# ONLY OCRX
#                                             ocrx_label   ocrx_code ansm_label  \
# 382                           ÉMULSION PAR VOIE OTIQUE  4000000384       None
# 383                          ÉMULSION PAR VOIE TOPIQUE  4000000419       None
# 384  ÉMULSION PAR VOIE INTRAMUSCULAIRE OU INTRAVEIN...  4000000444       None
# 385                  ÉMULSION PAR VOIE INTRAMUSCULAIRE  4000000467       None
# 386                    ÉMULSION PAR VOIE INTRAVEINEUSE  4000000468       None
#
#     ansm_code ocrx_match_type ansm_match_type
# 382      None              NA            NONE
# 383      None              NA            NONE
# 384      None              NA            NONE
# 385      None              NA            NONE
# 386      None              NA            NONE
# (242, 6)
# ONLY ANSM
#     ocrx_label ocrx_code                          ansm_label ansm_code  \
# 940       None      None                             MATRICE         7
# 944       None      None                       DISPOSITIF(S)        11
# 955       None      None          GÉLULE GASTRO-RÉSISTANT(E)        23
# 970       None      None  TAMPON IMPRÉGNÉ(E) POUR INHALATION        41
# 973       None      None            GRANULÉS EFFERVESCENT(E)        45
#
#     ocrx_match_type ansm_match_type
# 940            NONE              NA
# 944            NONE              NA
# 955            NONE              NA
# 970            NONE              NA
# 973            NONE              NA
# (78, 6)
# TOTAL MATCH:
#          ocrx_label   ocrx_code        ansm_label ansm_code ocrx_match_type  \
# 0      SOUS-CUTANÉE  4100000026      SOUS-CUTANÉE         0           EXACT
# 2     INTRADERMIQUE  4100000068     INTRADERMIQUE        18           EXACT
# 3     INTRAVEINEUSE  4100000079     INTRAVEINEUSE        35           EXACT
# 4  INTRA-ARTÉRIELLE  4100000091  INTRA-ARTÉRIELLE        27           EXACT
# 8             ORALE  4100000056             ORALE        48           EXACT
#
#   ansm_match_type
# 0           EXACT
# 2           EXACT
# 3           EXACT
# 4           EXACT
# 8           EXACT
# (27, 6)
# ONLY OCRX
#                                           ocrx_label   ocrx_code ansm_label  \
# 1                                         PERCUTANÉE  4100000032       None
# 5  TOPIQUE (HÔPITAUX, ÉTABLISSEMENTS DE SOINS DE ...  4100000044       None
# 6                                   INTRA-AMNIOTIQUE  4100000066       None
# 7                    DÉSINFECTANT (USAGE DOMESTIQUE)  4100000088       None
# 9                                            TOPIQUE  4100000030       None
#
#   ansm_code ocrx_match_type ansm_match_type
# 1      None              NA            NONE
# 5      None              NA            NONE
# 6      None              NA            NONE
# 7      None              NA            NONE
# 9      None              NA            NONE
# (69, 6)
# ONLY ANSM
#    ocrx_label ocrx_code      ansm_label ansm_code ocrx_match_type  \
# 95       None      None  BUCCOGINGIVALE         1            NONE
# 96       None      None    INTRASÉREUSE         2            NONE
# 97       None      None  INTRAVITRÉENNE         4            NONE
# 98       None      None  HÉMOFILTRATION         6            NONE
# 99       None      None     INTRADURALE         7            NONE
#
#    ansm_match_type
# 95              NA
# 96              NA
# 97              NA
# 98              NA
# 99              NA
# (41, 6)
# TOTAL MATCH:
#                      ocrx_label   ocrx_code                    ansm_label  \
# 1  BENZATHINE BENZYLPÉNICILLINE  3000004942  BENZATHINE BENZYLPÉNICILLINE
# 4                     L-PROLINE  3000001302                     L-PROLINE
# 5                       PROLINE  3000001302                       PROLINE
# 6                          IODE  3000001570                          IODE
# 7          EMBONATE DE PYRANTEL  3000002873          EMBONATE DE PYRANTEL
#
#   ansm_code ocrx_match_type ansm_match_type
# 1       609           EXACT           EXACT
# 4       874           EXACT           EXACT
# 5      1968           EXACT           EXACT
# 6      1919           EXACT           EXACT
# 7      2408           EXACT           EXACT
# (1820, 6)
# ONLY OCRX
#                     ocrx_label   ocrx_code ansm_label ansm_code  \
# 0                BREXPIPRAZOLE  3000003754       None      None
# 2                  BENZÉTHACIL  3000004942       None      None
# 3     PÉNICILLINE G BENZATHINE  3000004942       None      None
# 8          PAMOATE DE PYRANTEL  3000002873       None      None
# 12  CHLORHYDRATE DE PAROXÉTINE  3000002056       None      None
#
#    ocrx_match_type ansm_match_type
# 0               NA            NONE
# 2               NA            NONE
# 3               NA            NONE
# 8               NA            NONE
# 12              NA            NONE
# (3231, 6)
# ONLY ANSM
#      ocrx_label ocrx_code                                         ansm_label  \
# 4536       None      None                                POUDRE DE VALERIANE
# 4537       None      None  CALADIUM SEGUINUM POUR PRÉPARATIONS HOMÉOPATHI...
# 4538       None      None                                         ZICONOTIDE
# 4539       None      None                                BENZOATE DE QUININE
# 4540       None      None                                        RILMÉNIDINE
#
#      ansm_code ocrx_match_type ansm_match_type
# 4536         1            NONE              NA
# 4537         2            NONE              NA
# 4538         3            NONE              NA
# 4539         4            NONE              NA
# 4540         8            NONE              NA
# (2448, 6)

# %%
all_stats
# Out:
# {'form': {'total': 987, 'ocrx': 242, 'ansm': 78},
#  'roa': {'total': 27, 'ocrx': 69, 'ansm': 41},
#  'substance': {'total': 1820, 'ocrx': 3231, 'ansm': 2448}}

# %% [markdown]
# # Indications thérapeutiques

# %%
# !nemo .
# Out:
# ** (nemo:66252): WARNING **: 09:25:25.579: Current gtk theme is not known to have nemo support (Nordic-master) - checking...
# ImportError: could not import gobject (error was: ModuleNotFoundError("No module named 'gi'"))
#
# ** (nemo:66252): WARNING **: 09:25:25.709: pygobject initialization failed
#
# ** (nemo:66252): WARNING **: 09:25:25.709: nemo_python_init_python failed
# Nemo-Share-Message: 09:25:26.429: Called "net usershare info" but it failed: 'net usershare' returned error 255: net usershare: cannot open usershare directory /var/lib/samba/usershares. Error No such file or directory
# Please ask your system administrator to enable user sharing.
#
# Nemo-Share-Message: 09:44:21.785: Called "net usershare info" but it failed: 'net usershare' returned error 255: net usershare: cannot open usershare directory /var/lib/samba/usershares. Error No such file or directory
# Please ask your system administrator to enable user sharing.

# %%
import pandas as pd

patholo_csv = "cis-pathologie.csv"
df_patho = pd.read_csv(patholo_csv,sep='\t')
df_patho.columns = ['code_cis', 'indications']
final_df_indications = pd.merge(pd.merge(df_bdpm,df_compo,on="code_cis",suffixes=['_bdpm','_compo']),df_patho,on="code_cis")
final_df_indications.to_csv("df_indications.csv")

# %%
final_df_indications.shape[0]
# Out:
# 23885

# %%
df_patho.shape[0]
# Out:
# 15338

# %%
df_compo.shape[0]
# Out:
# 32343

# %%
df_bdpm.shape[0]
# Out:
# 15695

# %%
els = [df for i, df in final_df_indications.groupby('code_cis') if df.shape[0] > 1]

# %%
els[0]
# Out:
#        code_cis                                  denomination_bdpm  \
# 18915  60002504  RANITIDINE BIOGARAN 150 mg, comprimé effervescent
# 18916  60002504  RANITIDINE BIOGARAN 150 mg, comprimé effervescent
# 18917  60002504  RANITIDINE BIOGARAN 150 mg, comprimé effervescent
# 18918  60002504  RANITIDINE BIOGARAN 150 mg, comprimé effervescent
# 18919  60002504  RANITIDINE BIOGARAN 150 mg, comprimé effervescent
# 18920  60002504  RANITIDINE BIOGARAN 150 mg, comprimé effervescent
#
#                            form      roa            status_amm  \
# 18915  COMPRIMÉ EFFERVESCENT(E)  [ORALE]  Autorisation abrogée
# 18916  COMPRIMÉ EFFERVESCENT(E)  [ORALE]  Autorisation abrogée
# 18917  COMPRIMÉ EFFERVESCENT(E)  [ORALE]  Autorisation abrogée
# 18918  COMPRIMÉ EFFERVESCENT(E)  [ORALE]  Autorisation abrogée
# 18919  COMPRIMÉ EFFERVESCENT(E)  [ORALE]  Autorisation abrogée
# 18920  COMPRIMÉ EFFERVESCENT(E)  [ORALE]  Autorisation abrogée
#
#                   type_amm commercialisation_state    date_amm  \
# 18915  Procédure nationale      Non commercialisée  04/07/1989
# 18916  Procédure nationale      Non commercialisée  04/07/1989
# 18917  Procédure nationale      Non commercialisée  04/07/1989
# 18918  Procédure nationale      Non commercialisée  04/07/1989
# 18919  Procédure nationale      Non commercialisée  04/07/1989
# 18920  Procédure nationale      Non commercialisée  04/07/1989
#
#                    statutbdm num_authorization_eu       titulaire  \
# 18915  Warning disponibilité                  NaN   SAINT GERMAIN
# 18916  Warning disponibilité                  NaN   SAINT GERMAIN
# 18917  Warning disponibilité                  NaN   SAINT GERMAIN
# 18918  Warning disponibilité                  NaN   SAINT GERMAIN
# 18919  Warning disponibilité                  NaN   SAINT GERMAIN
# 18920  Warning disponibilité                  NaN   SAINT GERMAIN
#
#       surveillance designation  substance_code          denomination_compo  \
# 18915          Non    comprimé           25783  CHLORHYDRATE DE RANITIDINE
# 18916          Non    comprimé           25783  CHLORHYDRATE DE RANITIDINE
# 18917          Non    comprimé           25783  CHLORHYDRATE DE RANITIDINE
# 18918          Non    comprimé           49632                  RANITIDINE
# 18919          Non    comprimé           49632                  RANITIDINE
# 18920          Non    comprimé           49632                  RANITIDINE
#
#          dose     dose_ref composant_type num_linked  \
# 18915  168 mg  un comprimé             SA          1
# 18916  168 mg  un comprimé             SA          1
# 18917  168 mg  un comprimé             SA          1
# 18918  150 mg  un comprimé             FT          1
# 18919  150 mg  un comprimé             FT          1
# 18920  150 mg  un comprimé             FT          1
#
#                      indications
# 18915  Reflux gastro-oesophagien
# 18916            Ulcère duodénal
# 18917           Ulcère gastrique
# 18918  Reflux gastro-oesophagien
# 18919            Ulcère duodénal
# 18920           Ulcère gastrique

# %%
import pandas as pd
import ast
final_df_indications = pd.read_csv("df_indications.csv").astype(str)
def parse_ast(df):
    cols = ['roa']
    for col in cols:
        df[col] = [ast.literal_eval(val) for val in df[col].values]
#         (ast.literal_eval)
parse_ast(final_df_indications)
synonym_df = pd.read_csv("bdpm-pathologies.csv",sep=';').dropna()
synonym_df.columns = ['indications','synonyms']
synonym_df.synonyms = synonym_df['synonyms'].astype('str').apply(lambda el: el.split(':')[-1] if el is not None else el)

# %%
synonym_dict = {row['indications'] : row['synonyms'] for _, row in synonym_df.iterrows()}

# %%
def convert_to_list_indication(el):
    if el in synonym_dict:
        return [el,synonym_dict[el]]
    else:
        return [el]
final_df_indications['indications'] = final_df_indications['indications'].apply(convert_to_list_indication)

# %%
final_df_indications['roa'].iloc[0]
# Out:
# ['CUTANÉE']

# %%
if 'denomination_compo' in final_df_indications.columns:
    final_df_indications = final_df_indications.rename(columns={'denomination_compo':'substance'})

# %%
def convert_cols_to_list(df,cols):
    for col in cols:
        df[col] = df[col].apply(lambda el: [el] if type(el) != list else el)

def load_ocrx_matches(els):
    return {el: pd.read_csv(f'match-ocrx/match_{el}.csv',dtype=str) for el in els}

convert_cols_to_list(final_df_indications,['form','roa','substance'])
matches = load_ocrx_matches(['form','roa','substance'])

def create_extend_to_ocrx(el_type):
    def extend(el):
        df = matches[el_type]
        cols = ['ansm_label','ocrx_label','ansm_code','ocrx_code', 'ansm_match_type', 'ocrx_match_type']
#         import ipdb; ipdb.set_trace()
        return [dict(df.loc[(df['ansm_label'] == el_i)][cols].iloc[0]) for el_i in el]
    return extend

def extend_all_df_to_ocrx(df):
    new_df = df.copy()
    cols = ['form','roa','substance']
#     import ipdb; ipdb.set_trace()
    for col in cols:
        extender = create_extend_to_ocrx(col)
        new_df[col] = df[col].apply(extender)
    return new_df
df_with_ocrx = extend_all_df_to_ocrx(final_df_indications)

# %%
dict(matches['form'].iloc[0])
# Out:
# {'Unnamed: 0': '0',
#  'ocrx_label': 'SOLUTION (À LIBÉRATION PROLONGÉE)',
#  'ocrx_code': '4000000106',
#  'ansm_label': 'SOLUTION',
#  'ansm_code': '170',
#  'ocrx_match_type': nan,
#  'ansm_match_type': 'PREFIX'}

# %%
df_with_ocrx['form'][0]
# Out:
# [{'ansm_label': 'POMMADE',
#   'ocrx_label': 'POMMADE PAR VOIE OPHTALMIQUE OU OTIQUE',
#   'ansm_code': '317',
#   'ocrx_code': '4000000230',
#   'ansm_match_type': 'PREFIX',
#   'ocrx_match_type': nan}]

# %%
df_with_ocrx.to_csv("df_ocrx.csv")

# %%
df_with_ocrx
# Out:
#       Unnamed: 0  code_cis                                  denomination_bdpm  \
# 0              0  61266250                A 313 200 000 UI POUR CENT, pommade
# 1              1  61266250                A 313 200 000 UI POUR CENT, pommade
# 2              2  66513085  ABASAGLAR 100 unités/ml, solution injectable e...
# 3              3  64332894  ABASAGLAR 100 unités/ml, solution injectable e...
# 4              4  66207341  ABELCET 5 mg/ml, suspension à diluer pour perf...
# ...          ...       ...                                                ...
# 23880      23880  68664125      ZYPREXA VELOTAB 5 mg, comprimé orodispersible
# 23881      23881  65016707       ZYRTEC 10 mg/ml, solution buvable en gouttes
# 23882      23882  65016707       ZYRTEC 10 mg/ml, solution buvable en gouttes
# 23883      23883  64949486        ZYRTECSET 10 mg, comprimé pelliculé sécable
# 23884      23884  64949486        ZYRTECSET 10 mg, comprimé pelliculé sécable
#
#                                                     form  \
# 0      [{'ansm_label': 'POMMADE', 'ocrx_label': 'POMM...
# 1      [{'ansm_label': 'POMMADE', 'ocrx_label': 'POMM...
# 2      [{'ansm_label': 'SOLUTION INJECTABLE', 'ocrx_l...
# 3      [{'ansm_label': 'SOLUTION INJECTABLE', 'ocrx_l...
# 4      [{'ansm_label': 'SUSPENSION À DILUER POUR PERF...
# ...                                                  ...
# 23880  [{'ansm_label': 'COMPRIMÉ ORODISPERSIBLE', 'oc...
# 23881  [{'ansm_label': 'SOLUTION BUVABLE EN GOUTTES',...
# 23882  [{'ansm_label': 'SOLUTION BUVABLE EN GOUTTES',...
# 23883  [{'ansm_label': 'COMPRIMÉ PELLICULÉ SÉCABLE', ...
# 23884  [{'ansm_label': 'COMPRIMÉ PELLICULÉ SÉCABLE', ...
#
#                                                      roa           status_amm  \
# 0      [{'ansm_label': 'CUTANÉE', 'ocrx_label': nan, ...  Autorisation active
# 1      [{'ansm_label': 'CUTANÉE', 'ocrx_label': nan, ...  Autorisation active
# 2      [{'ansm_label': 'SOUS-CUTANÉE', 'ocrx_label': ...  Autorisation active
# 3      [{'ansm_label': 'SOUS-CUTANÉE', 'ocrx_label': ...  Autorisation active
# 4      [{'ansm_label': 'INTRAVEINEUSE', 'ocrx_label':...  Autorisation active
# ...                                                  ...                  ...
# 23880  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23881  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23882  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23883  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23884  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
#
#                                    type_amm commercialisation_state  \
# 0                       Procédure nationale          Commercialisée
# 1                       Procédure nationale          Commercialisée
# 2                     Procédure centralisée          Commercialisée
# 3                     Procédure centralisée          Commercialisée
# 4                       Procédure nationale          Commercialisée
# ...                                     ...                     ...
# 23880                 Procédure centralisée          Commercialisée
# 23881  Procédure de reconnaissance mutuelle          Commercialisée
# 23882  Procédure de reconnaissance mutuelle          Commercialisée
# 23883                   Procédure nationale          Commercialisée
# 23884                   Procédure nationale          Commercialisée
#
#          date_amm statutbdm  ...                          titulaire  \
# 0      12/03/1998       nan  ...               PHARMA DEVELOPPEMENT
# 1      12/03/1998       nan  ...               PHARMA DEVELOPPEMENT
# 2      09/09/2014       nan  ...   ELI LILLY NEDERLAND BV (PAY-BAS)
# 3      09/09/2014       nan  ...   ELI LILLY NEDERLAND BV (PAY-BAS)
# 4      10/06/1997       nan  ...                       ACINO FRANCE
# ...           ...       ...  ...                                ...
# 23880  03/02/2000       nan  ...               ELI LILLY (PAYS BAS)
# 23881  14/11/1996       nan  ...                         UCB PHARMA
# 23882  14/11/1996       nan  ...                         UCB PHARMA
# 23883  28/10/1994       nan  ...                         UCB PHARMA
# 23884  28/10/1994       nan  ...                         UCB PHARMA
#
#       surveillance designation substance_code  \
# 0              Non     pommade          77887
# 1              Non     pommade          77887
# 2              Non    solution          44461
# 3              Non    solution          44461
# 4              Non  suspension           1150
# ...            ...         ...            ...
# 23880          Non    comprimé          17723
# 23881          Non    solution          60929
# 23882          Non    solution          60929
# 23883          Non    comprimé          60929
# 23884          Non    comprimé          60929
#
#                                                substance        dose  \
# 0      [{'ansm_label': 'CONCENTRAT DE VITAMINE A SYNT...  200 000 UI
# 1      [{'ansm_label': 'CONCENTRAT DE VITAMINE A SYNT...  200 000 UI
# 2      [{'ansm_label': 'INSULINE GLARGINE', 'ocrx_lab...  100 unités
# 3      [{'ansm_label': 'INSULINE GLARGINE', 'ocrx_lab...  100 unités
# 4      [{'ansm_label': 'AMPHOTÉRICINE B', 'ocrx_label...        5 mg
# ...                                                  ...         ...
# 23880  [{'ansm_label': 'OLANZAPINE', 'ocrx_label': 'O...        5 mg
# 23881  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...     1,000 g
# 23882  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...     1,000 g
# 23883  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...       10 mg
# 23884  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...       10 mg
#
#                  dose_ref composant_type num_linked  \
# 0        100 g de pommade             SA        1.0
# 1        100 g de pommade             SA        1.0
# 2                    1 ml             SA        1.0
# 3                    1 ml             SA        1.0
# 4      1 mL de suspension             SA        1.0
# ...                   ...            ...        ...
# 23880         un comprimé             SA        1.0
# 23881              100 ml             SA        1.0
# 23882              100 ml             SA        1.0
# 23883         un comprimé             SA        1.0
# 23884         un comprimé             SA        1.0
#
#                                       indications
# 0      [Dermatite de contact,  Eczéma de contact]
# 1      [Eczéma de contact,  Dermatite de contact]
# 2                                       [Diabète]
# 3                                       [Diabète]
# 4                                  [Aspergillose]
# ...                                           ...
# 23880                             [Schizophrénie]
# 23881                        [Rhinite allergique]
# 23882                                 [Urticaire]
# 23883                        [Rhinite allergique]
# 23884                                 [Urticaire]
#
# [23885 rows x 21 columns]

# %%
from pytrie import Trie

# %% [markdown]
# # Lire le fichier HTML

# %%
import pandas as pd
df_rcp = pd.read_csv("CIS_RCP.csv",sep='\t')

# %%
df_rcp.columns
# Out:
# Index(['Code_CIS', 'RCP_html'], dtype='object')

# %%
import os
if not os.path.exists("htmls"):
    os.mkdir("htmls")
    for _, row in df_rcp.iterrows():
        content = row['RCP_html']
        if type(content) != str:
            continue
        code_cis = row['Code_CIS']
        with open(f"htmls/{code_cis}.html","w") as f:
            f.write(content)

# %%
from lxml import etree as et
import re
def strip_html(text):
#     return text
    if text is None:
        return None
    return re.sub('<[^<]+?>', '', text)
def extract_ade(content):
    if type(content) != str:
        return None
    lines = content.split('\n')
#     import ipdb; ipdb.set_trace()
    start_indices = [i for i,line in enumerate(lines) if 'RcpEffetsIndesirables' in line]
    if len(start_indices) == 0:
        return None
    start_index = start_indices[0]
    end_index = [start_index+j for j, line in enumerate(lines[start_index:]) if 'AmmAnnexeTitre2' in line and '"Rcp' in line]
    if len(end_index) <= 1:
        return ('\n'.join(lines[start_index:]))
    elif len(end_index) > 1:
        return ('\n'.join(lines[start_index:end_index[1]]))

# %%
df_rcp['adverse_events_html'] = df_rcp['RCP_html'].apply(extract_ade)
df_rcp['adverse_events_text'] = df_rcp['adverse_events_html'].apply(strip_html)

# %%
df_rcp.columns = ['code_cis', 'rcp_html', 'adverse_events_html', 'adverse_events_text']

# %%
df_rcp
# Out:
#        code_cis                                           rcp_html  \
# 0      61266250  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
# 1      62869109  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
# 2      61876780  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
# 3      62401060  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
# 4      63797011  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
# ...         ...                                                ...
# 15644  66425614                                                NaN
# 15645  67337081                                                NaN
# 15646  63095061  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
# 15647  63283095  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
# 15648  68311278  <!DOCTYPE html>\n<html>\n<body><div id="textDo...
#
#                                      adverse_events_html  \
# 0      <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
# 1      <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
# 2      <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
# 3      <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
# 4      <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
# ...                                                  ...
# 15644                                               None
# 15645                                               None
# 15646  <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
# 15647  <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
# 15648  <p class="AmmAnnexeTitre2"><a name="RcpEffetsI...
#
#                                      adverse_events_text
# 0      4.8. Effets indésirables  \nPossibilité de réa...
# 1      4.8. Effets indésirables  \nTout effet indésir...
# 2      4.8. Effets indésirables  \nPour la plupart de...
# 3      4.8. Effets indésirables  \nPour la plupart de...
# 4      4.8. Effets indésirables  \nPour la plupart de...
# ...                                                  ...
# 15644                                               None
# 15645                                               None
# 15646  4.8. Effets indésirables  \nLe tableau ci-dess...
# 15647  4.8. Effets indésirables  \nLe tableau ci-dess...
# 15648  4.8. Effets indésirables  \nLe tableau ci-dess...
#
# [15649 rows x 4 columns]

# %%
df_ocrx = pd.read_csv("df_ocrx.csv")

# %%
df_ocrx
# Out:
#        Unnamed: 0  Unnamed: 0.1  code_cis  \
# 0               0             0  61266250
# 1               1             1  61266250
# 2               2             2  66513085
# 3               3             3  64332894
# 4               4             4  66207341
# ...           ...           ...       ...
# 23880       23880         23880  68664125
# 23881       23881         23881  65016707
# 23882       23882         23882  65016707
# 23883       23883         23883  64949486
# 23884       23884         23884  64949486
#
#                                        denomination_bdpm  \
# 0                    A 313 200 000 UI POUR CENT, pommade
# 1                    A 313 200 000 UI POUR CENT, pommade
# 2      ABASAGLAR 100 unités/ml, solution injectable e...
# 3      ABASAGLAR 100 unités/ml, solution injectable e...
# 4      ABELCET 5 mg/ml, suspension à diluer pour perf...
# ...                                                  ...
# 23880      ZYPREXA VELOTAB 5 mg, comprimé orodispersible
# 23881       ZYRTEC 10 mg/ml, solution buvable en gouttes
# 23882       ZYRTEC 10 mg/ml, solution buvable en gouttes
# 23883        ZYRTECSET 10 mg, comprimé pelliculé sécable
# 23884        ZYRTECSET 10 mg, comprimé pelliculé sécable
#
#                                                     form  \
# 0      [{'ansm_label': 'POMMADE', 'ocrx_label': 'POMM...
# 1      [{'ansm_label': 'POMMADE', 'ocrx_label': 'POMM...
# 2      [{'ansm_label': 'SOLUTION INJECTABLE', 'ocrx_l...
# 3      [{'ansm_label': 'SOLUTION INJECTABLE', 'ocrx_l...
# 4      [{'ansm_label': 'SUSPENSION À DILUER POUR PERF...
# ...                                                  ...
# 23880  [{'ansm_label': 'COMPRIMÉ ORODISPERSIBLE', 'oc...
# 23881  [{'ansm_label': 'SOLUTION BUVABLE EN GOUTTES',...
# 23882  [{'ansm_label': 'SOLUTION BUVABLE EN GOUTTES',...
# 23883  [{'ansm_label': 'COMPRIMÉ PELLICULÉ SÉCABLE', ...
# 23884  [{'ansm_label': 'COMPRIMÉ PELLICULÉ SÉCABLE', ...
#
#                                                      roa           status_amm  \
# 0      [{'ansm_label': 'CUTANÉE', 'ocrx_label': nan, ...  Autorisation active
# 1      [{'ansm_label': 'CUTANÉE', 'ocrx_label': nan, ...  Autorisation active
# 2      [{'ansm_label': 'SOUS-CUTANÉE', 'ocrx_label': ...  Autorisation active
# 3      [{'ansm_label': 'SOUS-CUTANÉE', 'ocrx_label': ...  Autorisation active
# 4      [{'ansm_label': 'INTRAVEINEUSE', 'ocrx_label':...  Autorisation active
# ...                                                  ...                  ...
# 23880  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23881  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23882  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23883  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
# 23884  [{'ansm_label': 'ORALE', 'ocrx_label': 'ORALE'...  Autorisation active
#
#                                    type_amm commercialisation_state  \
# 0                       Procédure nationale          Commercialisée
# 1                       Procédure nationale          Commercialisée
# 2                     Procédure centralisée          Commercialisée
# 3                     Procédure centralisée          Commercialisée
# 4                       Procédure nationale          Commercialisée
# ...                                     ...                     ...
# 23880                 Procédure centralisée          Commercialisée
# 23881  Procédure de reconnaissance mutuelle          Commercialisée
# 23882  Procédure de reconnaissance mutuelle          Commercialisée
# 23883                   Procédure nationale          Commercialisée
# 23884                   Procédure nationale          Commercialisée
#
#          date_amm  ...                          titulaire surveillance  \
# 0      12/03/1998  ...               PHARMA DEVELOPPEMENT          Non
# 1      12/03/1998  ...               PHARMA DEVELOPPEMENT          Non
# 2      09/09/2014  ...   ELI LILLY NEDERLAND BV (PAY-BAS)          Non
# 3      09/09/2014  ...   ELI LILLY NEDERLAND BV (PAY-BAS)          Non
# 4      10/06/1997  ...                       ACINO FRANCE          Non
# ...           ...  ...                                ...          ...
# 23880  03/02/2000  ...               ELI LILLY (PAYS BAS)          Non
# 23881  14/11/1996  ...                         UCB PHARMA          Non
# 23882  14/11/1996  ...                         UCB PHARMA          Non
# 23883  28/10/1994  ...                         UCB PHARMA          Non
# 23884  28/10/1994  ...                         UCB PHARMA          Non
#
#       designation substance_code  \
# 0         pommade          77887
# 1         pommade          77887
# 2        solution          44461
# 3        solution          44461
# 4      suspension           1150
# ...           ...            ...
# 23880    comprimé          17723
# 23881    solution          60929
# 23882    solution          60929
# 23883    comprimé          60929
# 23884    comprimé          60929
#
#                                                substance        dose  \
# 0      [{'ansm_label': 'CONCENTRAT DE VITAMINE A SYNT...  200 000 UI
# 1      [{'ansm_label': 'CONCENTRAT DE VITAMINE A SYNT...  200 000 UI
# 2      [{'ansm_label': 'INSULINE GLARGINE', 'ocrx_lab...  100 unités
# 3      [{'ansm_label': 'INSULINE GLARGINE', 'ocrx_lab...  100 unités
# 4      [{'ansm_label': 'AMPHOTÉRICINE B', 'ocrx_label...        5 mg
# ...                                                  ...         ...
# 23880  [{'ansm_label': 'OLANZAPINE', 'ocrx_label': 'O...        5 mg
# 23881  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...     1,000 g
# 23882  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...     1,000 g
# 23883  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...       10 mg
# 23884  [{'ansm_label': 'DICHLORHYDRATE DE CÉTIRIZINE'...       10 mg
#
#                  dose_ref composant_type num_linked  \
# 0        100 g de pommade             SA        1.0
# 1        100 g de pommade             SA        1.0
# 2                    1 ml             SA        1.0
# 3                    1 ml             SA        1.0
# 4      1 mL de suspension             SA        1.0
# ...                   ...            ...        ...
# 23880         un comprimé             SA        1.0
# 23881              100 ml             SA        1.0
# 23882              100 ml             SA        1.0
# 23883         un comprimé             SA        1.0
# 23884         un comprimé             SA        1.0
#
#                                           indications
# 0      ['Dermatite de contact', ' Eczéma de contact']
# 1      ['Eczéma de contact', ' Dermatite de contact']
# 2                                         ['Diabète']
# 3                                         ['Diabète']
# 4                                    ['Aspergillose']
# ...                                               ...
# 23880                               ['Schizophrénie']
# 23881                          ['Rhinite allergique']
# 23882                                   ['Urticaire']
# 23883                          ['Rhinite allergique']
# 23884                                   ['Urticaire']
#
# [23885 rows x 22 columns]

# %%
df_ocrx_with_ade = pd.merge(df_ocrx,df_rcp,on="code_cis",how="left")

# %%
df_ocrx_with_ade['adverse_events_text'].isna().sum()
# Out:
# 2627

# %%
# 2627 / 23885 have no adverse events

# %%
df_ocrx_with_ade.to_csv("df_ocrx_with_ade.csv")

# %%
df_ocrx_with_ade['form'].iloc[0]
# Out:
# "[{'ansm_label': 'POMMADE', 'ocrx_label': 'POMMADE PAR VOIE OPHTALMIQUE OU OTIQUE', 'ansm_code': '317', 'ocrx_code': '4000000230', 'ansm_match_type': 'PREFIX', 'ocrx_match_type': nan}]"

# %%
df_ocrx_with_ade['substance'].iloc[6]
# Out:
# "[{'ansm_label': 'ARIPIPRAZOLE', 'ocrx_label': 'ARIPIPRAZOLE', 'ansm_code': '4077', 'ocrx_code': '3000002188', 'ansm_match_type': 'EXACT', 'ocrx_match_type': 'EXACT'}]"

# %%
SNOMED CT pour matching
REST API pour match indications et ADEs
