# %%
import pandas as pd
import ast

def parse_df(df):
    columns_to_convert = ['form','roa','active_ingredient']
    def parse(el):
        if type(el) == str:
            return ast.literal_eval(el)
        return []
    for column in columns_to_convert:
        df[column] = df[column].apply(parse)
    return df

all_dailymed_drugs = parse_df(pd.read_csv("all_drugs_ade_indications_updated.csv"))


def construct_dict(df):
#     import ipdb; ipdb.set_trace()
    df = df.dropna()
    return {row['code_dailymed'] : str(int(row['code_ocrx'])) for _, row in df.iterrows()}
    
def load_matches():
    els = ['active_ingredient','form','roa']
    return {el: construct_dict(pd.read_csv(f"results/new_match_{el}.csv")) for el in els}

# %% [markdown]
# - [ ] Nombre de fichiers
# - [ ] Nombre de medicaments
# - [ ] Nombres de substances uniques
# - [ ] Nombre de produits de substances multiples
# - [ ] Try doing the cache of all OCRx/ DailyMed lookup tuples

# %%
matches = load_matches()

# %%
import os
import pandas as pd
EXPORT_DIR = "export/"
if not os.path.exists(EXPORT_DIR):
    os.mkdir(EXPORT_DIR)

terms = ['active_ingredient','form','roa']
def generate_export_df(term):
    df = pd.DataFrame(list(set(([(el['code'],el['name']) for value in all_dailymed_drugs[term].values for el in value if el['name'] is not None]))))
    df.columns = ['dailymed_code','dailymed_label']
    df = df.sort_values('dailymed_label')
    df.to_csv(f"{EXPORT_DIR}/dailymed_{term}_en.csv")

for term in terms:
    generate_export_df(term)

# %%
def export_drug(df):
    new_df = df[['code','drug']].copy()
    new_df.columns = ['dailymed_code','dailymed_label']
    new_df = new_df.sort_values('dailymed_label')
    new_df.to_csv(f"{EXPORT_DIR}/dailymed_drug_en.csv")

export_drug(all_dailymed_drugs)

# %%
# !nemo .

# %%
def extend_current_df(df):
    def add_ocrx_handler(column):
        def handler(els):
            return [{**el, 'ocrx_code' : matches[column].get(el['code'],None)} for el in els]
        return handler
    
    columns = ['form','roa','active_ingredient']
    new_df = df.copy()
    for column in columns:
        new_df[column] = new_df[column].apply(add_ocrx_handler(column))
    return new_df

# %%
ocrx_df = extend_current_df(all_dailymed_drugs)

# %%
ocrx_df.to_csv("ocrx_dailymed.csv")

# %%
ocrx_df['active_ingredient'].iloc[0]
# Out:
# [{'name': 'ETHINYL ESTRADIOL',
#   'code': '423D2T571U',
#   'ocrx_code': '3000002514'},
#  {'name': 'NORETHINDRONE', 'code': 'T18F433X4S', 'ocrx_code': '3000004496'}]

# %%
# !mkdir ocrx-matches

# %%
# 1. Select rows that only have one active ingredient
# 2. Find that active ingredient in OCRx
'''Use QueryFact.queryM'''
import requests
from tqdm import tqdm
class Pipe:
    def __init__(self,fns):
        self.fns = fns
    def __call__(self,*start):
        args = start
        for fn in self.fns:
            args = fn(*args)
        return args

def select_one_active_ingredient(df): 
    return df.loc[df['active_ingredient'].apply(lambda el: len(el) == 1)]
#     return df.loc[map(lambda val: '|||' not in val,df['active_ingredient'].values)]

def parse_dl_response(dlresponse):
    if 'CCD' not in dlresponse:
        return None
#     return [row for row in dlresponse['CCD']]
    return {el: row['RxCui'] for row in dlresponse['CCD'] for el in row['labels']}
def convert_string(dailymed_string):
#     print(dailymed_string)
    return str(dailymed_string).upper()
def convert_comb_dailymed_ocrx(dailymed_string,field):
    df = matches[field]
    el = df.loc[df['label'] == dailymed_string]
    if el.shape[0] > 0:
        return el.iloc[0]['code_ocrx']
    else:
        return None
#     return matches[field].get(convert_string(dailymed_string),None)

def dlquery_and_dump(form_data,i,drug_name):
    parsed = dlquery(form_data)
    filename = f"ocrx-matches/{i:09}_{drug_name}.txt"
    total = {request : form_data, drug_name : drug_name, response : parsed}
    with open(filename,"w"):
        f.write(json.dumps(total))
        
def dlquery(form_data):
    
    if form_data['substance'] == '':
        return None
#     import ipdb; ipdb.set_trace()
    multipart_form_data = {key: (None,val) for key,val in form_data.items()}
    response = requests.post('http://localhost:8080/DLquery',files=multipart_form_data,headers={'Authorization': 'Bearer foo'}).json()
    parsed = parse_dl_response(response)
    return parsed

def match_with_ocrx(df):
    proper_names = {'active_ingredient': 'substance', 'form' : 'form','roa' : 'route'}
#     lookup_names = {'active_ingredient': 'active_ingredient','form':'form','roa':'roa'}
    fields = ['active_ingredient', 'form', 'roa']
    def make_codes_dict(row,field):
#         import ipdb; ipdb.set_trace()
        codes = [el['ocrx_code'] for el in row[field]]
        filtered_codes = [code for code in codes if code is not None]
        return ' '.join(filtered_codes)
    form_datas = [{proper_names[field] : make_codes_dict(row,field) for field in fields} for _, row in df.iterrows()]         
#     import ipdb; ipdb.set_trace()
    drug_names = df['drug'].values
    dl_results = {drug_name: dlquery_and_dump(comb,i,drug_name) for i, (drug_name, comb) in enumerate(tqdm(zip(drug_names,form_datas)))}
    return dl_results

# %%
dlquery({})

# %%
one_active = select_one_active_ingredient(ocrx_df)

# %%
one_active.loc[one_active['active_ingredient'].apply(lambda el: el[0]['ocrx_code'] == '3000004855')]
# Out:
#        Unnamed: 0                                             author  \
# 69             69                            Northern Welding Supply
# 102           102                            MITCHELL WELDING SUPPLY
# 137           137                            Yosemite Medical Supply
# 147           147                                  Peachtree Medical
# 182           182                         Linde Gas & Equipment Inc.
# ...           ...                                                ...
# 46506       46506                             Empresas De Soldaduras
# 46516       46516                             Advacare Home Services
# 46517       46517  Manuel Enterprises, Inc. dba Nepenthe Home Med...
# 46581       46581    RXO2 Oxygen & Medical Equipment Supply Co. Inc.
# 46595       46595                        Cook Children's Home Health
#
#                    drug                                  active_ingredient  \
# 69               Oxygen  [{'name': 'Oxygen', 'code': 'S88TT14065', 'ocr...
# 102              Oxygen  [{'name': 'OXYGEN', 'code': 'S88TT14065', 'ocr...
# 137              Oxygen  [{'name': 'Oxygen', 'code': 'S88TT14065', 'ocr...
# 147              Oxygen  [{'name': 'Oxygen', 'code': 'S88TT14065', 'ocr...
# 182    Air, Compressed   [{'name': 'Oxygen', 'code': 'S88TT14065', 'ocr...
# ...                 ...                                                ...
# 46506            Oxygen  [{'name': 'OXYGEN', 'code': 'S88TT14065', 'ocr...
# 46516            Oxygen  [{'name': 'OXYGEN', 'code': 'S88TT14065', 'ocr...
# 46517            Oxygen  [{'name': 'OXYGEN', 'code': 'S88TT14065', 'ocr...
# 46581            Oxygen  [{'name': 'OXYGEN', 'code': 'S88TT14065', 'ocr...
# 46595            Oxygen  [{'name': 'OXYGEN', 'code': 'S88TT14065', 'ocr...
#
#              code                                           filename  \
# 69      10825-002  prescription/20101007_97fdc5d0-b18d-40b8-a99e-...
# 102     72276-001  prescription/20211008_704755e8-239d-18d6-e053-...
# 137    39338-1072  prescription/20100719_8c0478bf-7ac1-467f-a2bc-...
# 147    59225-0001  prescription/20130725_281e8cb5-27f3-4df2-9bc5-...
# 182     25373-006  prescription/20211225_b8b12e84-9e49-77de-700f-...
# ...           ...                                                ...
# 46506   80421-100  prescription/20211014_6f57cec9-9132-4ba4-a033-...
# 46516  65386-0001  prescription/20211005_985fb6bc-3f1e-41ac-a3ae-...
# 46517   58089-001  prescription/20211005_97542e76-4122-4754-e053-...
# 46581  68639-0001  prescription/20211007_9db62731-bcb1-4793-ae12-...
# 46595   62046-001  prescription/20211003_3101d4c6-109c-4720-96bd-...
#
#                                                     form  \
# 69     [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 102    [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 137    [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 147    [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 182    [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# ...                                                  ...
# 46506  [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 46516  [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 46517  [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 46581  [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
# 46595  [{'name': 'GAS', 'code': 'C42933', 'ocrx_code'...
#
#                                                      roa adverse_events_list  \
# 69     [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 102    [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 137    [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 147    [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 182    [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# ...                                                  ...                 ...
# 46506  [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 46516  [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 46517  [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 46581  [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
# 46595  [{'name': 'RESPIRATORY (INHALATION)', 'code': ...                  []
#
#       adverse_events indications active_ingredients numerator_name  \
# 69               NaN         NaN                NaN            NaN
# 102              NaN         NaN                NaN            NaN
# 137              NaN         NaN                NaN            NaN
# 147              NaN         NaN                NaN            NaN
# 182              NaN         NaN                NaN            NaN
# ...              ...         ...                ...            ...
# 46506            NaN         NaN                NaN            NaN
# 46516            NaN         NaN                NaN            NaN
# 46517            NaN         NaN                NaN            NaN
# 46581            NaN         NaN                NaN            NaN
# 46595            NaN         NaN                NaN            NaN
#
#        numerator_val denominator_name  denominator_val
# 69               NaN              NaN              NaN
# 102              NaN              NaN              NaN
# 137              NaN              NaN              NaN
# 147              NaN              NaN              NaN
# 182              NaN              NaN              NaN
# ...              ...              ...              ...
# 46506            NaN              NaN              NaN
# 46516            NaN              NaN              NaN
# 46517            NaN              NaN              NaN
# 46581            NaN              NaN              NaN
# 46595            NaN              NaN              NaN
#
# [1049 rows x 16 columns]

# %%
import pickle
result = match_with_ocrx(one_active)
# result = "hi"
with open("ocrx_dailymed_match.pickle","wb") as f:
    pickle.dump(result,f)
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
# 3it [00:01,  2.64it/s]
#
#
#
#
# 4it [00:02,  1.62it/s]
#
#
#
#
# 5it [00:03,  1.28it/s]
#
#
#
#
# 6it [00:04,  1.11it/s]
#
#
#
#
# 7it [00:05,  1.02it/s]
#
#
#
#
# 9it [00:06,  1.33it/s]
#
#
#
#
# 10it [00:07,  1.27it/s]
#
#
#
#
# 11it [00:08,  1.23it/s]
#
#
#
#
# 12it [00:09,  1.20it/s]
#
#
#
#
# 13it [00:10,  1.17it/s]
#
#
#
#
# 14it [00:11,  1.16it/s]
#
#
#
#
# 16it [00:11,  1.86it/s]
#
#
#
#
# 18it [00:12,  1.98it/s]
#
#
#
#
# 19it [00:13,  1.70it/s]
#
#
#
#
# 20it [00:14,  1.49it/s]
#
#
#
#
# 21it [00:15,  1.37it/s]
#
#
#
#
# 22it [00:15,  1.30it/s]
#
#
#
#
# 23it [00:16,  1.24it/s]
#
#
#
#
# 24it [00:17,  1.19it/s]
#
#
#
#
# 25it [00:17,  1.57it/s]
#
#
#
#
# 27it [00:18,  1.79it/s]
#
#
#
#
# 28it [00:19,  1.55it/s]
#
#
#
#
# 30it [00:20,  1.77it/s]
#
#
#
#
# 31it [00:21,  1.51it/s]
#
#
#
#
# 32it [00:22,  1.37it/s]
#
#
#
#
# 33it [00:23,  1.29it/s]
#
#
#
#
# 34it [00:24,  1.22it/s]
#
#
#
#
# 36it [00:25,  1.52it/s]
#
#
#
#
# 37it [00:26,  1.41it/s]
#
#
#
#
# 38it [00:27,  1.33it/s]
#
#
#
#
# 39it [00:27,  1.28it/s]
#
#
#
#
# 40it [00:28,  1.23it/s]
#
#
#
#
# 41it [00:29,  1.18it/s]
#
#
#
#
# 43it [00:30,  1.49it/s]
#
#
#
#
# 45it [00:31,  1.71it/s]
#
#
#
#
# 46it [00:32,  1.54it/s]
#
#
#
#
# 47it [00:33,  1.42it/s]
#
#
#
#
# 48it [00:34,  1.33it/s]
#
#
#
#
# 50it [00:34,  2.12it/s]
#
#
#
#
# 51it [00:35,  1.74it/s]
#
#
#
#
# 52it [00:36,  1.53it/s]
#
#
#
#
# 53it [00:37,  1.40it/s]
#
#
#
#
# 54it [00:37,  1.31it/s]
#
#
#
#
# 55it [00:38,  1.25it/s]
#
#
#
#
# 56it [00:39,  1.22it/s]
#
#
#
#
# 57it [00:40,  1.19it/s]
#
#
#
#
# 58it [00:41,  1.17it/s]
#
#
#
#
# 59it [00:42,  1.12it/s]
#
#
#
#
# 60it [00:43,  1.12it/s]
#
#
#
#
# 61it [00:44,  1.12it/s]
#
#
#
#
# 62it [00:45,  1.12it/s]
#
#
#
#
# 63it [00:46,  1.13it/s]
#
#
#
#
# 64it [00:47,  1.04it/s]
#
#
#
#
# 65it [00:48,  1.02s/it]
#
#
#
#
# 66it [00:49,  1.07s/it]
#
#
#
#
# 68it [00:50,  1.20it/s]
#
#
#
#
# 69it [00:51,  1.18it/s]
#
#
#
#
# 70it [00:52,  1.17it/s]
#
#
#
#
# 71it [00:52,  1.53it/s]
#
#
#
#
# 72it [00:53,  1.39it/s]
#
#
#
#
# 73it [00:53,  1.82it/s]
#
#
#
#
# 74it [00:54,  1.48it/s]
#
#
#
#
# 75it [00:55,  1.35it/s]
#
#
#
#
# 76it [00:56,  1.27it/s]
#
#
#
#
# 78it [00:57,  1.58it/s]
#
#
#
#
# 80it [00:58,  1.78it/s]
#
#
#
#
# 81it [00:59,  1.57it/s]
#
#
#
#
# 82it [01:00,  1.33it/s]
#
#
#
#
# 83it [01:01,  1.17it/s]
#
#
#
#
# 84it [01:02,  1.07it/s]
#
#
#
#
# 85it [01:03,  1.01it/s]
#
#
#
#
# 86it [01:04,  1.03it/s]
#
#
#
#
# 87it [01:05,  1.06it/s]
#
#
#
#
# 89it [01:05,  1.82it/s]
#
#
#
#
# 90it [01:06,  1.58it/s]
#
#
#
#
# 91it [01:07,  1.40it/s]
#
#
#
#
# 92it [01:08,  1.30it/s]
#
#
#
#
# 93it [01:09,  1.24it/s]
#
#
#
#
# 94it [01:10,  1.20it/s]
#
#
#
#
# 96it [01:11,  1.51it/s]
#
#
#
#
# 97it [01:11,  1.39it/s]
#
#
#
#
# 98it [01:12,  1.31it/s]
#
#
#
#
# 99it [01:13,  1.24it/s]
#
#
#
#
# 100it [01:14,  1.21it/s]
#
#
#
#
# 101it [01:15,  1.18it/s]
#
#
#
#
# 102it [01:16,  1.17it/s]
#
#
#
#
# 103it [01:17,  1.16it/s]
#
#
#
#
# 104it [01:18,  1.15it/s]
#
#
#
#
# 105it [01:18,  1.55it/s]
#
#
#
#
# 106it [01:19,  1.40it/s]
#
#
#
#
# 108it [01:20,  1.70it/s]
#
#
#
#
# 109it [01:20,  1.51it/s]
#
#
#
#
# 110it [01:21,  1.35it/s]
#
#
#
#
# 111it [01:22,  1.27it/s]
#
#
#
#
# 112it [01:23,  1.22it/s]
#
#
#
#
# 113it [01:24,  1.19it/s]
#
#
#
#
# 114it [01:25,  1.17it/s]
#
#
#
#
# 115it [01:26,  1.15it/s]
#
#
#
#
# 116it [01:27,  1.14it/s]
#
#
#
#
# 117it [01:28,  1.11it/s]
#
#
#
#
# 118it [01:29,  1.12it/s]
#
#
#
#
# 119it [01:29,  1.12it/s]
#
#
#
#
# 120it [01:30,  1.12it/s]
#
#
#
#
# 121it [01:31,  1.12it/s]
#
#
#
#
# 122it [01:32,  1.13it/s]
#
#
#
#
# 123it [01:33,  1.13it/s]
#
#
#
#
# 124it [01:34,  1.13it/s]
#
#
#
#
# 125it [01:35,  1.12it/s]
#
#
#
#
# 126it [01:36,  1.11it/s]
#
#
#
#
# 127it [01:37,  1.07it/s]
#
#
#
#
# 128it [01:38,  1.04it/s]
#
#
#
#
# 129it [01:39,  1.06it/s]
#
#
#
#
# 131it [01:40,  1.29it/s]
#
#
#
#
# 132it [01:41,  1.15it/s]
#
#
#
#
# 133it [01:42,  1.06it/s]
#
#
#
#
# 135it [01:43,  1.27it/s]
#
#
#
#
# 136it [01:44,  1.24it/s]
#
#
#
#
# 137it [01:45,  1.21it/s]
#
#
#
#
# 138it [01:46,  1.17it/s]
#
#
#
#
# 139it [01:47,  1.15it/s]
#
#
#
#
# 140it [01:48,  1.10it/s]
#
#
#
#
# 141it [01:49,  1.09it/s]
#
#
#
#
# 142it [01:50,  1.09it/s]
#
#
#
#
# 143it [01:51,  1.09it/s]
#
#
#
#
# 144it [01:52,  1.10it/s]
#
#
#
#
# 147it [01:53,  1.75it/s]
#
#
#
#
# 148it [01:53,  1.56it/s]
#
#
#
#
# 149it [01:54,  1.43it/s]
#
#
#
#
# 150it [01:55,  1.35it/s]
#
#
#
#
# 151it [01:56,  1.29it/s]
#
#
#
#
# 152it [01:57,  1.19it/s]
#
#
#
#
# 153it [01:58,  1.16it/s]
#
#
#
#
# 155it [01:59,  1.47it/s]
#
#
#
#
# 156it [02:00,  1.37it/s]
#
#
#
#
# 157it [02:01,  1.29it/s]
#
#
#
#
# 158it [02:02,  1.13it/s]
#
#
#
#
# 159it [02:03,  1.04it/s]
#
#
#
#
# 161it [02:04,  1.26it/s]
#
#
#
#
# 162it [02:05,  1.12it/s]
#
#
#
#
# 163it [02:06,  1.11it/s]
#
#
#
#
# 164it [02:07,  1.10it/s]
#
#
#
#
# 166it [02:08,  1.41it/s]
#
#
#
#
# 167it [02:09,  1.33it/s]
#
#
#
#
# 169it [02:10,  1.60it/s]
#
#
#
#
# 170it [02:11,  1.46it/s]
#
#
#
#
# 172it [02:12,  1.69it/s]
#
#
#
#
# 173it [02:13,  1.53it/s]
#
#
#
#
# 174it [02:13,  1.41it/s]
#
#
#
#
# 175it [02:14,  1.33it/s]
#
#
#
#
# 176it [02:15,  1.26it/s]
#
#
#
#
# 177it [02:16,  1.22it/s]
#
#
#
#
# 178it [02:17,  1.19it/s]
#
#
#
#
# 179it [02:18,  1.17it/s]
#
#
#
#
# 180it [02:19,  1.12it/s]
#
#
#
#
# 181it [02:20,  1.11it/s]
#
#
#
#
# 182it [02:21,  1.10it/s]
#
#
#
#
# 183it [02:22,  1.11it/s]
#
#
#
#
# 184it [02:22,  1.48it/s]
#
#
#
#
# 185it [02:23,  1.35it/s]
#
#
#
#
# 186it [02:23,  1.78it/s]
#
#
#
#
# 187it [02:24,  1.38it/s]
#
#
#
#
# 189it [02:25,  1.51it/s]
#
#
#
#
# 191it [02:26,  1.58it/s]
#
#
#
#
# 192it [02:27,  1.33it/s]
#
#
#
#
# 194it [02:29,  1.44it/s]
#
#
#
#
# 195it [02:30,  1.26it/s]
#
#
#
#
# 196it [02:31,  1.14it/s]
#
#
#
#
# 197it [02:32,  1.07it/s]
#
#
#
#
# 199it [02:33,  1.38it/s]
#
#
#
#
# 201it [02:34,  1.61it/s]
#
#
#
#
# 202it [02:35,  1.48it/s]
#
#
#
#
# 203it [02:36,  1.38it/s]
#
#
#
#
# 204it [02:36,  1.31it/s]
#
#
#
#
# 205it [02:37,  1.26it/s]
#
#
#
#
# 206it [02:38,  1.22it/s]
#
#
#
#
# 207it [02:39,  1.19it/s]
#
#
#
#
# 208it [02:40,  1.17it/s]
#
#
#
#
# 210it [02:41,  1.50it/s]
#
#
#
#
# 211it [02:42,  1.39it/s]
#
#
#
#
# 212it [02:43,  1.27it/s]
#
#
#
#
# 213it [02:44,  1.21it/s]
#
#
#
#
# 214it [02:45,  1.17it/s]
#
#
#
#
# 215it [02:46,  1.14it/s]
#
#
#
#
# 216it [02:46,  1.13it/s]
#
#
#
#
# 217it [02:47,  1.13it/s]
#
#
#
#
# 218it [02:48,  1.12it/s]
#
#
#
#
# 219it [02:49,  1.11it/s]
#
#
#
#
# 222it [02:50,  1.70it/s]
#
#
#
#
# 223it [02:51,  1.40it/s]
#
#
#
#
# 224it [02:53,  1.23it/s]
#
#
#
#
# 225it [02:54,  1.11it/s]
#
#
#
#
# 226it [02:55,  1.07it/s]
#
#
#
#
# 228it [02:56,  1.37it/s]
#
#
#
#
# 229it [02:57,  1.30it/s]
#
#
#
#
# 230it [02:57,  1.25it/s]
#
#
#
#
# 231it [02:58,  1.22it/s]
#
#
#
#
# 232it [02:59,  1.19it/s]
#
#
#
#
# 233it [03:00,  1.17it/s]
#
#
#
#
# 234it [03:00,  1.55it/s]
#
#
#
#
# 235it [03:01,  1.39it/s]
#
#
#
#
# 236it [03:02,  1.30it/s]
#
#
#
#
# 237it [03:03,  1.25it/s]
#
#
#
#
# 238it [03:04,  1.21it/s]
#
#
#
#
# 240it [03:05,  1.54it/s]
#
#
#
#
# 241it [03:06,  1.41it/s]
#
#
#
#
# 244it [03:06,  2.01it/s]
#
#
#
#
# 245it [03:07,  1.74it/s]
#
#
#
#
# 247it [03:08,  1.75it/s]
#
#
#
#
# 249it [03:10,  1.69it/s]
#
#
#
#
# 250it [03:11,  1.41it/s]
#
#
#
#
# 251it [03:11,  1.69it/s]
#
#
#
#
# 252it [03:12,  1.41it/s]
#
#
#
#
# 253it [03:12,  1.76it/s]
#
#
#
#
# 254it [03:13,  1.50it/s]
#
#
#
#
# 255it [03:14,  1.36it/s]
#
#
#
#
# 256it [03:15,  1.27it/s]
#
#
#
#
# 257it [03:16,  1.22it/s]
#
#
#
#
# 258it [03:17,  1.19it/s]
#
#
#
#
# 259it [03:18,  1.16it/s]
#
#
#
#
# 260it [03:19,  1.14it/s]
#
#
#
#
# 261it [03:20,  1.12it/s]
#
#
#
#
# 262it [03:21,  1.10it/s]
#
#
#
#
# 263it [03:22,  1.06it/s]
#
#
#
#
# 264it [03:22,  1.08it/s]
#
#
#
#
# 265it [03:23,  1.46it/s]
#
#
#
#
# 266it [03:23,  1.34it/s]
#
#
#
#
# 267it [03:24,  1.27it/s]
#
#
#
#
# 268it [03:25,  1.23it/s]
#
#
#
#
# 269it [03:26,  1.20it/s]
#
#
#
#
# 270it [03:27,  1.18it/s]
#
#
#
#
# 271it [03:27,  1.58it/s]
#
#
#
#
# 272it [03:28,  1.42it/s]
#
#
#
#
# 273it [03:29,  1.32it/s]
#
#
#
#
# 274it [03:30,  1.21it/s]
#
#
#
#
# 275it [03:31,  1.09it/s]
#
#
#
#
# 276it [03:32,  1.01it/s]
#
#
#
#
# 277it [03:32,  1.35it/s]
#
#
#
#
# 278it [03:32,  1.78it/s]
#
#
#
#
# 279it [03:34,  1.36it/s]
#
#
#
#
# 280it [03:35,  1.25it/s]
#
#
#
#
# 281it [03:35,  1.21it/s]
#
#
#
#
# 282it [03:36,  1.18it/s]
#
#
#
#
# 284it [03:37,  1.44it/s]
#
#
#
#
# 285it [03:38,  1.80it/s]
#
#
#
#
# 286it [03:38,  1.53it/s]
#
#
#
#
# 287it [03:39,  1.38it/s]
#
#
#
#
# 288it [03:40,  1.28it/s]
#
#
#
#
# 289it [03:41,  1.22it/s]
#
#
#
#
# 290it [03:42,  1.18it/s]
#
#
#
#
# 291it [03:43,  1.13it/s]
#
#
#
#
# 292it [03:44,  1.03it/s]
#
#
#
#
# 293it [03:45,  1.02s/it]
#
#
#
#
# 296it [03:47,  1.49it/s]
#
#
#
#
# 297it [03:48,  1.28it/s]
#
#
#
#
# 298it [03:49,  1.15it/s]
#
#
#
#
# 299it [03:50,  1.05it/s]
#
#
#
#
# 300it [03:51,  1.01s/it]
#
#
#
#
# 301it [03:52,  1.02s/it]
#
#
#
#
# 302it [03:53,  1.01it/s]
#
#
#
#
# 304it [03:54,  1.33it/s]
#
#
#
#
# 305it [03:55,  1.26it/s]
#
#
#
#
# 306it [03:55,  1.60it/s]
#
#
#
#
# 307it [03:56,  1.42it/s]
#
#
#
#
# 308it [03:57,  1.31it/s]
#
#
#
#
# 310it [03:58,  1.60it/s]
#
#
#
#
# 311it [03:59,  1.44it/s]
#
#
#
#
# 312it [04:00,  1.35it/s]
#
#
#
#
# 313it [04:01,  1.25it/s]
#
#
#
#
# 314it [04:02,  1.11it/s]
#
#
#
#
# 315it [04:03,  1.02it/s]
#
#
#
#
# 316it [04:04,  1.04s/it]
#
#
#
#
# 317it [04:05,  1.09s/it]
#
#
#
#
# 318it [04:07,  1.13s/it]
#
#
#
#
# 319it [04:08,  1.15s/it]
#
#
#
#
# 320it [04:09,  1.16s/it]
#
#
#
#
# 321it [04:10,  1.11s/it]
#
#
#
#
# 322it [04:11,  1.05s/it]
#
#
#
#
# 323it [04:12,  1.01s/it]
#
#
#
#
# 324it [04:13,  1.02it/s]
#
#
#
#
# 325it [04:14,  1.05it/s]
#
#
#
#
# 326it [04:15,  1.02s/it]
#
#
#
#
# 327it [04:16,  1.11s/it]
#
#
#
#
# 328it [04:17,  1.14s/it]
#
#
#
#
# 330it [04:19,  1.15it/s]
#
#
#
#
# 331it [04:19,  1.13it/s]
#
#
#
#
# 332it [04:20,  1.11it/s]
#
#
#
#
# 334it [04:21,  1.41it/s]
#
#
#
#
# 335it [04:22,  1.32it/s]
#
#
#
#
# 336it [04:23,  1.21it/s]
#
#
#
#
# 338it [04:24,  1.38it/s]
#
#
#
#
# 339it [04:26,  1.21it/s]
#
#
#
#
# 340it [04:27,  1.10it/s]
#
#
#
#
# 341it [04:28,  1.08it/s]
#
#
#
#
# 342it [04:29,  1.08it/s]
#
#
#
#
# 343it [04:30,  1.08it/s]
#
#
#
#
# 344it [04:30,  1.09it/s]
#
#
#
#
# 345it [04:31,  1.09it/s]
#
#
#
#
# 347it [04:33,  1.32it/s]
#
#
#
#
# 348it [04:34,  1.16it/s]
#
#
#
#
# 349it [04:35,  1.04it/s]
#
#
#
#
# 350it [04:36,  1.00s/it]
#
#
#
#
# 351it [04:37,  1.03it/s]
#
#
#
#
# 353it [04:38,  1.35it/s]
#
#
#
#
# 354it [04:39,  1.29it/s]
#
#
#
#
# 356it [04:40,  1.54it/s]
#
#
#
#
# 357it [04:41,  1.41it/s]
#
#
#
#
# 358it [04:42,  1.23it/s]
#
#
#
#
# 359it [04:43,  1.11it/s]
#
#
#
#
# 360it [04:44,  1.03it/s]
#
#
#
#
# 361it [04:45,  1.00it/s]
#
#
#
#
# 363it [04:46,  1.32it/s]
#
#
#
#
# 364it [04:47,  1.26it/s]
#
#
#
#
# 365it [04:48,  1.22it/s]
#
#
#
#
# 366it [04:49,  1.19it/s]
#
#
#
#
# 367it [04:50,  1.13it/s]
#
#
#
#
# 368it [04:51,  1.04it/s]
#
#
#
#
# 369it [04:52,  1.01s/it]
#
#
#
#
# 370it [04:53,  1.05s/it]
#
#
#
#
# 371it [04:54,  1.04s/it]
#
#
#
#
# 372it [04:55,  1.01it/s]
#
#
#
#
# 373it [04:56,  1.05it/s]
#
#
#
#
# 374it [04:57,  1.07it/s]
#
#
#
#
# 376it [04:58,  1.41it/s]
#
#
#
#
# 377it [04:59,  1.27it/s]
#
#
#
#
# 378it [05:00,  1.13it/s]
#
#
#
#
# 379it [05:01,  1.01s/it]
#
#
#
#
# 380it [05:02,  1.06s/it]
#
#
#
#
# 382it [05:03,  1.25it/s]
#
#
#
#
# 383it [05:04,  1.22it/s]
#
#
#
#
# 384it [05:05,  1.18it/s]
#
#
#
#
# 385it [05:06,  1.17it/s]
#
#
#
#
# 386it [05:07,  1.16it/s]
#
#
#
#
# 387it [05:08,  1.04it/s]
#
#
#
#
# 388it [05:09,  1.04s/it]
#
#
#
#
# 389it [05:11,  1.09s/it]
#
#
#
#
# 390it [05:12,  1.13s/it]
#
#
#
#
# 391it [05:13,  1.12s/it]
#
#
#
#
# 392it [05:14,  1.13s/it]
#
#
#
#
# 394it [05:15,  1.14it/s]
#
#
#
#
# 396it [05:16,  1.34it/s]
#
#
#
#
# 397it [05:17,  1.28it/s]
#
#
#
#
# 400it [05:18,  1.84it/s]
#
#
#
#
# 401it [05:19,  1.65it/s]
#
#
#
#
# 402it [05:20,  1.49it/s]
#
#
#
#
# 403it [05:21,  1.39it/s]
#
#
#
#
# 404it [05:22,  1.21it/s]
#
#
#
#
# 405it [05:23,  1.02it/s]
#
#
#
#
# 407it [05:24,  1.33it/s]
#
#
#
#
# 410it [05:25,  1.81it/s]
#
#
#
#
# 413it [05:27,  1.99it/s]
#
#
#
#
# 414it [05:28,  1.65it/s]
#
#
#
#
# 415it [05:29,  1.40it/s]
#
#
#
#
# 416it [05:30,  1.24it/s]
#
#
#
#
# 417it [05:31,  1.08it/s]
#
#
#
#
# 418it [05:33,  1.04s/it]
#
#
#
#
# 419it [05:34,  1.10s/it]
#
#
#
#
# 420it [05:35,  1.08s/it]
#
#
#
#
# 421it [05:36,  1.04s/it]
#
#
#
#
# 422it [05:37,  1.01s/it]
#
#
#
#
# 423it [05:38,  1.01it/s]
#
#
#
#
# 424it [05:39,  1.03s/it]
#
#
#
#
# 425it [05:40,  1.11s/it]
#
#
#
#
# 426it [05:42,  1.17s/it]
#
#
#
#
# 427it [05:43,  1.17s/it]
#
#
#
#
# 428it [05:44,  1.09s/it]
#
#
#
#
# 430it [05:45,  1.25it/s]
#
#
#
#
# 432it [05:45,  1.52it/s]
#
#
#
#
# 433it [05:46,  1.41it/s]
#
#
#
#
# 434it [05:47,  1.30it/s]
#
#
#
#
# 435it [05:48,  1.16it/s]
#
#
#
#
# 436it [05:50,  1.07it/s]
#
#
#
#
# 437it [05:50,  1.39it/s]
#
#
#
#
# 438it [05:51,  1.12it/s]
#
#
#
#
# 439it [05:52,  1.08it/s]
#
#
#
#
# 441it [05:53,  1.36it/s]
#
#
#
#
# 442it [05:54,  1.26it/s]
#
#
#
#
# 444it [05:55,  1.50it/s]
#
#
#
#
# 446it [05:56,  1.68it/s]
#
#
#
#
# 447it [05:56,  2.01it/s]
#
#
#
#
# 448it [05:57,  1.69it/s]
#
#
#
#
# 449it [05:58,  1.49it/s]
#
#
#
#
# 450it [05:58,  1.89it/s]
#
#
#
#
# 451it [05:59,  1.58it/s]
#
#
#
#
# 452it [06:00,  1.40it/s]
#
#
#
#
# 453it [06:01,  1.23it/s]
#
#
#
#
# 454it [06:02,  1.09it/s]
#
#
#
#
# 455it [06:03,  1.01it/s]
#
#
#
#
# 456it [06:04,  1.06s/it]
#
#
#
#
# 457it [06:05,  1.03s/it]
#
#
#
#
# 458it [06:06,  1.01it/s]
#
#
#
#
# 459it [06:07,  1.04it/s]
#
#
#
#
# 461it [06:08,  1.37it/s]
#
#
#
#
# 462it [06:09,  1.27it/s]
#
#
#
#
# 463it [06:10,  1.14it/s]
#
#
#
#
# 464it [06:11,  1.05it/s]
#
#
#
#
# 465it [06:13,  1.05s/it]
#
#
#
#
# 467it [06:14,  1.20it/s]
#
#
#
#
# 468it [06:15,  1.16it/s]
#
#
#
#
# 469it [06:16,  1.14it/s]
#
#
#
#
# 471it [06:17,  1.42it/s]
#
#
#
#
# 472it [06:18,  1.35it/s]
#
#
#
#
# 473it [06:18,  1.27it/s]
#
#
#
#
# 476it [06:19,  1.85it/s]
#
#
#
#
# 477it [06:20,  1.63it/s]
#
#
#
#
# 480it [06:21,  2.04it/s]
#
#
#
#
# 481it [06:22,  1.68it/s]
#
#
#
#
# 482it [06:23,  1.48it/s]
#
#
#
#
# 483it [06:24,  1.37it/s]
#
#
#
#
# 484it [06:25,  1.30it/s]
#
#
#
#
# 485it [06:26,  1.25it/s]
#
#
#
#
# 486it [06:27,  1.20it/s]
#
#
#
#
# 487it [06:28,  1.09it/s]
#
#
#
#
# 488it [06:29,  1.02it/s]
#
#
#
#
# 489it [06:30,  1.03s/it]
#
#
#
#
# 490it [06:32,  1.05s/it]
#
#
#
#
# 491it [06:32,  1.00it/s]
#
#
#
#
# 492it [06:33,  1.03it/s]
#
#
#
#
# 493it [06:34,  1.06it/s]
#
#
#
#
# 494it [06:35,  1.08it/s]
#
#
#
#
# 495it [06:36,  1.08it/s]
#
#
#
#
# 496it [06:37,  1.09it/s]
#
#
#
#
# 497it [06:38,  1.10it/s]
#
#
#
#
# 498it [06:39,  1.10it/s]
#
#
#
#
# 500it [06:40,  1.44it/s]
#
#
#
#
# 501it [06:40,  1.35it/s]
#
#
#
#
# 502it [06:41,  1.25it/s]
#
#
#
#
# 503it [06:42,  1.20it/s]
#
#
#
#
# 504it [06:43,  1.09it/s]
#
#
#
#
# 505it [06:44,  1.07it/s]
#
#
#
#
# 506it [06:45,  1.07it/s]
#
#
#
#
# 507it [06:46,  1.05it/s]
#
#
#
#
# 508it [06:47,  1.05it/s]
#
#
#
#
# 509it [06:48,  1.06it/s]
#
#
#
#
# 510it [06:49,  1.07it/s]
#
#
#
#
# 511it [06:50,  1.07it/s]
#
#
#
#
# 512it [06:51,  1.07it/s]
#
#
#
#
# 513it [06:52,  1.07it/s]
#
#
#
#
# 514it [06:53,  1.07it/s]
#
#
#
#
# 515it [06:54,  1.04it/s]
#
#
#
#
# 516it [06:55,  1.03s/it]
#
#
#
#
# 517it [06:56,  1.08s/it]
#
#
#
#
# 518it [06:58,  1.11s/it]
#
#
#
#
# 519it [06:59,  1.07s/it]
#
#
#
#
# 521it [06:59,  1.26it/s]
#
#
#
#
# 522it [07:00,  1.22it/s]
#
#
#
#
# 523it [07:01,  1.17it/s]
#
#
#
#
# 524it [07:02,  1.15it/s]
#
#
#
#
# 525it [07:02,  1.50it/s]
#
#
#
#
# 527it [07:03,  1.74it/s]
#
#
#
#
# 528it [07:04,  1.50it/s]
#
#
#
#
# 529it [07:05,  1.37it/s]
#
#
#
#
# 530it [07:06,  1.28it/s]
#
#
#
#
# 531it [07:07,  1.16it/s]
#
#
#
#
# 532it [07:08,  1.01it/s]
#
#
#
#
# 533it [07:10,  1.04s/it]
#
#
#
#
# 535it [07:11,  1.21it/s]
#
#
#
#
# 536it [07:12,  1.08it/s]
#
#
#
#
# 537it [07:13,  1.02it/s]
#
#
#
#
# 538it [07:14,  1.03s/it]
#
#
#
#
# 539it [07:15,  1.06s/it]
#
#
#
#
# 540it [07:16,  1.02s/it]
#
#
#
#
# 541it [07:17,  1.02it/s]
#
#
#
#
# 542it [07:18,  1.03it/s]
#
#
#
#
# 543it [07:19,  1.06it/s]
#
#
#
#
# 544it [07:20,  1.08it/s]
#
#
#
#
# 545it [07:21,  1.01it/s]
#
#
#
#
# 546it [07:22,  1.03s/it]
#
#
#
#
# 547it [07:23,  1.08s/it]
#
#
#
#
# 548it [07:25,  1.10s/it]
#
#
#
#
# 549it [07:25,  1.04s/it]
#
#
#
#
# 550it [07:26,  1.00s/it]
#
#
#
#
# 551it [07:26,  1.36it/s]
#
#
#
#
# 552it [07:27,  1.28it/s]
#
#
#
#
# 553it [07:28,  1.23it/s]
#
#
#
#
# 554it [07:28,  1.66it/s]
#
#
#
#
# 555it [07:29,  1.46it/s]
#
#
#
#
# 556it [07:30,  1.33it/s]
#
#
#
#
# 557it [07:31,  1.26it/s]
#
#
#
#
# 559it [07:32,  1.52it/s]
#
#
#
#
# 561it [07:33,  1.74it/s]
#
#
#
#
# 562it [07:34,  1.46it/s]
#
#
#
#
# 563it [07:35,  1.23it/s]
#
#
#
#
# 565it [07:36,  1.37it/s]
#
#
#
#
# 566it [07:38,  1.19it/s]
#
#
#
#
# 567it [07:39,  1.09it/s]
#
#
#
#
# 568it [07:40,  1.03it/s]
#
#
#
#
# 569it [07:41,  1.09s/it]
#
#
#
#
# 570it [07:42,  1.10s/it]
#
#
#
#
# 572it [07:43,  1.21it/s]
#
#
#
#
# 574it [07:44,  1.87it/s]
#
#
#
#
# 575it [07:45,  1.56it/s]
#
#
#
#
# 577it [07:46,  1.41it/s]
#
#
#
#
# 578it [07:47,  1.22it/s]
#
#
#
#
# 579it [07:49,  1.11it/s]
#
#
#
#
# 580it [07:49,  1.39it/s]
#
#
#
#
# 581it [07:49,  1.73it/s]
#
#
#
#
# 582it [07:50,  1.23it/s]
#
#
#
#
# 583it [07:52,  1.11s/it]
#
#
#
#
# 584it [07:54,  1.40s/it]
#
#
#
#
# 585it [07:57,  1.63s/it]
#
#
#
#
# 586it [08:00,  2.11s/it]
#
#
#
#
# 587it [08:01,  1.96s/it]
#
#
#
#
# 588it [08:03,  1.86s/it]
#
#
#
#
# 589it [08:05,  1.82s/it]
#
#
#
#
# 590it [08:07,  1.89s/it]
#
#
#
#
# 591it [08:09,  1.95s/it]
#
#
#
#
# 592it [08:11,  1.98s/it]
#
#
#
#
# 593it [08:13,  2.01s/it]
#
#
#
#
# 594it [08:15,  1.90s/it]
#
#
#
#
# 596it [08:16,  1.40s/it]
#
#
#
#
# 600it [08:18,  1.19it/s]
#
#
#
#
# 602it [08:20,  1.19it/s]
#
#
#
#
# 604it [08:20,  1.62it/s]
#
#
#
#
# 605it [08:22,  1.07it/s]
#
#
#
#
# 606it [08:24,  1.15s/it]
#
#
#
#
# 607it [08:26,  1.35s/it]
#
#
#
#
# 608it [08:29,  1.57s/it]
#
#
#
#
# 609it [08:31,  1.71s/it]
#
#
#
#
# 610it [08:32,  1.70s/it]
#
#
#
#
# 611it [08:34,  1.69s/it]
#
#
#
#
# 612it [08:36,  1.68s/it]
#
#
#
#
# 613it [08:37,  1.67s/it]
#
#
#
#
# 614it [08:39,  1.66s/it]
#
#
#
#
# 615it [08:41,  1.72s/it]
#
#
#
#
# 616it [08:41,  1.26s/it]
#
#
#
#
# 617it [08:43,  1.45s/it]
#
#
#
#
# 618it [08:45,  1.64s/it]
#
#
#
#
# 619it [08:47,  1.80s/it]
#
#
#
#
# 620it [08:49,  1.88s/it]
#
#
#
#
# 621it [08:51,  1.96s/it]
#
#
#
#
# 623it [08:53,  1.50s/it]
#
#
#
#
# 624it [08:54,  1.16s/it]
#
#
#
#
# 625it [08:55,  1.25s/it]
#
#
#
#
# 626it [08:57,  1.35s/it]
#
#
#
#
# 627it [08:58,  1.43s/it]
#
#
#
#
# 629it [08:58,  1.22it/s]
#
#
#
#
# 630it [09:00,  1.03it/s]
#
#
#
#
# 631it [09:02,  1.15s/it]
#
#
#
#
# 632it [09:04,  1.37s/it]
#
#
#
#
# 633it [09:05,  1.42s/it]
#
#
#
#
# 634it [09:07,  1.45s/it]
#
#
#
#
# 635it [09:09,  1.63s/it]
#
#
#
#
# 636it [09:11,  1.76s/it]
#
#
#
#
# 637it [09:12,  1.71s/it]
#
#
#
#
# 640it [09:14,  1.10s/it]
#
#
#
#
# 641it [09:16,  1.23s/it]
#
#
#
#
# 642it [09:18,  1.34s/it]
#
#
#
#
# 643it [09:18,  1.04s/it]
#
#
#
#
# 644it [09:19,  1.18s/it]
#
#
#
#
# 646it [09:21,  1.04s/it]
#
#
#
#
# 647it [09:23,  1.18s/it]
#
#
#
#
# 648it [09:24,  1.31s/it]
#
#
#
#
# 649it [09:28,  1.82s/it]
#
#
#
#
# 650it [09:28,  1.40s/it]
#
#
#
#
# 651it [09:29,  1.45s/it]
#
#
#
#
# 652it [09:31,  1.49s/it]
#
#
#
#
# 653it [09:33,  1.52s/it]
#
#
#
#
# 654it [09:35,  1.67s/it]
#
#
#
#
# 655it [09:37,  1.81s/it]
#
#
#
#
# 656it [09:39,  1.79s/it]
#
#
#
#
# 657it [09:40,  1.76s/it]
#
#
#
#
# 658it [09:41,  1.60s/it]
#
#
#
#
# 659it [09:43,  1.48s/it]
#
#
#
#
# 660it [09:44,  1.53s/it]
#
#
#
#
# 661it [09:44,  1.11s/it]
#
#
#
#
# 662it [09:46,  1.22s/it]
#
#
#
#
# 663it [09:48,  1.36s/it]
#
#
#
#
# 664it [09:49,  1.45s/it]
#
#
#
#
# 665it [09:51,  1.54s/it]
#
#
#
#
# 666it [09:53,  1.71s/it]
#
#
#
#
# 668it [09:55,  1.40s/it]
#
#
#
#
# 669it [09:57,  1.50s/it]
#
#
#
#
# 670it [09:59,  1.55s/it]
#
#
#
#
# 671it [10:00,  1.59s/it]
#
#
#
#
# 672it [10:02,  1.62s/it]
#
#
#
#
# 673it [10:04,  1.64s/it]
#
#
#
#
# 674it [10:05,  1.66s/it]
#
#
#
#
# 675it [10:07,  1.66s/it]
#
#
#
#
# 677it [10:09,  1.31s/it]
#
#
#
#
# 678it [10:11,  1.54s/it]
#
#
#
#
# 680it [10:13,  1.36s/it]
#
#
#
#
# 681it [10:16,  1.54s/it]
#
#
#
#
# 682it [10:18,  1.68s/it]
#
#
#
#
# 683it [10:20,  1.79s/it]
#
#
#
#
# 684it [10:20,  1.35s/it]
#
#
#
#
# 685it [10:22,  1.51s/it]
#
#
#
#
# 688it [10:23,  1.02it/s]
#
#
#
#
# 693it [10:25,  1.65it/s]
#
#
#
#
# 694it [10:27,  1.34it/s]
#
#
#
#
# 695it [10:28,  1.11it/s]
#
#
#
#
# 696it [10:30,  1.05s/it]
#
#
#
#
# 697it [10:32,  1.25s/it]
#
#
#
#
# 698it [10:34,  1.46s/it]
#
#
#
#
# 699it [10:36,  1.60s/it]
#
#
#
#
# 700it [10:38,  1.75s/it]
#
#
#
#
# 701it [10:40,  1.78s/it]
#
#
#
#
# 702it [10:42,  1.73s/it]
#
#
#
#
# 703it [10:44,  1.74s/it]
#
#
#
#
# 705it [10:45,  1.34s/it]
#
#
#
#
# 706it [10:47,  1.44s/it]
#
#
#
#
# 707it [10:49,  1.50s/it]
#
#
#
#
# 708it [10:50,  1.54s/it]
#
#
#
#
# 710it [10:52,  1.23s/it]
#
#
#
#
# 711it [10:54,  1.32s/it]
#
#
#
#
# 713it [10:55,  1.11s/it]
#
#
#
#
# 714it [10:55,  1.13it/s]
#
#
#
#
# 715it [10:57,  1.03s/it]
#
#
#
#
# 717it [10:59,  1.01s/it]
#
#
#
#
# 718it [11:01,  1.25s/it]
#
#
#
#
# 719it [11:03,  1.47s/it]
#
#
#
#
# 720it [11:05,  1.62s/it]
#
#
#
#
# 721it [11:07,  1.68s/it]
#
#
#
#
# 722it [11:09,  1.69s/it]
#
#
#
#
# 724it [11:10,  1.31s/it]
#
#
#
#
# 725it [11:12,  1.39s/it]
#
#
#
#
# 726it [11:14,  1.45s/it]
#
#
#
#
# 727it [11:15,  1.53s/it]
#
#
#
#
# 728it [11:17,  1.69s/it]
#
#
#
#
# 731it [11:20,  1.16s/it]
#
#
#
#
# 732it [11:22,  1.35s/it]
#
#
#
#
# 734it [11:24,  1.23s/it]
#
#
#
#
# 735it [11:25,  1.31s/it]
#
#
#
#
# 736it [11:27,  1.37s/it]
#
#
#
#
# 737it [11:29,  1.45s/it]
#
#
#
#
# 738it [11:30,  1.52s/it]
#
#
#
#
# 740it [11:32,  1.23s/it]
#
#
#
#
# 741it [11:34,  1.33s/it]
#
#
#
#
# 742it [11:35,  1.41s/it]
#
#
#
#
# 743it [11:37,  1.47s/it]
#
#
#
#
# 745it [11:39,  1.19s/it]
#
#
#
#
# 746it [11:40,  1.28s/it]
#
#
#
#
# 747it [11:42,  1.38s/it]
#
#
#
#
# 748it [11:44,  1.57s/it]
#
#
#
#
# 749it [11:46,  1.70s/it]
#
#
#
#
# 750it [11:48,  1.80s/it]
#
#
#
#
# 751it [11:50,  1.75s/it]
#
#
#
#
# 752it [11:50,  1.28s/it]
#
#
#
#
# 753it [11:51,  1.25s/it]
#
#
#
#
# 754it [11:52,  1.35s/it]
#
#
#
#
# 755it [11:54,  1.42s/it]
#
#
#
#
# 757it [11:56,  1.13s/it]
#
#
#
#
# 758it [11:57,  1.25s/it]
#
#
#
#
# 759it [11:59,  1.33s/it]
#
#
#
#
# 760it [12:01,  1.52s/it]
#
#
#
#
# 762it [12:03,  1.30s/it]
#
#
#
#
# 764it [12:03,  1.21it/s]
#
#
#
#
# 765it [12:05,  1.01s/it]
#
#
#
#
# 766it [12:06,  1.17s/it]
#
#
#
#
# 767it [12:08,  1.29s/it]
#
#
#
#
# 768it [12:08,  1.01it/s]
#
#
#
#
# 769it [12:10,  1.13s/it]
#
#
#
#
# 770it [12:11,  1.28s/it]
#
#
#
#
# 771it [12:13,  1.38s/it]
#
#
#
#
# 772it [12:15,  1.45s/it]
#
#
#
#
# 773it [12:16,  1.49s/it]
#
#
#
#
# 774it [12:18,  1.54s/it]
#
#
#
#
# 775it [12:19,  1.55s/it]
#
#
#
#
# 776it [12:21,  1.56s/it]
#
#
#
#
# 777it [12:23,  1.69s/it]
#
#
#
#
# 778it [12:25,  1.84s/it]
#
#
#
#
# 780it [12:27,  1.47s/it]
#
#
#
#
# 781it [12:29,  1.62s/it]
#
#
#
#
# 782it [12:31,  1.65s/it]
#
#
#
#
# 783it [12:31,  1.23s/it]
#
#
#
#
# 784it [12:31,  1.09it/s]
#
#
#
#
# 787it [12:33,  1.51it/s]
#
#
#
#
# 788it [12:34,  1.18it/s]
#
#
#
#
# 789it [12:36,  1.02s/it]
#
#
#
#
# 790it [12:37,  1.16s/it]
#
#
#
#
# 791it [12:39,  1.29s/it]
#
#
#
#
# 792it [12:39,  1.02it/s]
#
#
#
#
# 793it [12:41,  1.13s/it]
#
#
#
#
# 794it [12:42,  1.28s/it]
#
#
#
#
# 795it [12:44,  1.38s/it]
#
#
#
#
# 796it [12:46,  1.45s/it]
#
#
#
#
# 797it [12:47,  1.51s/it]
#
#
#
#
# 798it [12:49,  1.56s/it]
#
#
#
#
# 799it [12:51,  1.57s/it]
#
#
#
#
# 801it [12:52,  1.21s/it]
#
#
#
#
# 802it [12:54,  1.42s/it]
#
#
#
#
# 803it [12:56,  1.59s/it]
#
#
#
#
# 804it [12:58,  1.72s/it]
#
#
#
#
# 805it [13:00,  1.82s/it]
#
#
#
#
# 806it [13:02,  1.89s/it]
#
#
#
#
# 807it [13:05,  1.94s/it]
#
#
#
#
# 809it [13:06,  1.48s/it]
#
#
#
#
# 810it [13:08,  1.50s/it]
#
#
#
#
# 811it [13:10,  1.53s/it]
#
#
#
#
# 812it [13:11,  1.56s/it]
#
#
#
#
# 813it [13:13,  1.59s/it]
#
#
#
#
# 815it [13:15,  1.25s/it]
#
#
#
#
# 816it [13:16,  1.35s/it]
#
#
#
#
# 817it [13:18,  1.43s/it]
#
#
#
#
# 818it [13:18,  1.08s/it]
#
#
#
#
# 819it [13:19,  1.20s/it]
#
#
#
#
# 820it [13:21,  1.33s/it]
#
#
#
#
# 821it [13:23,  1.41s/it]
#
#
#
#
# 822it [13:25,  1.57s/it]
#
#
#
#
# 823it [13:27,  1.72s/it]
#
#
#
#
# 824it [13:29,  1.82s/it]
#
#
#
#
# 825it [13:31,  1.90s/it]
#
#
#
#
# 826it [13:33,  1.88s/it]
#
#
#
#
# 828it [13:34,  1.38s/it]
#
#
#
#
# 829it [13:36,  1.43s/it]
#
#
#
#
# 832it [13:38,  1.04it/s]
#
#
#
#
# 833it [13:39,  1.09s/it]
#
#
#
#
# 834it [13:41,  1.21s/it]
#
#
#
#
# 836it [13:42,  1.06s/it]
#
#
#
#
# 837it [13:44,  1.19s/it]
#
#
#
#
# 838it [13:46,  1.30s/it]
#
#
#
#
# 839it [13:47,  1.39s/it]
#
#
#
#
# 840it [13:49,  1.47s/it]
#
#
#
#
# 842it [13:51,  1.19s/it]
#
#
#
#
# 843it [13:52,  1.30s/it]
#
#
#
#
# 844it [13:54,  1.37s/it]
#
#
#
#
# 845it [13:56,  1.54s/it]
#
#
#
#
# 847it [13:58,  1.32s/it]
#
#
#
#
# 848it [14:00,  1.50s/it]
#
#
#
#
# 849it [14:02,  1.65s/it]
#
#
#
#
# 851it [14:04,  1.33s/it]
#
#
#
#
# 852it [14:06,  1.39s/it]
#
#
#
#
# 853it [14:07,  1.43s/it]
#
#
#
#
# 854it [14:09,  1.49s/it]
#
#
#
#
# 855it [14:10,  1.54s/it]
#
#
#
#
# 856it [14:12,  1.58s/it]
#
#
#
#
# 857it [14:14,  1.60s/it]
#
#
#
#
# 858it [14:15,  1.62s/it]
#
#
#
#
# 859it [14:17,  1.62s/it]
#
#
#
#
# 860it [14:19,  1.64s/it]
#
#
#
#
# 861it [14:20,  1.64s/it]
#
#
#
#
# 862it [14:22,  1.63s/it]
#
#
#
#
# 863it [14:24,  1.61s/it]
#
#
#
#
# 864it [14:25,  1.61s/it]
#
#
#
#
# 865it [14:27,  1.75s/it]
#
#
#
#
# 866it [14:27,  1.27s/it]
#
#
#
#
# 867it [14:29,  1.47s/it]
#
#
#
#
# 870it [14:31,  1.03s/it]
#
#
#
#
# 871it [14:33,  1.25s/it]
#
#
#
#
# 873it [14:35,  1.10s/it]
#
#
#
#
# 874it [14:37,  1.23s/it]
#
#
#
#
# 875it [14:39,  1.33s/it]
#
#
#
#
# 876it [14:40,  1.41s/it]
#
#
#
#
# 877it [14:42,  1.47s/it]
#
#
#
#
# 878it [14:43,  1.51s/it]
#
#
#
#
# 879it [14:45,  1.55s/it]
#
#
#
#
# 880it [14:47,  1.59s/it]
#
#
#
#
# 881it [14:48,  1.61s/it]
#
#
#
#
# 882it [14:50,  1.60s/it]
#
#
#
#
# 883it [14:52,  1.60s/it]
#
#
#
#
# 884it [14:54,  1.74s/it]
#
#
#
#
# 885it [14:56,  1.85s/it]
#
#
#
#
# 886it [15:03,  3.43s/it]
#
#
#
#
# 887it [15:05,  2.88s/it]
#
#
#
#
# 888it [15:06,  2.58s/it]
#
#
#
#
# 889it [15:08,  2.43s/it]
#
#
#
#
# 890it [15:09,  1.75s/it]
#
#
#
#
# 891it [15:11,  1.80s/it]
#
#
#
#
# 892it [15:13,  1.88s/it]
#
#
#
#
# 893it [15:13,  1.38s/it]
#
#
#
#
# 895it [15:15,  1.14s/it]
#
#
#
#
# 896it [15:16,  1.25s/it]
#
#
#
#
# 897it [15:18,  1.33s/it]
#
#
#
#
# 898it [15:19,  1.40s/it]
#
#
#
#
# 900it [15:21,  1.14s/it]
#
#
#
#
# 901it [15:22,  1.25s/it]
#
#
#
#
# 902it [15:24,  1.35s/it]
#
#
#
#
# 904it [15:26,  1.13s/it]
#
#
#
#
# 905it [15:27,  1.25s/it]
#
#
#
#
# 907it [15:29,  1.08s/it]
#
#
#
#
# 908it [15:31,  1.20s/it]
#
#
#
#
# 909it [15:32,  1.32s/it]
#
#
#
#
# 910it [15:34,  1.40s/it]
#
#
#
#
# 912it [15:36,  1.15s/it]
#
#
#
#
# 913it [15:38,  1.35s/it]
#
#
#
#
# 914it [15:40,  1.54s/it]
#
#
#
#
# 915it [15:47,  2.96s/it]
#
#
#
#
# 917it [15:48,  2.03s/it]
#
#
#
#
# 920it [15:50,  1.34s/it]
#
#
#
#
# 921it [15:50,  1.12s/it]
#
#
#
#
# 923it [15:52,  1.06s/it]
#
#
#
#
# 924it [15:54,  1.27s/it]
#
#
#
#
# 926it [15:56,  1.19s/it]
#
#
#
#
# 927it [15:58,  1.36s/it]
#
#
#
#
# 929it [16:00,  1.16s/it]
#
#
#
#
# 932it [16:06,  1.57s/it]
#
#
#
#
# 933it [16:08,  1.52s/it]
#
#
#
#
# 936it [16:10,  1.16s/it]
#
#
#
#
# 937it [16:12,  1.32s/it]
#
#
#
#
# 938it [16:14,  1.46s/it]
#
#
#
#
# 939it [16:21,  2.63s/it]
#
#
#
#
# 940it [16:22,  2.38s/it]
#
#
#
#
# 941it [16:24,  2.19s/it]
#
#
#
#
# 942it [16:30,  3.25s/it]
#
#
#
#
# 943it [16:32,  2.80s/it]
#
#
#
#
# 944it [16:38,  3.75s/it]
#
#
#
#
# 945it [16:44,  4.44s/it]
#
#
#
#
# 946it [16:54,  6.19s/it]
#
#
#
#
# 947it [17:09,  8.76s/it]
#
#
#
#
# 948it [17:28, 11.81s/it]
#
#
#
#
# 949it [18:00, 17.79s/it]
#
#
#
#
# 950it [19:28, 38.65s/it]
#
#
#
#
# 951it [23:33, 100.06s/it]
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/http/client.py in _read_status(self)
#     274             # sending a valid response.
# --> 275             raise RemoteDisconnected("Remote end closed connection without"
#     276                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     530             if read is False or not self._is_method_retryable(method):
# --> 531                 raise six.reraise(type(error), error, _stacktrace)
#     532             elif read is not None:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/http/client.py in _read_status(self)
#     274             # sending a valid response.
# --> 275             raise RemoteDisconnected("Remote end closed connection without"
#     276                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-51-95293d976751> in <module>
#       1 import pickle
# ----> 2 result = match_with_ocrx(one_active)
#       3 # result = "hi"
#       4 with open("ocrx_dailymed_match.pickle","wb") as f:
#       5     pickle.dump(result,f)
#
# <ipython-input-48-e7640b0d6297> in match_with_ocrx(df)
#      55 #     import ipdb; ipdb.set_trace()
#      56     drug_names = df['drug'].values
# ---> 57     dl_results = {drug_name: dlquery(comb) for drug_name, comb in tqdm(zip(drug_names,form_datas))}
#      58     return dl_results
#
# <ipython-input-48-e7640b0d6297> in <dictcomp>(.0)
#      55 #     import ipdb; ipdb.set_trace()
#      56     drug_names = df['drug'].values
# ---> 57     dl_results = {drug_name: dlquery(comb) for drug_name, comb in tqdm(zip(drug_names,form_datas))}
#      58     return dl_results
#
# <ipython-input-48-e7640b0d6297> in dlquery(form_data)
#      40 #     import ipdb; ipdb.set_trace()
#      41     multipart_form_data = {key: (None,val) for key,val in form_data.items()}
# ---> 42     response = requests.post('http://localhost:8080/DLquery',files=multipart_form_data,headers={'Authorization': 'Bearer foo'}).json()
#      43     return parse_dl_response(response)
#      44
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/programs/miniconda3/envs/ml-env/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
result

# %%
result = dlquery({'form' : '4000000043','substance' : '3000001547', 'route' : '4100000056'})

# %%
result
# Out:
# {'ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 80 MG AS TABLET IN ORAL': '1000009689',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 80 MG AS TABLET IN ORAL': '1000008169',
#  'ATORVASTATIN (ATORVASTATIN CALCIUM) 10 MG AS TABLET IN ORAL': '1000019068',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 80 MG AS TABLET IN ORAL': '1000010934',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 10 MG AS TABLET IN ORAL': '1000007010',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 40 MG AS TABLET IN ORAL': '1000011683',
#  'ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 40 MG AS TABLET IN ORAL': '1000023084',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 20 MG AS TABLET IN ORAL': '1000004813',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 40 MG AS TABLET IN ORAL': '1000005026',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 20 MG AS TABLET IN ORAL': '1000016311',
#  'ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 10 MG AS TABLET IN ORAL': '1000017305',
#  'ATORVASTATIN (ATORVASTATIN CALCIUM) 80 MG AS TABLET IN ORAL': '1000026799',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 10 MG AS TABLET IN ORAL': '1000026768',
#  'ATORVASTATIN (ATORVASTATIN CALCIUM) 20 MG AS TABLET IN ORAL': '1000023293',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 80 MG AS TABLET IN ORAL': '1000001242',
#  'ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 20 MG AS TABLET IN ORAL': '1000012970',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 10 MG AS TABLET IN ORAL': '1000016493',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 20 MG AS TABLET IN ORAL': '1000006813',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 80 MG AS TABLET IN ORAL': '1000007967',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 40 MG AS TABLET IN ORAL': '1000024663',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 10 MG AS TABLET IN ORAL': '1000018560',
#  'ATORVASTATIN (ATORVASTATIN CALCIUM) 40 MG AS TABLET IN ORAL': '1000005947',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 40 MG AS TABLET IN ORAL': '1000000052',
#  'AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 20 MG AS TABLET IN ORAL': '1000013434'}

# %%
[row['labels'] for row in result['CCD']]
# Out:
# [['ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 80 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 80 MG AS TABLET IN ORAL'],
#  ['ATORVASTATIN (ATORVASTATIN CALCIUM) 10 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 80 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 10 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 40 MG AS TABLET IN ORAL'],
#  ['ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 40 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 20 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 40 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 20 MG AS TABLET IN ORAL'],
#  ['ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 10 MG AS TABLET IN ORAL'],
#  ['ATORVASTATIN (ATORVASTATIN CALCIUM) 80 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 10 MG AS TABLET IN ORAL'],
#  ['ATORVASTATIN (ATORVASTATIN CALCIUM) 20 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 80 MG AS TABLET IN ORAL'],
#  ['ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 20 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 10 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 20 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM PROPYLENE GLYCOL SOLVATE) 80 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 10 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 40 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 10 MG AS TABLET IN ORAL'],
#  ['ATORVASTATIN (ATORVASTATIN CALCIUM) 40 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 40 MG AS TABLET IN ORAL'],
#  ['AMLODIPINE (AMLODIPINE BESYLATE) 5 MG | ATORVASTATIN (ATORVASTATIN CALCIUM) 20 MG AS TABLET IN ORAL']]

# %%
matches
# Out:
# {'drug': {'LUTETIUM OXODOTREOTIDE LU-177': '3000001032',
#   'RAMUCIRUMAB': '3000003980',
#   'THROMBIN ALFA': '3000002952',
#   'AMLODIPINE': '3000002513',
#   'NITROFURANTOIN': '3000000127',
#   'ALFENTANIL': '3000000911',
#   'ACACIA': '3000000820',
#   'FLUTAMIDE': '3000000764',
#   'ANTI-INHIBITOR COAGULANT COMPLEX': '3000004771',
#   'TRIAZOLAM': '3000003468',
#   'NILOTINIB': '3000001622',
#   'FENTANYL CITRATE': '3000001599',
#   'DAPTOMYCIN': '3000002748',
#   'CINACALCET': '3000002939',
#   'DISOPYRAMIDE PHOSPHATE': '3000002318',
#   'DROSPIRENONE': '3000002109',
#   'IRINOTECAN': '3000003522',
#   'TOCOPHEROL': '3000002449',
#   'FLUDROCORTISONE': '3100005314',
#   'CEFOTETAN DISODIUM': '3000004281',
#   'COPPER': '3000003164',
#   'DIFLORASONE DIACETATE': '3000002382',
#   'FEXOFENADINE': '3100005340',
#   'METHENAMINE': '3000002610',
#   'PEGASPARGASE': '3000005086',
#   'FLIBANSERIN': '3000002603',
#   'VALSARTAN': '3000003776',
#   'NITISINONE': '3000000128',
#   'FLUOROMETHOLONE': '3000000760',
#   'NABUMETONE': '3000002617',
#   'PEGFILGRASTIM': '3000002947',
#   'ACLIDINIUM': '3100005193',
#   'DEXRAZOXANE': '3000004545',
#   'PANTOTHENIC ACID': '3000004369',
#   'BUPIVACAINE': '3100005283',
#   'CEFTIZOXIME SODIUM': '3000001906',
#   'METHACHOLINE': '3100005187',
#   'ADALIMUMAB': '3000001670',
#   'CRESOL': '3000000162',
#   'MENTHOL': '3000000834',
#   'BRIVARACETAM': '3000002820',
#   'INSULIN HUMAN': '3000000196',
#   'VALRUBICIN': '3000004940',
#   'HUMAN IMMUNOGLOBULIN G': '3000001669',
#   'CHLOROTHIAZIDE': '3000003951',
#   'OCRELIZUMAB': '3000000387',
#   'AXITINIB': '3000001724',
#   'N-ACETYLTYROSINE': '3000004871',
#   'ALBUTEROL': '3000000959',
#   'BENRALIZUMAB': '3000003912',
#   'NAPROXEN': '3000002400',
#   'MEDROXYPROGESTERONE': '3100005300',
#   'CHLORIDE ION': '3000002482',
#   'CALCIUM ACETATE': '3000000881',
#   'TESAMORELIN': '3000000680',
#   'CALCIPOTRIENE': '3000003673',
#   '.ALPHA.-TOCOPHEROL, DL-': '3000001837',
#   'DOBUTAMINE': '3000000590',
#   'NELFINAVIR': '3000004652',
#   'OXYBENZONE': '3000001889',
#   'THYROID': '3000004268',
#   'HISTIDINE': '3000001626',
#   'ETHIODIZED OIL': '3000000100',
#   'GINGER': '3000002137',
#   'METFORMIN HYDROCHLORIDE': '3000004649',
#   'LIDOCAINE': '3000005030',
#   'EFAVIRENZ': '3000001780',
#   'VISMODEGIB': '3000003369',
#   'EVOLOCUMAB': '3000002587',
#   'PHENYTOIN': '3000001955',
#   'SPIRONOLACTONE': '3000002515',
#   'POMALIDOMIDE': '3000003220',
#   '.ALPHA.-LIPOIC ACID': '3000003736',
#   'AZATHIOPRINE': '3000000009',
#   'BENZOIC ACID': '3000004362',
#   'NEVIRAPINE': '3000000090',
#   'NORGESTREL': '3000002477',
#   'ENOXAPARIN': '3100005342',
#   'CLOBAZAM': '3000001718',
#   'CANDESARTAN': '3100005253',
#   'DORAVIRINE': '3000000596',
#   'RETEPLASE': '3000002245',
#   'PHENYL SALICYLATE': '3000003472',
#   'IPRATROPIUM BROMIDE': '3000001587',
#   'DASABUVIR': '3000002180',
#   'CEFACLOR': '3000001731',
#   'FLUTICASONE': '3100005192',
#   'ALMOTRIPTAN': '3000004367',
#   'CARBOPLATIN': '3000000371',
#   'IOHEXOL': '3000001934',
#   'NEDOCROMIL': '3100005351',
#   'MANGANESE': '3000002579',
#   'BETAXOLOL': '3000000626',
#   'ZINC': '3000000767',
#   'SUCCINIC ACID': '3000003008',
#   'PRASUGREL': '3000004365',
#   'GALSULFASE': '3000003546',
#   'ENFUVIRTIDE': '3000004651',
#   'MIRTAZAPINE': '3000000116',
#   'CHOLESTYRAMINE': '3100005146',
#   'GEFITINIB': '3000004370',
#   'CAPSICUM OLEORESIN': '3000000690',
#   'TEZACAFTOR': '3000003167',
#   'INOSITOL NIACINATE': '3000003014',
#   'GLYCEROL PHENYLBUTYRATE': '3000002022',
#   'RIBOCICLIB': '3000001074',
#   'IBUTILIDE': '3100005201',
#   'CERTOLIZUMAB PEGOL': '3000004047',
#   'ROSUVASTATIN': '3000003411',
#   'ORLISTAT': '3000003023',
#   'PREDNICARBATE': '3000004704',
#   'ZIPRASIDONE': '3000000436',
#   'SARILUMAB': '3000001915',
#   'HYDROXYUREA': '3000000782',
#   'DONEPEZIL HYDROCHLORIDE': '3000002443',
#   'LOSARTAN': '3100005241',
#   'ISOSORBIDE MONONITRATE': '3000000977',
#   'EXEMESTANE': '3000001953',
#   'LETERMOVIR': '3000003890',
#   'ZINC OXIDE': '3000001429',
#   'ANASTROZOLE': '3000004699',
#   'DIPHENOXYLATE': '3100005148',
#   'ETHAMBUTOL': '3100005274',
#   'LOPERAMIDE': '3100005236',
#   'CODEINE PHOSPHATE': '3000003877',
#   'NICOTINE': '3000004768',
#   'NALOXONE': '3000000186',
#   'BIMATOPROST': '3000002573',
#   'ECAMSULE': '3000003668',
#   'FORMOTEROL': '3100005285',
#   'PROPARACAINE': '3100005344',
#   'NALTREXONE': '3100005235',
#   'GADOFOSVESET TRISODIUM': '3000001093',
#   'FIBRINOGEN HUMAN': '3000003340',
#   'MIFEPRISTONE': '3000001228',
#   'LINOLEIC ACID': '3000003352',
#   'ALITRETINOIN': '3000002601',
#   'SELENIUM': '3000002397',
#   'BETAMETHASONE': '3000004280',
#   'FLUORIDE ION': '3000004453',
#   'ANTAZOLINE': '3100005135',
#   'PRILOCAINE': '3000000249',
#   'DESFLURANE': '3000004753',
#   'MILRINONE': '3000003865',
#   'DOCUSATE': '3100005199',
#   'TACROLIMUS': '3000002403',
#   'ZOLPIDEM TARTRATE': '3000002968',
#   'MEPERIDINE HYDROCHLORIDE': '3000004861',
#   'TAZAROTENE': '3000002479',
#   'CALCITRIOL': '3000004125',
#   'PYRIDOSTIGMINE BROMIDE': '3000003973',
#   'ICOSAPENT': '3000001045',
#   'CHLORHEXIDINE': '3000004380',
#   'ADO-TRASTUZUMAB EMTANSINE': '3000002253',
#   'LOTEPREDNOL': '3100005338',
#   'BETAXOLOL HYDROCHLORIDE': '3000004551',
#   'MIGLUSTAT': '3000003088',
#   'ETONOGESTREL': '3000004465',
#   'NARATRIPTAN': '3000000899',
#   'PERPHENAZINE': '3000004621',
#   'CLAVULANIC ACID': '3000000560',
#   'OXAPROZIN': '3000000752',
#   'DOXERCALCIFEROL': '3000004136',
#   'OCTISALATE': '3000004941',
#   'PSEUDOEPHEDRINE': '3100005197',
#   'LAPINE T-LYMPHOCYTE IMMUNE GLOBULIN': '3000002273',
#   'TUBERCULIN PURIFIED PROTEIN DERIVATIVE': '3000000218',
#   'SINCALIDE': '3000000499',
#   'PALIFERMIN': '3000001031',
#   'EPOPROSTENOL': '3000003119',
#   'AMIKACIN': '3000004205',
#   'OMBITASVIR': '3000004121',
#   'BETAINE': '3000004188',
#   'ICATIBANT': '3000002246',
#   'PEGVISOMANT': '3000004759',
#   'ESTAZOLAM': '3000002465',
#   'GUANFACINE': '3000000866',
#   'MINOCYCLINE': '3000002567',
#   'DUPILUMAB': '3000004214',
#   'BECLOMETHASONE': '3100005322',
#   'LENVATINIB': '3000004515',
#   'METHSUXIMIDE': '3000000968',
#   'ACYCLOVIR': '3000003914',
#   'DILTIAZEM': '3100005325',
#   'ACETAZOLAMIDE': '3000000750',
#   'AZELAIC ACID': '3000002877',
#   'PROMETHAZINE HYDROCHLORIDE': '3000004590',
#   'METOPROLOL TARTRATE': '3000004596',
#   'DIATRIZOATE SODIUM': '3000002187',
#   'DEXTROSE HYDROUS': '3000000111',
#   'CORTICOTROPIN': '3000002899',
#   'LEUCOVORIN': '3000002697',
#   'BENOXINATE': '3100005129',
#   'DANTROLENE': '3100005330',
#   'PROPRANOLOL': '3000003777',
#   'PEGINTERFERON ALFA-2A': '3000001921',
#   'PORFIMER': '3100005121',
#   'FAMOTIDINE': '3000000681',
#   'FLUOCINOLONE ACETONIDE': '3000004308',
#   'PRALATREXATE': '3000000794',
#   'METHIONINE': '3000000583',
#   'RISEDRONIC ACID': '3100005329',
#   'SOYBEAN OIL': '3000003248',
#   'ESZOPICLONE': '3000000831',
#   'PAMIDRONIC ACID': '3100005182',
#   'DROPERIDOL': '3000001293',
#   'AMITRIPTYLINE': '3000003802',
#   'CROMOLYN SODIUM': '3000002292',
#   'INDAPAMIDE': '3000001115',
#   'USTILAGO MAYDIS': '3000002681',
#   'CARFILZOMIB': '3000000047',
#   'ASCORBIC ACID': '3000003423',
#   'INSULIN GLULISINE': '3100005191',
#   'SIMVASTATIN': '3000003323',
#   'SILODOSIN': '3000002876',
#   'CEFAZOLIN SODIUM': '3000000277',
#   'LIDOCAINE HYDROCHLORIDE': '3000002569',
#   'IBRUTINIB': '3000000707',
#   'RIFABUTIN': '3000000551',
#   'PRAMIPEXOLE': '3100005155',
#   'BUSULFAN': '3000001308',
#   'ENTRECTINIB': '3000004355',
#   'ENZALUTAMIDE': '3000002814',
#   'MINOCYCLINE HYDROCHLORIDE': '3000001002',
#   'QUININE': '3000000432',
#   'ROSUVASTATIN CALCIUM': '3000002061',
#   'TREPROSTINIL': '3000004228',
#   'ETANERCEPT': '3000004914',
#   'LEUPROLIDE ACETATE': '3000002228',
#   'MAFENIDE': '3000000582',
#   'PARITAPREVIR': '3000003400',
#   'EDROPHONIUM CHLORIDE': '3000003278',
#   'DONEPEZIL': '3100005363',
#   'DESONIDE': '3000000664',
#   'AZELASTINE': '3100005157',
#   'SODIUM SULFATE ANHYDROUS': '3000002087',
#   'DEXTROSE': '3000004901',
#   'PROCAINE HYDROCHLORIDE': '3000000191',
#   'TIOTROPIUM': '3000001186',
#   'QUINUPRISTIN': '3000001747',
#   'BRENTUXIMAB VEDOTIN': '3000002761',
#   'METHIMAZOLE': '3000003814',
#   'MELOXICAM': '3000001647',
#   'LIFITEGRAST': '3000001705',
#   '2,3-DIMERCAPTOSUCCINIC ACID': '3000000135',
#   'DULOXETINE': '3000003855',
#   'HYOSCYAMINE': '3000004780',
#   'CODEINE': '3000002636',
#   'LISDEXAMFETAMINE': '3100005167',
#   'ECULIZUMAB': '3000000618',
#   'METOCLOPRAMIDE': '3100005127',
#   'LEDIPASVIR': '3000003296',
#   'SERINE': '3000000318',
#   'OLOPATADINE': '3000003102',
#   'CARGLUMIC ACID': '3000001410',
#   'COLISTIN': '3000000229',
#   'PYRIDOXINE': '3000001616',
#   'METHADONE': '3100005319',
#   'IVACAFTOR': '3000003826',
#   'OLMESARTAN': '3100005263',
#   'VANDETANIB': '3000001301',
#   'MEXILETINE': '3100005247',
#   'DANAZOL': '3000002366',
#   'METHYLPREDNISOLONE': '3000003892',
#   'BRODALUMAB': '3000002900',
#   'TERBINAFINE': '3000003956',
#   'LAPATINIB': '3000002724',
#   'PENTETIC ACID': '3000004435',
#   'GLATIRAMER': '3100005210',
#   'ELOSULFASE ALFA': '3000004245',
#   'NEOMYCIN': '3000004323',
#   'CAPLACIZUMAB': '3000002901',
#   'HYDRALAZINE HYDROCHLORIDE': '3000001845',
#   'METHOXSALEN': '3000002794',
#   'CERITINIB': '3000003916',
#   'STREPTOZOCIN': '3000000131',
#   'MECLIZINE HYDROCHLORIDE': '3000003502',
#   'LOPERAMIDE HYDROCHLORIDE': '3000003917',
#   'SCABIES LESION LYSATE (HUMAN)': '3000003017',
#   'DEXTROAMPHETAMINE SULFATE': '3000001584',
#   'CEFPROZIL': '3000001199',
#   'PENTETATE CALCIUM TRISODIUM': '3000003030',
#   'FENOPROFEN': '3000001510',
#   'SOFOSBUVIR': '3000003570',
#   'ROCURONIUM': '3100005242',
#   'ABACAVIR': '3000004639',
#   'MORPHINE': '3000004489',
#   'APOMORPHINE': '3000005062',
#   'ALLANTOIN': '3000000121',
#   'RANITIDINE HYDROCHLORIDE': '3000000478',
#   'ISOSULFAN BLUE': '3000000665',
#   'RIOCIGUAT': '3000003084',
#   'DOXYCYCLINE HYCLATE': '3000000780',
#   'TOLMETIN': '3000001834',
#   'UREA': '3000005082',
#   'AFATINIB': '3000001063',
#   'ONDANSETRON': '3000004924',
#   'PHENELZINE': '3000003850',
#   'SULINDAC': '3000004577',
#   'VILANTEROL': '3000002591',
#   'BIOTIN': '3000002305',
#   'IVABRADINE': '3000004526',
#   'BUROSUMAB': '3000003693',
#   'SERTRALINE': '3000002593',
#   'IOPROMIDE': '3000002077',
#   'PROPAFENONE HYDROCHLORIDE': '3000002740',
#   'SULFACETAMIDE SODIUM': '3000004257',
#   'EXAMETAZIME': '3000004557',
#   'ROMOSOZUMAB': '3000001271',
#   'CARISOPRODOL': '3000001273',
#   'SEVELAMER': '3100005323',
#   'SULFASALAZINE': '3000004935',
#   'SAFINAMIDE': '3000000779',
#   'ETODOLAC': '3000001621',
#   'OCTREOTIDE': '3000000801',
#   'ETOPOSIDE': '3000004051',
#   'ENASIDENIB': '3000002991',
#   'NITROFURANTOIN, MACROCRYSTALLINE': '3000000127',
#   'PAROMOMYCIN': '3000004742',
#   'ARIPIPRAZOLE': '3000002188',
#   'GOLIMUMAB': '3000005021',
#   'BENZTROPINE': '3100005293',
#   'GENTAMICIN': '3000000342',
#   'BAZEDOXIFENE': '3000003258',
#   'DESOXIMETASONE': '3000004922',
#   'SULFATE ION': '3000002825',
#   'VALACYCLOVIR': '3000003684',
#   'OPIUM': '3000004995',
#   'IPRATROPIUM': '3100005345',
#   'FERRIC FERROCYANIDE': '3000000877',
#   'NITROGLYCERIN': '3000004094',
#   'VALPROIC ACID': '3000000558',
#   'SITAGLIPTIN': '3000004643',
#   'VENLAFAXINE': '3000000030',
#   'FOSINOPRIL': '3100005163',
#   'TRAVOPROST': '3000003432',
#   'DIAZOXIDE': '3000004292',
#   'IBRITUMOMAB TIUXETAN': '3000001488',
#   'EPHEDRINE': '3000004143',
#   'PATISIRAN': '3000001215',
#   'CRISABOROLE': '3000000872',
#   'SODIUM ACETATE TRIHYDRATE': '3000002486',
#   'BUSPIRONE': '3100005346',
#   'LABETALOL': '3100005188',
#   'FERRIC SUBSULFATE': '3000005032',
#   'MAGNESIUM HYDROXIDE': '3000004373',
#   'ENALAPRIL': '3100005200',
#   'ZALEPLON': '3000000448',
#   'LAMOTRIGINE': '3000004705',
#   'MEDRYSONE': '3000000445',
#   'FAMCICLOVIR': '3000002577',
#   'TINZAPARIN SODIUM': '3000004361',
#   'ALUMINUM': '3000002727',
#   'BEVACIZUMAB': '3000004287',
#   'FROVATRIPTAN': '3000003162',
#   'CIPROFLOXACIN': '3000000322',
#   'PROTAMINE': '3100005215',
#   'USTEKINUMAB': '3000001342',
#   'PORACTANT ALFA': '3000003647',
#   'ALECTINIB': '3000001839',
#   'ALTEPLASE': '3000001627',
#   'ANAKINRA': '3000000327',
#   'VALGANCICLOVIR': '3000002186',
#   'APREPITANT': '3000000522',
#   'TOCOPHERSOLAN': '3000002472',
#   'SAQUINAVIR': '3000001709',
#   'VINBLASTINE': '3100005327',
#   'OXYMETAZOLINE': '3100005318',
#   'MEFENAMIC ACID': '3000004004',
#   'ELUXADOLINE': '3000003713',
#   'IPILIMUMAB': '3000001588',
#   'PRAZOSIN': '3000002958',
#   'DARIFENACIN': '3000004998',
#   'CLOBETASOL': '3100005331',
#   'GLECAPREVIR': '3000003074',
#   'BROMOCRIPTINE': '3000004786',
#   'MEXILETINE HYDROCHLORIDE': '3000001829',
#   'BUTALBITAL': '3000000679',
#   'MORPHINE SULFATE': '3000004344',
#   'FENOFIBRATE': '3000003605',
#   'ABIRATERONE': '3100005310',
#   'TRAZODONE HYDROCHLORIDE': '3000000245',
#   '.BETA.-CAROTENE': '3000004793',
#   'ISAVUCONAZOLE': '3000003436',
#   'BETAMETHASONE DIPROPIONATE': '3000000632',
#   'ALPRAZOLAM': '3000001114',
#   'CEFAZOLIN': '3000003207',
#   'ALPHA LIPOIC ACID': '3000003736',
#   'PALBOCICLIB': '3000000115',
#   'PROPOFOL': '3000003954',
#   'TRIMETREXATE GLUCURONATE': '3000002076',
#   'CHLORDIAZEPOXIDE HYDROCHLORIDE': '3000001800',
#   'ATAZANAVIR': '3000004181',
#   'PALIVIZUMAB': '3000001717',
#   'PYRAZINAMIDE': '3000002363',
#   'PHENAZOPYRIDINE': '3100005350',
#   'ALOGLIPTIN': '3000002736',
#   'ROFLUMILAST': '3000000743',
#   'PETROLATUM': '3000004864',
#   'OBINUTUZUMAB': '3000002327',
#   'ERGOCALCIFEROL': '3000004981',
#   'NITROGEN': '3000004057',
#   'EDOXABAN': '3000003572',
#   'ESOMEPRAZOLE': '3000002242',
#   'OLSALAZINE': '3100005123',
#   'METHYLCOBALAMIN': '3000004437',
#   'BETHANECHOL': '3100005221',
#   'PHYTONADIONE': '3100005184',
#   'NEOMYCIN SULFATE': '3000004422',
#   'VITAMIN A': '3000001976',
#   'TRIPTORELIN': '3000004271',
#   'BUPRENORPHINE': '3000003081',
#   'CLOZAPINE': '3000003286',
#   'VEMURAFENIB': '3000002588',
#   'TELITHROMYCIN': '3000004944',
#   'RIVAROXABAN': '3000000008',
#   'IDELALISIB': '3000000856',
#   'PROCHLORPERAZINE': '3000005003',
#   'KETOCONAZOLE': '3000002030',
#   'TEMSIROLIMUS': '3000004027',
#   'EDETIC ACID': '3000002223',
#   'CYCLOSERINE': '3000003616',
#   'DAROLUTAMIDE': '3000001150',
#   'DULAGLUTIDE': '3000001046',
#   'DEFERASIROX': '3000000848',
#   'ELTROMBOPAG': '3000000430',
#   'EPINEPHRINE': '3000003680',
#   'BARIUM SULFATE': '3000002045',
#   'ELAGOLIX': '3000000512',
#   'ANTIHEMOPHILIC FACTOR, HUMAN RECOMBINANT': '3000001844',
#   'NITROUS OXIDE': '3000001768',
#   'CHLOROQUINE': '3100005185',
#   'ESTRADIOL VALERATE': '3000003105',
#   'CLOFARABINE': '3000000302',
#   'CHLORAMBUCIL': '3000001303',
#   'SULFURIC ACID': '3000004468',
#   'ANTIPYRINE': '3000000758',
#   'OCTOCRYLENE': '3000001979',
#   'TOCILIZUMAB': '3000003486',
#   'TICAGRELOR': '3000000643',
#   'GLYCOPYRROLATE': '3000003201',
#   'LINACLOTIDE': '3000002164',
#   'GEMIFLOXACIN MESYLATE': '3000004126',
#   'CLONIDINE': '3100005280',
#   'VERAPAMIL': '3100005357',
#   'URSODIOL': '3000000574',
#   'NIZATIDINE': '3000000221',
#   'BENZOYL PEROXIDE': '3000001787',
#   'CASPOFUNGIN': '3000001390',
#   'ZANAMIVIR': '3000003784',
#   'NYSTATIN': '3000003368',
#   'OSIMERTINIB': '3000003346',
#   'BRIMONIDINE': '3000004987',
#   'FORMALDEHYDE': '3000005064',
#   'LANSOPRAZOLE': '3000004837',
#   'CAPECITABINE': '3000001970',
#   'ALBUMIN HUMAN': '3000000661',
#   'ANTHRALIN': '3000003273',
#   'DIBUCAINE': '3000003129',
#   'LOXAPINE': '3000000132',
#   'AMPRENAVIR': '3000000227',
#   'VARENICLINE': '3000001609',
#   'UBIDECARENONE': '3000002419',
#   'AFLIBERCEPT': '3000004989',
#   'PASIREOTIDE': '3000002209',
#   'AMANTADINE': '3100005286',
#   'BENAZEPRIL HYDROCHLORIDE': '3000002634',
#   'FLUCONAZOLE': '3000002368',
#   'MOLYBDENUM': '3000004675',
#   'OXYCODONE': '3100005217',
#   'IOVERSOL': '3000004979',
#   'LANREOTIDE': '3000000814',
#   'MEPIVACAINE HYDROCHLORIDE': '3000001040',
#   'PEMETREXED': '3000001686',
#   'IRON': '3000002041',
#   'SULFUR': '3000003293',
#   'MECLOFENAMIC ACID': '3000003775',
#   'BROLUCIZUMAB': '3000003391',
#   'DISULFIRAM': '3000004633',
#   'NORTRIPTYLINE HYDROCHLORIDE': '3000004190',
#   'CLORAZEPIC ACID': '3100005239',
#   'ERTUGLIFLOZIN': '3000003205',
#   'VILAZODONE': '3100005172',
#   'TETROFOSMIN': '3000003309',
#   'RALOXIFENE': '3100005321',
#   'KETOROLAC TROMETHAMINE': '3000003611',
#   'ISOPROPYL ALCOHOL': '3000001855',
#   'CETIRIZINE': '3100005120',
#   'HYDROCORTISONE ACETATE': '3000004558',
#   'GUSELKUMAB': '3000002463',
#   'GLUCAGON': '3000000862',
#   'PARICALCITOL': '3000001321',
#   'LURASIDONE': '3100005282',
#   'PERTUZUMAB': '3000003786',
#   'LEVOTHYROXINE': '3100005132',
#   'PHENOBARBITAL': '3000004132',
#   'PATIROMER': '3000003780',
#   'DEXTROSE MONOHYDRATE': '3000000111',
#   'CARBOPROST': '3000002932',
#   'APRACLONIDINE': '3000005000',
#   'HYDROGEN PEROXIDE': '3000002909',
#   'DICYCLOMINE': '3100005176',
#   'PERAMPANEL': '3000000078',
#   'DORZOLAMIDE': '3000001435',
#   'METOPROLOL': '3100005136',
#   'PRAVASTATIN': '3100005232',
#   'SAXAGLIPTIN': '3000003946',
#   'CEFADROXIL': '3000002792',
#   'DEFERIPRONE': '3000004801',
#   'PROBENECID': '3000003385',
#   'TRIMETHOPRIM': '3000001247',
#   'OLANZAPINE': '3000001719',
#   'MISOPROSTOL': '3000002388',
#   'EXENATIDE': '3000000749',
#   'PROTIRELIN': '3000000401',
#   'LEVONORGESTREL': '3000004606',
#   'ROMIDEPSIN': '3000002115',
#   'AGALSIDASE BETA': '3000002274',
#   'ELVITEGRAVIR': '3000000666',
#   'ACITRETIN': '3000002296',
#   'ALUMINUM HYDROXIDE': '3000000124',
#   'ARTICAINE HYDROCHLORIDE': '3000002120',
#   'MITOXANTRONE': '3000000184',
#   'VERAPAMIL HYDROCHLORIDE': '3000000652',
#   'SUFENTANIL CITRATE': '3000004682',
#   'CARBACHOL': '3000004843',
#   'GLUTAMIC ACID': '3000002819',
#   'DEGARELIX': '3000002315',
#   'ERDAFITINIB': '3000001986',
#   'RESERPINE': '3000004887',
#   'BLINATUMOMAB': '3000003901',
#   'NAPHAZOLINE HYDROCHLORIDE': '3000002828',
#   'DOXEPIN HYDROCHLORIDE': '3000002033',
#   'TRANYLCYPROMINE': '3000001257',
#   'RASAGILINE': '3000001980',
#   'METHYLPHENIDATE': '3100005208',
#   'SULFADIAZINE': '3000001201',
#   'TRIMIPRAMINE': '3000004910',
#   'CALCIUM CHLORIDE': '3000002928',
#   'DECITABINE': '3000002737',
#   'SORAFENIB': '3000002452',
#   'IMATINIB': '3000002234',
#   'NAFCILLIN': '3000003971',
#   'PHENYLEPHRINE': '3000003607',
#   'ZOLPIDEM': '3100005178',
#   'PRIMIDONE': '3000003341',
#   'LARONIDASE': '3000000781',
#   '.ALPHA.-TOCOPHEROL, D-': '3000004150',
#   'TESTOSTERONE': '3000003604',
#   'DEOXYCHOLIC ACID': '3000001156',
#   'KETAMINE': '3000000313',
#   'FLURANDRENOLIDE': '3000003884',
#   'ALCOHOL': '3000000818',
#   'FISH OIL': '3000002747',
#   'LINAGLIPTIN': '3000000870',
#   'AMLODIPINE BESYLATE': '3000002454',
#   'PRASTERONE': '3000001830',
#   'CHLORHEXIDINE GLUCONATE': '3000005004',
#   'ALGLUCOSIDASE ALFA': '3000003235',
#   'PHOSPHORIC ACID': '3000002457',
#   'PROPAFENONE': '3100005256',
#   'THIOTEPA': '3000002902',
#   'MOXIFLOXACIN': '3000000157',
#   'DIDANOSINE': '3000004002',
#   'PENTAMIDINE': '3100005177',
#   'FLAX SEED': '3000003962',
#   'INTERFERON ALFA-2B': '3000001343',
#   'FIDAXOMICIN': '3000004552',
#   'PENTOBARBITAL': '3000004197',
#   'MELPHALAN': '3000001807',
#   'PROLINE': '3000001302',
#   'NABILONE': '3000001795',
#   'HYDROCHLOROTHIAZIDE': '3000002704',
#   'DALBAVANCIN': '3000003921',
#   'DROMETRIZOLE TRISILOXANE': '3000001479',
#   'CEFEPIME': '3000001907',
#   'DAPSONE': '3000000556',
#   'CORTISONE': '3100005147',
#   'PIMOZIDE': '3000000623',
#   'THALIDOMIDE': '3000004962',
#   'AMOXICILLIN': '3000004816',
#   'MICONAZOLE NITRATE': '3000004195',
#   'CHOLINE': '3000000140',
#   'BENDAMUSTINE': '3100005244',
#   'NUSINERSEN': '3000003316',
#   'TYROSINE': '3000001129',
#   'OXAZEPAM': '3000004706',
#   'GEMIFLOXACIN': '3000004840',
#   'MOMETASONE FUROATE': '3000001519',
#   'EMPAGLIFLOZIN': '3000000270',
#   'CICLOPIROX': '3000002589',
#   'DABRAFENIB': '3000003438',
#   'ADAPALENE': '3000005068',
#   'HOMOSALATE': '3000000156',
#   'BOSUTINIB': '3000001506',
#   'CETUXIMAB': '3000002432',
#   'LACTULOSE': '3000002036',
#   'TIPIRACIL': '3000003752',
#   'CEPHALEXIN': '3000002915',
#   'NORETHINDRONE': '3000004496',
#   'DEXLANSOPRAZOLE': '3000001417',
#   'TOLCAPONE': '3000001663',
#   'NETUPITANT': '3000002100',
#   'FLUVOXAMINE': '3100005353',
#   'MEMANTINE': '3100005238',
#   'FLURAZEPAM': '3100005290',
#   'HEPARIN SODIUM': '3000004866',
#   '.ALPHA.-TOCOPHEROL ACETATE, DL-': '3000004436',
#   'BUSPIRONE HYDROCHLORIDE': '3000002306',
#   'ATROPINE': '3000004938',
#   'SILVER SULFADIAZINE': '3000002927',
#   'ESTROPIPATE': '3000002688',
#   'CHLORTHALIDONE': '3000003450',
#   'DOCONEXENT': '3000000048',
#   'BUPIVACAINE HYDROCHLORIDE': '3000004112',
#   'COLESEVELAM': '3100005212',
#   'TIPRANAVIR': '3000002023',
#   'PHOSPHORUS': '3000004711',
#   'NORGESTIMATE': '3000000897',
#   'LEVOCARNITINE': '3000002647',
#   'SODIUM ACETATE': '3000004803',
#   'TETRABENAZINE': '3000000927',
#   'OBETICHOLIC ACID': '3000001491',
#   'TENECTEPLASE': '3000004469',
#   'FLUOROURACIL': '3000004791',
#   'OXIGLUTATIONE': '3000000900',
#   'BUPROPION': '3100005288',
#   'DALTEPARIN': '3100005271',
#   'TRIAMTERENE': '3000000018',
#   'FLUOCINONIDE': '3000003482',
#   'TOLVAPTAN': '3000000763',
#   'TRIPROLIDINE': '3100005324',
#   'LOMITAPIDE': '3000002752',
#   'ISOTRETINOIN': '3000000689',
#   'AMINOLEVULINIC ACID HYDROCHLORIDE': '3000003214',
#   'EPROSARTAN': '3000000735',
#   'EUCALYPTUS OIL': '3000000803',
#   'LINCOMYCIN': '3000004122',
#   'LORLATINIB': '3000003524',
#   'EPTIFIBATIDE': '3000000423',
#   'TRABECTEDIN': '3000001785',
#   'PENICILLAMINE': '3000002507',
#   'CYANOCOBALAMIN': '3000002858',
#   'TALAZOPARIB': '3000000314',
#   'INSULIN GLARGINE': '3000001827',
#   'IMIPRAMINE': '3100005301',
#   'COBAMAMIDE': '3000004171',
#   'EMTRICITABINE': '3000000085',
#   'RETAPAMULIN': '3000004259',
#   'HYDROCORTISONE': '3000003788',
#   'NOREPINEPHRINE': '3000003197',
#   'BUMETANIDE': '3000002868',
#   'DIATRIZOATE MEGLUMINE': '3000002967',
#   'IXEKIZUMAB': '3000003040',
#   'DOXAZOSIN MESYLATE': '3000004473',
#   'VINORELBINE': '3000004331',
#   'FEBUXOSTAT': '3000003871',
#   'ARGININE': '3000003457',
#   'BLEOMYCIN': '3000002618',
#   'TRAMADOL': '3100005360',
#   'NIRAPARIB': '3000001775',
#   'SIPONIMOD': '3000002062',
#   'LIOTHYRONINE': '3000000037',
#   'IMIGLUCERASE': '3000004781',
#   'CEFPODOXIME': '3000001619',
#   'ACETAMINOPHEN': '3000004395',
#   'SUGAMMADEX': '3000001121',
#   'CEMIPLIMAB': '3000001514',
#   'INDOCYANINE GREEN': '3000002675',
#   'ALANINE': '3000000053',
#   'COAGULATION FACTOR VIIA RECOMBINANT HUMAN': '3000002972',
#   'ELIGLUSTAT': '3000001552',
#   'ALEMTUZUMAB': '3000001537',
#   'ENALAPRILAT': '3000001205',
#   'SERTRALINE HYDROCHLORIDE': '3000002766',
#   'DEXTRAN 40': '3000004054',
#   'AMCINONIDE': '3000004879',
#   'METHYLTESTOSTERONE': '3000002144',
#   'ABATACEPT': '3000003364',
#   'PREDNISONE': '3000003259',
#   'GEMTUZUMAB OZOGAMICIN': '3000000703',
#   'EPIRUBICIN HYDROCHLORIDE': '3000004347',
#   'RILUZOLE': '3000004953',
#   'ATOMOXETINE': '3000000431',
#   'ISOFLURANE': '3000001874',
#   'POLYETHYLENE GLYCOL 3350': '3000003404',
#   'DEXMEDETOMIDINE': '3000001887',
#   'PARATHYROID HORMONE': '3000000471',
#   'FLUVOXAMINE MALEATE': '3000000262',
#   'CALCIUM PHOSPHATE, DIBASIC, ANHYDROUS': '3000002790',
#   'HESPERIDIN': '3000003407',
#   'POLYSORBATE 80': '3000001026',
#   'FENTANYL': '3000000490',
#   'INTERFERON BETA-1A': '3000001489',
#   'IDURSULFASE': '3000003997',
#   'LEVOMEFOLIC ACID': '3100005138',
#   'LYSINE': '3000003703',
#   'LATANOPROST': '3000004016',
#   'TRANEXAMIC ACID': '3000003790',
#   'GLYCOPYRRONIUM': '3000002240',
#   'INSULIN ASPART': '3000004211',
#   'BROMOCRIPTINE MESYLATE': '3000003731',
#   'AMINOLEVULINIC ACID': '3100005281',
#   'TRYPTOPHAN': '3000001965',
#   'TIMOLOL': '3000000692',
#   'RITONAVIR': '3000000978',
#   'ERTAPENEM': '3000003264',
#   'PIMECROLIMUS': '3000000851',
#   'SILDENAFIL': '3000002971',
#   'COAL TAR': '3000001132',
#   'ALBUTEROL SULFATE': '3000004030',
#   'BROMFENAC': '3000004549',
#   'SAPROPTERIN': '3100005315',
#   'IODIDE ION': '3000001381',
#   'MAGNESIUM OXIDE': '3000005042',
#   'HYDRALAZINE': '3100005275',
#   'LODOXAMIDE': '3000005105',
#   'LAMIVUDINE': '3000003578',
#   'HEPARIN': '3000003467',
#   'CYCLOSPORINE': '3000000515',
#   'BUTORPHANOL': '3000005005',
#   'REGORAFENIB': '3000002260',
#   'ESTROGENS, ESTERIFIED': '3000003730',
#   'LISINOPRIL': '3000002680',
#   'INOTERSEN': '3000003932',
#   'TAZOBACTAM': '3000005104',
#   'SILICON DIOXIDE': '3000004033',
#   'PRAMOXINE': '3100005229',
#   'SUNITINIB': '3000001039',
#   'AMINOCAPROIC ACID': '3000000292',
#   'BENDROFLUMETHIAZIDE': '3000004071',
#   'THREONINE': '3000003194',
#   'DIFLUPREDNATE': '3000002229',
#   'BENZYL ALCOHOL': '3000001817',
#   'GANCICLOVIR': '3000004008',
#   'MEFLOQUINE': '3000000294',
#   'AMMONIA': '3000001618',
#   'METHYL AMINOLEVULINATE HYDROCHLORIDE': '3000001450',
#   'VENLAFAXINE HYDROCHLORIDE': '3000004256',
#   'PODOFILOX': '3000001299',
#   'CALCITONIN SALMON': '3100005153',
#   'CLOPIDOGREL': '3000004394',
#   'VERTEPORFIN': '3000001971',
#   'METOLAZONE': '3000001331',
#   'DEXTROSE, UNSPECIFIED FORM': '3000004901',
#   'TEMAZEPAM': '3000002505',
#   'DENOSUMAB': '3000002118',
#   'NITRIC OXIDE': '3000000006',
#   'GALCANEZUMAB': '3000003383',
#   'OFLOXACIN': '3000003052',
#   'BRIGATINIB': '3000002741',
#   'COLCHICINE': '3000005056',
#   'HYDROXYZINE': '3100005272',
#   'INOSITOL': '3000002128',
#   'SULFUR HEXAFLUORIDE': '3000004884',
#   'AZTREONAM': '3000000013',
#   'FLECAINIDE': '3100005233',
#   'PERINDOPRIL': '3100005218',
#   'BIVALIRUDIN': '3000001059',
#   'VELPATASVIR': '3000004296',
#   'VINCRISTINE': '3100005211',
#   'RILPIVIRINE': '3000005102',
#   'FOSFOMYCIN': '3000001415',
#   'ADENINE': '3000004240',
#   'SULFAMETHOXAZOLE': '3000001382',
#   'PRAZIQUANTEL': '3000001092',
#   'BICALUTAMIDE': '3000003256',
#   'TOLTERODINE': '3100005198',
#   'ATOVAQUONE': '3000005051',
#   'CLOMIPHENE': '3100005150',
#   'BENZALKONIUM': '3000004324',
#   'CANTHARIDIN': '3000000580',
#   'DUTASTERIDE': '3000003498',
#   'DILTIAZEM HYDROCHLORIDE': '3000003903',
#   'PACLITAXEL': '3000003930',
#   'POLYMYXIN B SULFATE': '3000003121',
#   'MEDRONIC ACID': '3000002237',
#   'MICONAZOLE': '3000000887',
#   'MANNITOL': '3000004825',
#   'RAMIPRIL': '3000004668',
#   'LATANOPROSTENE BUNOD': '3000002338',
#   'EMICIZUMAB': '3000001572',
#   'LOPINAVIR': '3000000543',
#   'VOXILAPREVIR': '3000004309',
#   'COBIMETINIB': '3000003320',
#   'ERENUMAB': '3000000063',
#   'DIMETHYL SULFOXIDE': '3000004510',
#   'BETIATIDE': '3000004392',
#   'CHORIONIC GONADOTROPIN': '3000003178',
#   'MYCOPHENOLIC ACID': '3000000080',
#   'IOFLUPANE I-123': '3000002624',
#   'ALPHA-TOCOPHEROL, D-': '3000004150',
#   'SODIUM LACTATE': '3000002026',
#   'TARTARIC ACID': '3000000591',
#   'NATALIZUMAB': '3000002194',
#   'ITRACONAZOLE': '3000001363',
#   '3-(2-(4-(6-FLUORO-1,2-BENZISOXAZOL-3-YL)-1-PIPERIDINYL)ETHYL)-6,7,8,9-TETRAHYDRO-2-METHYL-4H-PYRIDO(1,2-A)PYRIMIDIN-4-ONE': '3000000849',
#   'THIORIDAZINE': '3000004591',
#   'BETAMETHASONE VALERATE': '3000003324',
#   'PANITUMUMAB': '3000000693',
#   'GLIMEPIRIDE': '3000001279',
#   'CLINDAMYCIN PHOSPHATE': '3000002708',
#   'CABAZITAXEL': '3000000226',
#   'AMYL NITRITE': '3000004486',
#   'SIROLIMUS': '3000005036',
#   'DIGOXIN': '3000001528',
#   'FOLIC ACID': '3000003829',
#   'TOBRAMYCIN SULFATE': '3000000987',
#   'APALUTAMIDE': '3000003459',
#   'NORELGESTROMIN': '3000002888',
#   'CHROMIUM': '3000001329',
#   'DIENOGEST': '3000003910',
#   'THIAMINE': '3000001580',
#   'IVERMECTIN': '3000001020',
#   'ISOPROTERENOL': '3100005173',
#   'OMEPRAZOLE MAGNESIUM': '3000000594',
#   'ESTRADIOL CYPIONATE': '3000004890',
#   'SULFISOXAZOLE': '3000002298',
#   'COAGULATION FACTOR X HUMAN': '3000001023',
#   'FLUDARABINE PHOSPHATE': '3000002986',
#   'THIOTHIXENE': '3000003697',
#   'LETROZOLE': '3000003058',
#   'QUETIAPINE': '3000001145',
#   'COAGULATION FACTOR IX RECOMBINANT HUMAN': '3000000792',
#   'SUCCINYLCHOLINE': '3100005332',
#   'TRASTUZUMAB': '3000002995',
#   'RISPERIDONE': '3000000849',
#   'TEMOZOLOMIDE': '3000003036',
#   'PROGUANIL': '3000003889',
#   'CILASTATIN': '3000002055',
#   'POLYMYXIN B': '3000002772',
#   'PROPYLTHIOURACIL': '3000003841',
#   'PAROXETINE': '3000001133',
#   'DACARBAZINE': '3000002765',
#   'COSYNTROPIN': '3000001508',
#   'SODIUM BICARBONATE': '3000002434',
#   'TETRACAINE': '3000003304',
#   'HALOBETASOL': '3100005303',
#   'DANTROLENE SODIUM': '3000001782',
#   'OXYGEN': '3000004855',
#   'INOTUZUMAB OZOGAMICIN': '3000000762',
#   'RIBOFLAVIN': '3000003565',
#   'CHLORZOXAZONE': '3000000753',
#   'OMALIZUMAB': '3000001935',
#   'DEFEROXAMINE': '3100005164',
#   'SELENIOUS ACID': '3000003350',
#   'CEFTOLOZANE': '3000002735',
#   'PREGABALIN': '3000000337',
#   'TELOTRISTAT': '3100005277',
#   'CITALOPRAM HYDROBROMIDE': '3000003590',
#   'PIROXICAM': '3000000725',
#   'PILOCARPINE': '3000000216',
#   'IOPAMIDOL': '3000005095',
#   'DAUNORUBICIN': '3000000418',
#   'LORAZEPAM': '3000000791',
#   'IRBESARTAN': '3000003409',
#   'PRIMAQUINE': '3100005287',
#   'GRISEOFULVIN': '3000004702',
#   'TOFACITINIB': '3000001786',
#   'OXYTETRACYCLINE HYDROCHLORIDE': '3000001211',
#   'MEPIVACAINE': '3100005333',
#   'PROGESTERONE': '3000000938',
#   'CHORIOGONADOTROPIN ALFA': '3000004971',
#   'KETOROLAC': '3100005213',
#   'FUROSEMIDE': '3000002436',
#   'ASPARAGINASE': '3000001359',
#   'MINOXIDIL': '3000000024',
#   'CLONAZEPAM': '3000005097',
#   'QUINIDINE GLUCONATE': '3000003639',
#   'TERBUTALINE': '3100005349',
#   'MONTELUKAST': '3000003440',
#   'HELIUM': '3000003479',
#   'NIVOLUMAB': '3000004074',
#   'ARTICAINE': '3100005336',
#   'DABIGATRAN': '3100005267',
#   'GRANISETRON': '3000002623',
#   'CEFOXITIN': '3000001600',
#   'DRONABINOL': '3100005124',
#   'ESTRADIOL': '3000001099',
#   'METHOTREXATE': '3000000708',
#   'MITOTANE': '3000002290',
#   'CLIDINIUM': '3100005284',
#   'FINASTERIDE': '3000004647',
#   'PHENYLTOLOXAMINE': '3000000341',
#   'VEDOLIZUMAB': '3000001345',
#   'SEMAGLUTIDE': '3000001028',
#   'CETRORELIX': '3000000984',
#   'PENTOSTATIN': '3000003801',
#   'HALOPERIDOL': '3000002391',
#   'MILRINONE LACTATE': '3000002412',
#   'BENZOCAINE': '3000000965',
#   'MIDAZOLAM': '3000000976',
#   'CLOMIPRAMINE': '3100005270',
#   'AZITHROMYCIN': '3000002746',
#   'MIDOSTAURIN': '3000000217',
#   'ESTROGENS, CONJUGATED': '3000001928',
#   'SECOBARBITAL SODIUM': '3000003667',
#   'BENAZEPRIL': '3100005226',
#   'DOXYCYCLINE': '3000004744',
#   'IXAZOMIB': '3000000494',
#   'AIR': '3000004680',
#   'RANITIDINE': '3000004690',
#   'CANNABIDIOL': '3000001259',
#   'TROPICAMIDE': '3000001457',
#   'HISTAMINE': '3000002262',
#   'ESTRONE': '3000003740',
#   'RALTEGRAVIR': '3000000886',
#   'CAPSAICIN': '3000004244',
#   'ETRAVIRINE': '3000000955',
#   'SELENIUM SULFIDE': '3000002390',
#   'ALPHA-TOCOPHEROL, DL-': '3000001837',
#   'RIMABOTULINUMTOXINB': '3000003737',
#   'SELEGILINE': '3000002984',
#   'CYPROHEPTADINE': '3100005249',
#   'LEVETIRACETAM': '3000002348',
#   'DARBEPOETIN ALFA': '3000001300',
#   'TRANDOLAPRIL': '3000004691',
#   'OZENOXACIN': '3000004984',
#   'ACALABRUTINIB': '3000004035',
#   'SOLIFENACIN': '3100005295',
#   'EPLERENONE': '3000002203',
#   'BRINZOLAMIDE': '3000001458',
#   'MEPERIDINE': '3100005140',
#   'HYDROXYCHLOROQUINE': '3100005359',
#   'PRAVASTATIN SODIUM': '3000004743',
#   'DARATUMUMAB': '3000000271',
#   'ICODEXTRIN': '3000000878',
#   'PYRIMETHAMINE': '3000003492',
#   'GADOTERIDOL': '3000002185',
#   'CEFOTAXIME': '3000002563',
#   'ZIDOVUDINE': '3000003104',
#   'PHENYLALANINE': '3000000660',
#   'LEVOCABASTINE HYDROCHLORIDE': '3000000142',
#   'NEBIVOLOL': '3000004664',
#   'ATEZOLIZUMAB': '3000000942',
#   'PALIPERIDONE': '3000003675',
#   'CENEGERMIN': '3000002283',
#   'FLURBIPROFEN': '3000004512',
#   'STIRIPENTOL': '3000004716',
#   'RIFAMPIN': '3000003970',
#   'METHOXY POLYETHYLENE GLYCOL-EPOETIN BETA': '3000004076',
#   'SULBACTAM': '3000004408',
#   'ACEBUTOLOL': '3000003516',
#   'DYCLONINE': '3100005181',
#   'ALFENTANIL HYDROCHLORIDE': '3000002176',
#   'NAFARELIN': '3000000300',
#   'IMIQUIMOD': '3000003356',
#   'DESIPRAMINE': '3000002793',
#   'TAURINE': '3000002404',
#   'HYDROXYZINE HYDROCHLORIDE': '3000001824',
#   'TERCONAZOLE': '3000002988',
#   'PENICILLIN G': '3000003413',
#   'PINDOLOL': '3000002464',
#   'LORATADINE': '3000004637',
#   'APREMILAST': '3000001989',
#   'DIMERCAPROL': '3000002214',
#   'METHOCARBAMOL': '3000004656',
#   'CISATRACURIUM': '3000005084',
#   'DRONEDARONE': '3000004260',
#   'EDARAVONE': '3000001638',
#   'TELMISARTAN': '3000000947',
#   'OXYTOCIN': '3000002729',
#   'TRAMADOL HYDROCHLORIDE': '3000001260',
#   'BICARBONATE ION': '3000002841',
#   'FLUOXETINE': '3000002962',
#   'DERMATOPHAGOIDES FARINAE': '3000000485',
#   'OLAPARIB': '3000001164',
#   'ATORVASTATIN': '3000001547',
#   'FOMEPIZOLE': '3000003027',
#   'MICAFUNGIN': '3100005355',
#   'CALCIUM GLUCEPTATE': '3000003998',
#   'STREPTOMYCIN': '3000001790',
#   'NIACIN': '3000002411',
#   'ALDESLEUKIN': '3000002538',
#   'DOXEPIN': '3000000807',
#   'LUMACAFTOR': '3000003856',
#   'NIACINAMIDE': '3000003909',
#   'LENALIDOMIDE': '3000001530',
#   'TROSPIUM': '3100005348',
#   'AURANOFIN': '3000004382',
#   'ABEMACICLIB': '3000000101',
#   'LEVONORDEFRIN': '3000002529',
#   'ROPIVACAINE': '3100005269',
#   'ULIPRISTAL': '3100005133',
#   'TEDUGLUTIDE': '3000004164',
#   'CYCLOPENTOLATE': '3100005343',
#   'VIGABATRIN': '3000001825',
#   'CLARITHROMYCIN': '3000001706',
#   'BICTEGRAVIR': '3000000861',
#   'ASPARTIC ACID': '3000002518',
#   'TRIAMCINOLONE': '3000002263',
#   'MODAFINIL': '3000000483',
#   'PHENTOLAMINE': '3100005166',
#   'PROCARBAZINE': '3000003378',
#   'GATIFLOXACIN': '3000001212',
#   'CANAKINUMAB': '3000000645',
#   'ALBUMIN (HUMAN)': '3000000661',
#   'MOXIDECTIN': '3000002071',
#   'GANIRELIX': '3000003037',
#   'VECURONIUM BROMIDE': '3000001224',
#   ...},
#  'form': {'SUSPENSION': '4000000051',
#   'ELIXIR': '4000000029',
#   'POWDER, FOR SOLUTION': '4000000124',
#   'SHAMPOO': '4000000112',
#   'GEL': '4000000020',
#   'SPRAY': '4000000034',
#   'SOLUTION': '4000000045',
#   'INSERT': '4000000002',
#   'SWAB': '4000000063',
#   'TABLET, EFFERVESCENT': '4000000109',
#   'ENEMA': '4000000086',
#   'CREAM': '4000000065',
#   'OIL': '4000000090',
#   'LOTION': '4000000024',
#   'PASTE': '4000000110',
#   'TABLET, EXTENDED RELEASE': '4000000046',
#   'OINTMENT': '4000000083',
#   'POWDER': '4000000003',
#   'PELLET': '4000000062',
#   'STICK': '4000000094',
#   'PATCH, EXTENDED RELEASE': '4000000098',
#   'EMULSION': '4000000004',
#   'TABLET, ORALLY DISINTEGRATING': '4000000071',
#   'PATCH': '4000000097',
#   'LIQUID': '4000000118',
#   'GAS': '4000000095',
#   'CAPSULE, DELAYED RELEASE': '4000000025',
#   'LOZENGE': '4000000040',
#   'WAFER': '4000000079',
#   'POWDER, FOR SUSPENSION': '4000000089',
#   'TINCTURE': '4000000101',
#   'SUPPOSITORY': '4000000061',
#   'DISC': '4000000075',
#   'INSERT, EXTENDED RELEASE': '4000000100',
#   'AEROSOL': '4000000016',
#   'TABLET, CHEWABLE': '4000000068',
#   'TABLET, FOR SUSPENSION': '4000000013',
#   'TAPE': '4000000049',
#   'SYRUP': '4000000070',
#   'CAPSULE, EXTENDED RELEASE': '4000000018',
#   'FILM, SOLUBLE': '4000000073',
#   'JELLY': '4000000126',
#   'STRIP': '4000000021',
#   'SUSPENSION, EXTENDED RELEASE': '4000000009',
#   'TABLET, DELAYED RELEASE': '4000000080',
#   'CAPSULE': '4000000017',
#   'IMPLANT': '4000000082',
#   'AEROSOL, FOAM': '4000000127',
#   'MOUTHWASH': '4000000074',
#   'TABLET': '4000000043',
#   'KIT': '4000000093',
#   'SHAMPOO, SUSPENSION': '4000000111',
#   'RING': '4000000058'},
#  'roa': {'INTRALESIONAL': '4100000015',
#   'INTERSTITIAL': '4100000019',
#   'INTRAVENOUS': '4100000079',
#   'TRANSDERMAL': '4100000083',
#   'NASAL': '4100000065',
#   'INTRACAUDAL': '4100000063',
#   'SUBCUTANEOUS': '4100000026',
#   'INTRAVENTRICULAR': '4100000092',
#   'VAGINAL': '4100000034',
#   'INTRASPINAL': '4100000055',
#   'INTRAVESICAL': '4100000014',
#   'SUBLINGUAL': '4100000070',
#   'INTRA-ARTICULAR': '4100000085',
#   'EXTRACORPOREAL': '4100000074',
#   'INTRAPERITONEAL': '4100000060',
#   'INTRAVASCULAR': '4100000077',
#   'URETHRAL': '4100000069',
#   'PERCUTANEOUS': '4100000032',
#   'BUCCAL': '4100000047',
#   'OPHTHALMIC': '4100000004',
#   'INTRA-ARTERIAL': '4100000091',
#   'NASOGASTRIC': '4100000035',
#   'INTRACARDIAC': '4100000040',
#   'INTRACORONARY': '4100000012',
#   'IRRIGATION': '4100000048',
#   'INTRAVITREAL': '4100000023',
#   'RETROBULBAR': '4100000059',
#   'INTRAPLEURAL': '4100000038',
#   'INTRATHECAL': '4100000073',
#   'INTRASYNOVIAL': '4100000090',
#   'INFILTRATION': '4100000042',
#   'INTRAOCULAR': '4100000051',
#   'INTRAUTERINE': '4100000039',
#   'INTRACAVITARY': '4100000071',
#   'SUBMUCOSAL': '4100000033',
#   'EPIDURAL': '4100000075',
#   'INTRADERMAL': '4100000068',
#   'DENTAL': '4100000072',
#   'RECTAL': '4100000002',
#   'TOPICAL': '4100000030',
#   'INTRAMUSCULAR': '4100000057',
#   'ORAL': '4100000056'}}
