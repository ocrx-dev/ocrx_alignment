# %%
import pandas as pd
df = pd.read_csv("all_drugs_ade_indications.csv").dropna()

# %%
df[df['active_ingredient'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, author, drug, active_ingredient, active_ingredient_code, code, filename, form_code, form, roa, roa_code, adverse_events_list, adverse_events, indications, numerator_name, numerator_val, denominator_name, denominator_val]
# Index: []

# %%
df['author'].unique().shape[0]
# Out:
# 152

# %%
df['form'].apply(lambda el: '|||' in el).sum()
# Out:
# 0

# %%
df['form'].dropna().shape[0]
# Out:
# 269

# %%
df['form'].shape[0]
# Out:
# 269

# %%
df[df['drug'] == 'Oxygen']['filename'].values[:5]
# Out:
# array([], dtype=object)

# %%
df
# Out:
#        Unnamed: 0                                 author  \
# 163           163                 Taylor Pharmaceuticals
# 179           179                                 Roxane
# 364           364                            Watson Labs
# 493           493         Celltech Pharmaceuticals, Inc.
# 577           577                            Pfizer Labs
# ...           ...                                    ...
# 45795       45795              Watson Laboratories, Inc.
# 45956       45956                             SkinMedica
# 46188       46188                    Lek Pharmaceuticals
# 46266       46266  Bayer HealthCare Pharmaceuticals Inc.
# 46543       46543                    NovaDel Pharma Inc.
#
#                           drug        active_ingredient  \
# 163                   INAPSINE                 INAPSINE
# 179               Clotrimazole             Clotrimazole
# 364               Trimethoprim             Trimethoprim
# ...

# %%
df[df['active_ingredient'] == 'ALBUTEROL SULFATE']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, author, drug, active_ingredient, active_ingredient_code, code, filename, form_code, form, roa, roa_code, adverse_events_list, adverse_events, indications, numerator_name, numerator_val, denominator_name, denominator_val]
# Index: []

# %%
# Out:
# 163                     INAPSINE
# 179                 Clotrimazole
# 364                 Trimethoprim
# 493               Mykrox Tablets
# 577        Renese-R ||| Renese-R
#                   ...
# 45795                 Clonazepam
# 45956                   Desonate
# 46188    Bromocriptine Mesylate
# 46266                    Feridex
# 46543                  NitroMist
# Name: active_ingredient, Length: 269, dtype: object
